# %%
import pandas as pd
import csv
import os
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
from helper.utils import get_ct_code_and_year, team_url_to_back_number_url

# %%
session = Session(1000000) # doesn't really matter for statiz

# %%
url = "https://statiz.sporki.com/team/" # starting point
front_url = "https://statiz.sporki.com" # front part of URL in which hrefs will be concatenated on.

# %%
# to filter duplicate
# both removed the header row
added_team_and_year = set([tuple(row) for row in csv.reader(open('../data/st_finished_team_year.csv', 'r'))][1:])
added_player = set([tuple(row) for row in csv.reader(open('../data/st_player.csv', 'r'))][1:])

# %%
# print(added_team_and_year)
# print(len(added_team_and_year))
# print(len(added_player))

# %%
team_data = session.fetch(url).content.decode("utf-8") # each team's data

# %%
trimmed = BSoup(team_data, "lxml").find(class_="team_list")

# %%
# initial header row setup
file_path = '../data/st_player.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name_kor", "name_eng"]
        writer.writerow(header)

# %%
with open(file_path, 'a', newline='') as file:

    writer = csv.writer(file)
    teams = trimmed.find_all(class_="select_con")
    
    for team in teams:
        years = team.find_all("a")
    
        for year in years:
            current_ct_code, current_year = get_ct_code_and_year(year['href'])
            # print(current_ct_code, current_year)
            # skip over the fully processed year with the given team.
            if (str(current_ct_code), str(current_year)) in added_team_and_year:
                print(f"already done, skip over code:{current_ct_code}, year: {current_year}")
                continue
            team_player_list_url = team_url_to_back_number_url(year['href'])
            team_data = session.fetch(team_player_list_url).content.decode("utf-8")
            team_html = BSoup(team_data, "lxml")
            players = team_html.find_all(class_="item away")[2:]

            for player in players:
                player_url = front_url + player.find("a")['href']
                player_data = session.fetch(player_url).content.decode("utf-8")
                player_html = BSoup(player_data, "lxml")
                player_name_proto = player_html.find(class_="name")
                # sometimes there is a blank page that doesn't contain any info about the player.
                if not player_name_proto:
                    continue
                player_name = player_name_proto.text.strip()
                player_info = (player_name.split('(')[0].strip(), player_name.split('(')[1][:-1])
    
                if player_info not in added_player:
                    added_player.add(player_info)
                    writer.writerow(player_info)
                    print("newly added: ", player_info)
                else:
                    print("dup skipped: ", player_info)

            print(f"finished code:{current_ct_code}, year: {current_year}")
            with open('../data/st_finished_team_year.csv', 'a', newline='') as another_file:
                another_writer = csv.writer(another_file)
                another_writer.writerow((current_ct_code, current_year))
                added_team_and_year.add(((str(current_ct_code), str(current_year))))
# Out:
# already done, skip over code:2, year: 1982
# already done, skip over code:2, year: 1983
# already done, skip over code:2, year: 1984
# already done, skip over code:2, year: 1985
# already done, skip over code:2, year: 1986
# already done, skip over code:2, year: 1987
# already done, skip over code:2, year: 1988
# already done, skip over code:2, year: 1989
# already done, skip over code:2, year: 1990
# already done, skip over code:2, year: 1991
# already done, skip over code:2, year: 1992
# already done, skip over code:2, year: 1993
# already done, skip over code:2, year: 1994
# already done, skip over code:2, year: 1995
# already done, skip over code:2, year: 1996
# already done, skip over code:2, year: 1997
# already done, skip over code:2, year: 1998
# already done, skip over code:2, year: 1999
# already done, skip over code:2, year: 2000
# already done, skip over code:2, year: 2001
# already done, skip over code:2, year: 2002
# already done, skip over code:2, year: 2003
# already done, skip over code:2, year: 2004
# already done, skip over code:2, year: 2005
# already done, skip over code:2, year: 2006
# already done, skip over code:2, year: 2007
# already done, skip over code:2, year: 2008
# already done, skip over code:2, year: 2009
# already done, skip over code:2, year: 2010
# already done, skip over code:2, year: 2011
# already done, skip over code:2, year: 2012
# already done, skip over code:2, year: 2013
# already done, skip over code:2, year: 2014
# already done, skip over code:2, year: 2015
# already done, skip over code:2, year: 2016
# already done, skip over code:2, year: 2017
# already done, skip over code:2, year: 2018
# already done, skip over code:2, year: 2019
# already done, skip over code:2, year: 2020
# already done, skip over code:2, year: 2021
# already done, skip over code:2, year: 2022
# already done, skip over code:2, year: 2023
# already done, skip over code:2, year: 2024
# already done, skip over code:1, year: 1982
# already done, skip over code:1, year: 1983
# already done, skip over code:1, year: 1984
# already done, skip over code:1, year: 1985
# already done, skip over code:1, year: 1986
# already done, skip over code:1, year: 1987
# already done, skip over code:1, year: 1988
# already done, skip over code:1, year: 1989
# already done, skip over code:1, year: 1990
# already done, skip over code:1, year: 1991
# already done, skip over code:1, year: 1992
# already done, skip over code:1, year: 1993
# already done, skip over code:1, year: 1994
# already done, skip over code:1, year: 1995
# already done, skip over code:1, year: 1996
# already done, skip over code:1, year: 1997
# already done, skip over code:1, year: 1998
# already done, skip over code:1, year: 1999
# already done, skip over code:1, year: 2000
# already done, skip over code:1, year: 2001
# already done, skip over code:1, year: 2002
# already done, skip over code:1, year: 2003
# already done, skip over code:1, year: 2004
# already done, skip over code:1, year: 2005
# already done, skip over code:1, year: 2006
# already done, skip over code:1, year: 2007
# already done, skip over code:1, year: 2008
# already done, skip over code:1, year: 2009
# already done, skip over code:1, year: 2010
# already done, skip over code:1, year: 2011
# already done, skip over code:1, year: 2012
# already done, skip over code:1, year: 2013
# already done, skip over code:1, year: 2014
# already done, skip over code:1, year: 2015
# already done, skip over code:1, year: 2016
# already done, skip over code:1, year: 2017
# already done, skip over code:1, year: 2018
# already done, skip over code:1, year: 2019
# already done, skip over code:1, year: 2020
# already done, skip over code:1, year: 2021
# already done, skip over code:1, year: 2022
# already done, skip over code:1, year: 2023
# already done, skip over code:1, year: 2024
# already done, skip over code:6, year: 1982
# already done, skip over code:6, year: 1983
# already done, skip over code:6, year: 1984
# already done, skip over code:6, year: 1985
# already done, skip over code:6, year: 1986
# already done, skip over code:6, year: 1987
# already done, skip over code:6, year: 1988
# already done, skip over code:6, year: 1989
# already done, skip over code:6, year: 1990
# already done, skip over code:6, year: 1991
# already done, skip over code:6, year: 1992
# already done, skip over code:6, year: 1993
# already done, skip over code:6, year: 1994
# already done, skip over code:6, year: 1995
# already done, skip over code:6, year: 1996
# already done, skip over code:6, year: 1997
# already done, skip over code:6, year: 1998
# already done, skip over code:6, year: 1999
# already done, skip over code:6, year: 2000
# already done, skip over code:6, year: 2001
# already done, skip over code:6, year: 2002
# already done, skip over code:6, year: 2003
# already done, skip over code:6, year: 2004
# already done, skip over code:6, year: 2005
# already done, skip over code:6, year: 2006
# already done, skip over code:6, year: 2007
# already done, skip over code:6, year: 2008
# already done, skip over code:6, year: 2009
# already done, skip over code:6, year: 2010
# already done, skip over code:6, year: 2011
# already done, skip over code:6, year: 2012
# already done, skip over code:6, year: 2013
# already done, skip over code:6, year: 2014
# already done, skip over code:6, year: 2015
# already done, skip over code:6, year: 2016
# already done, skip over code:6, year: 2017
# already done, skip over code:6, year: 2018
# already done, skip over code:6, year: 2019
# already done, skip over code:6, year: 2020
# already done, skip over code:6, year: 2021
# already done, skip over code:6, year: 2022
# already done, skip over code:6, year: 2023
# already done, skip over code:6, year: 2024
# already done, skip over code:9, year: 2000
# already done, skip over code:9, year: 2001
# already done, skip over code:9, year: 2002
# already done, skip over code:9, year: 2003
# already done, skip over code:9, year: 2004
# already done, skip over code:9, year: 2005
# already done, skip over code:9, year: 2006
# already done, skip over code:9, year: 2007
# already done, skip over code:9, year: 2008
# already done, skip over code:9, year: 2009
# already done, skip over code:9, year: 2010
# already done, skip over code:9, year: 2011
# already done, skip over code:9, year: 2012
# already done, skip over code:9, year: 2013
# already done, skip over code:9, year: 2014
# already done, skip over code:9, year: 2015
# already done, skip over code:9, year: 2016
# already done, skip over code:9, year: 2017
# already done, skip over code:9, year: 2018
# already done, skip over code:9, year: 2019
# already done, skip over code:9, year: 2020
# already done, skip over code:9, year: 2021
# already done, skip over code:9, year: 2022
# already done, skip over code:9, year: 2023
# already done, skip over code:9, year: 2024
# already done, skip over code:4, year: 1982
# already done, skip over code:4, year: 1983
# already done, skip over code:4, year: 1984
# already done, skip over code:4, year: 1985
# already done, skip over code:4, year: 1986
# already done, skip over code:4, year: 1987
# already done, skip over code:4, year: 1988
# already done, skip over code:4, year: 1989
# already done, skip over code:4, year: 1990
# already done, skip over code:4, year: 1991
# already done, skip over code:4, year: 1992
# already done, skip over code:4, year: 1993
# already done, skip over code:4, year: 1994
# already done, skip over code:4, year: 1995
# already done, skip over code:4, year: 1996
# already done, skip over code:4, year: 1997
# already done, skip over code:4, year: 1998
# already done, skip over code:4, year: 1999
# already done, skip over code:4, year: 2000
# already done, skip over code:4, year: 2001
# already done, skip over code:4, year: 2002
# already done, skip over code:4, year: 2003
# already done, skip over code:4, year: 2004
# already done, skip over code:4, year: 2005
# already done, skip over code:4, year: 2006
# already done, skip over code:4, year: 2007
# already done, skip over code:5, year: 1982
# already done, skip over code:5, year: 1983
# already done, skip over code:5, year: 1984
# already done, skip over code:5, year: 1985
# already done, skip over code:5, year: 1986
# already done, skip over code:5, year: 1987
# already done, skip over code:5, year: 1988
# already done, skip over code:5, year: 1989
# already done, skip over code:5, year: 1990
# already done, skip over code:5, year: 1991
# already done, skip over code:5, year: 1992
# already done, skip over code:5, year: 1993
# already done, skip over code:5, year: 1994
# already done, skip over code:5, year: 1995
# already done, skip over code:5, year: 1996
# already done, skip over code:5, year: 1997
# already done, skip over code:5, year: 1998
# already done, skip over code:5, year: 1999
# already done, skip over code:5, year: 2000
# already done, skip over code:5, year: 2001
# already done, skip over code:5, year: 2002
# already done, skip over code:5, year: 2003
# already done, skip over code:5, year: 2004
# already done, skip over code:5, year: 2005
# already done, skip over code:5, year: 2006
# already done, skip over code:5, year: 2007
# already done, skip over code:5, year: 2008
# already done, skip over code:5, year: 2009
# already done, skip over code:5, year: 2010
# already done, skip over code:5, year: 2011
# already done, skip over code:5, year: 2012
# already done, skip over code:5, year: 2013
# already done, skip over code:5, year: 2014
# already done, skip over code:5, year: 2015
# already done, skip over code:5, year: 2016
# already done, skip over code:5, year: 2017
# already done, skip over code:5, year: 2018
# already done, skip over code:5, year: 2019
# already done, skip over code:5, year: 2020
# already done, skip over code:5, year: 2021
# already done, skip over code:5, year: 2022
# already done, skip over code:5, year: 2023
# already done, skip over code:5, year: 2024
# already done, skip over code:3, year: 1982
# already done, skip over code:3, year: 1983
# already done, skip over code:3, year: 1984
# already done, skip over code:3, year: 1985
# already done, skip over code:3, year: 1986
# already done, skip over code:3, year: 1987
# already done, skip over code:3, year: 1988
# already done, skip over code:3, year: 1989
# already done, skip over code:3, year: 1990
# already done, skip over code:3, year: 1991
# already done, skip over code:3, year: 1992
# already done, skip over code:3, year: 1993
# already done, skip over code:3, year: 1994
# already done, skip over code:3, year: 1995
# already done, skip over code:3, year: 1996
# already done, skip over code:3, year: 1997
# already done, skip over code:3, year: 1998
# already done, skip over code:3, year: 1999
# already done, skip over code:3, year: 2000
# already done, skip over code:3, year: 2001
# already done, skip over code:3, year: 2002
# already done, skip over code:3, year: 2003
# already done, skip over code:3, year: 2004
# already done, skip over code:3, year: 2005
# already done, skip over code:3, year: 2006
# already done, skip over code:3, year: 2007
# already done, skip over code:3, year: 2008
# already done, skip over code:3, year: 2009
# already done, skip over code:3, year: 2010
# already done, skip over code:3, year: 2011
# already done, skip over code:3, year: 2012
# already done, skip over code:3, year: 2013
# already done, skip over code:3, year: 2014
# already done, skip over code:3, year: 2015
# already done, skip over code:3, year: 2016
# already done, skip over code:3, year: 2017
# already done, skip over code:3, year: 2018
# already done, skip over code:3, year: 2019
# already done, skip over code:3, year: 2020
# already done, skip over code:3, year: 2021
# already done, skip over code:3, year: 2022
# already done, skip over code:3, year: 2023
# already done, skip over code:3, year: 2024
# dup skipped:  ('송상진', 'Sang-Jin Song')
# dup skipped:  ('이광길', 'Kwang-Gil Lee')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('김우열', 'Woo-Yeol Kim')
# dup skipped:  ('고원부', 'Won-Bu Ko')
# newly added:  ('김종수', 'Jong-Soo Kim')
# dup skipped:  ('박재천', 'Jae-Chun Park')
# newly added:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('이성수', 'Seong-Su Lee')
# newly added:  ('윤홍식', 'Hong-Sik Yoon')
# newly added:  ('김정태', 'Jung-Tae Kim')
# newly added:  ('임순태', 'Soon-Tae Lim')
# dup skipped:  ('김성갑', 'Sung-Gap Kim')
# dup skipped:  ('한희민', 'Hei-Min Han')
# newly added:  ('김연철', 'Yeon-Cheol Kim')
# newly added:  ('유해덕', 'Hae-Deok Yu')
# newly added:  ('전대영', 'Dae-Young Jeun')
# newly added:  ('민문식', 'Moon-Sik Min')
# newly added:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('장명부', 'Myung-Bu Jang')
# dup skipped:  ('이석규', 'Seog-Kyu Lee')
# newly added:  ('김종문', 'Jong-Moon Kim')
# newly added:  ('이정은', 'Jeong-Eun Lee')
# dup skipped:  ('유승안', 'Seung-An Yu')
# dup skipped:  ('배원영', 'Won-Young Bae')
# dup skipped:  ('김재열', 'Jae-Yeol Kim')
# newly added:  ('임재준', 'Jae-Jun Lim')
# dup skipped:  ('이근식', 'Keun-Sig Lee')
# dup skipped:  ('성낙수', 'Nak-Soo Sung')
# dup skipped:  ('김한근', 'Han-Geun Kim')
# dup skipped:  ('홍순만', 'Soon-Man Hong')
# newly added:  ('이강돈', 'Kang-Don Lee')
# newly added:  ('장훈', 'Hoon Jang')
# newly added:  ('이군노', 'Kun-Noh Lee')
# newly added:  ('조호표', 'Ho-Pyo Cho')
# newly added:  ('김현택', 'Hyun-Taek Kim')
# dup skipped:  ('손문곤', 'Mun-Gon Son')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# newly added:  ('김수길', 'Soo-Gil Kim')
# dup skipped:  ('황병일', 'Byeong-Il Hwang')
# dup skipped:  ('박찬', 'Chan Park')
# dup skipped:  ('김종윤', 'Jong-Yoon Kim')
# dup skipped:  ('천창호', 'Chang-Ho Cheon')
# dup skipped:  ('김성호', 'Seong-Ho Kim')
# finished code:7, year: 1986
# dup skipped:  ('이광길', 'Kwang-Gil Lee')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('고원부', 'Won-Bu Ko')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('윤홍식', 'Hong-Sik Yoon')
# dup skipped:  ('김정태', 'Jung-Tae Kim')
# dup skipped:  ('천창호', 'Chang-Ho Cheon')
# dup skipped:  ('김성갑', 'Sung-Gap Kim')
# dup skipped:  ('한희민', 'Hei-Min Han')
# dup skipped:  ('김연철', 'Yeon-Cheol Kim')
# dup skipped:  ('유해덕', 'Hae-Deok Yu')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강만식', 'Man-Sik Kang')
# dup skipped:  ('민문식', 'Moon-Sik Min')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('조용호', 'Yong-Ho Cho')
# dup skipped:  ('김종문', 'Jong-Moon Kim')
# dup skipped:  ('임정면', 'Jung-Myun Lim')
# dup skipped:  ('유승안', 'Seung-An Yu')
# dup skipped:  ('박전섭', 'Jeon-Sub Park')
# dup skipped:  ('김재열', 'Jae-Yeol Kim')
# dup skipped:  ('이동석', 'Dong-Seok Lee')
# newly added:  ('김대중', 'Dae-Joong Kim')
# dup skipped:  ('임재준', 'Jae-Jun Lim')
# dup skipped:  ('김한근', 'Han-Geun Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('김용남', 'Yong-Nam Kim')
# newly added:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('정상진', 'Sang-Jin Jung')
# dup skipped:  ('손문곤', 'Mun-Gon Son')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('김수길', 'Soo-Gil Kim')
# dup skipped:  ('황병일', 'Byeong-Il Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('김성호', 'Seong-Ho Kim')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# finished code:7, year: 1987
# dup skipped:  ('이광길', 'Kwang-Gil Lee')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('김한근', 'Han-Geun Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('고원부', 'Won-Bu Ko')
# dup skipped:  ('김성갑', 'Sung-Gap Kim')
# dup skipped:  ('김수길', 'Soo-Gil Kim')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# newly added:  ('곽동열', 'Dong-Yeol Kwak')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('천창호', 'Chang-Ho Cheon')
# newly added:  ('지성규', 'Sung-Kyu Ji')
# dup skipped:  ('한희민', 'Hei-Min Han')
# dup skipped:  ('김연철', 'Yeon-Cheol Kim')
# dup skipped:  ('유해덕', 'Hae-Deok Yu')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강만식', 'Man-Sik Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('조용호', 'Yong-Ho Cho')
# newly added:  ('오효근', 'Hyo-Geun Oh')
# newly added:  ('안성수', 'Sung-Soo An')
# dup skipped:  ('김종문', 'Jong-Moon Kim')
# dup skipped:  ('임정면', 'Jung-Myun Lim')
# dup skipped:  ('유승안', 'Seung-An Yu')
# dup skipped:  ('김재열', 'Jae-Yeol Kim')
# dup skipped:  ('이동석', 'Dong-Seok Lee')
# dup skipped:  ('김대중', 'Dae-Joong Kim')
# dup skipped:  ('임재준', 'Jae-Jun Lim')
# dup skipped:  ('이척기', 'Cheok-Ki Lee')
# newly added:  ('김홍명', 'Hong-Myeong Kim')
# newly added:  ('김광윤', 'Kwang-Yoon Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('김용남', 'Yong-Nam Kim')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('조양근', 'Yang-Geun Cho')
# dup skipped:  ('정상진', 'Sang-Jin Jung')
# dup skipped:  ('손문곤', 'Mun-Gon Son')
# newly added:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# dup skipped:  ('황병일', 'Byeong-Il Hwang')
# dup skipped:  ('송일섭', 'Il-Sub Song')
# dup skipped:  ('김성호', 'Seong-Ho Kim')
# newly added:  ('박성현', 'Sung-Hyun Park')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# finished code:7, year: 1988
# newly added:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('고원부', 'Won-Bu Ko')
# dup skipped:  ('김성갑', 'Sung-Gap Kim')
# dup skipped:  ('김수길', 'Soo-Gil Kim')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('곽동열', 'Dong-Yeol Kwak')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# newly added:  ('김락기', 'Rak-Gi Kim')
# dup skipped:  ('지성규', 'Sung-Kyu Ji')
# dup skipped:  ('한희민', 'Hei-Min Han')
# dup skipped:  ('유해덕', 'Hae-Deok Yu')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# newly added:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('조용호', 'Yong-Ho Cho')
# newly added:  ('성군철', 'Kun-Chul Sung')
# dup skipped:  ('안성수', 'Sung-Soo An')
# dup skipped:  ('김종문', 'Jong-Moon Kim')
# dup skipped:  ('이종호', 'Jong-Ho Lee')
# dup skipped:  ('유승안', 'Seung-An Yu')
# newly added:  ('진정필', 'Jeong-Pil Jin')
# newly added:  ('손경호', 'Kyoung-Ho Son')
# dup skipped:  ('이동석', 'Dong-Seok Lee')
# dup skipped:  ('김대중', 'Dae-Joong Kim')
# dup skipped:  ('임재준', 'Jae-Jun Lim')
# dup skipped:  ('이척기', 'Cheok-Ki Lee')
# dup skipped:  ('김홍명', 'Hong-Myeong Kim')
# dup skipped:  ('김광윤', 'Kwang-Yoon Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('김용남', 'Yong-Nam Kim')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('조양근', 'Yang-Geun Cho')
# dup skipped:  ('오효근', 'Hyo-Geun Oh')
# dup skipped:  ('손문곤', 'Mun-Gon Son')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# dup skipped:  ('황병일', 'Byeong-Il Hwang')
# dup skipped:  ('송일섭', 'Il-Sub Song')
# newly added:  ('이효봉', 'Hyo-Bong Lee')
# newly added:  ('이은승', 'Eun-Seung Lee')
# newly added:  ('손창현', 'Chang-Hyun Son')
# newly added:  ('김용선', 'Yong-Seon Kim')
# dup skipped:  ('박선일', 'Sun-Il Park')
# finished code:7, year: 1989
# newly added:  ('지화동', 'Hwa-Dong Ji')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('고원부', 'Won-Bu Ko')
# dup skipped:  ('김성갑', 'Sung-Gap Kim')
# dup skipped:  ('김수길', 'Soo-Gil Kim')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('김락기', 'Rak-Gi Kim')
# dup skipped:  ('지성규', 'Sung-Kyu Ji')
# dup skipped:  ('한희민', 'Hei-Min Han')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('성군철', 'Kun-Chul Sung')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('김종문', 'Jong-Moon Kim')
# dup skipped:  ('이종호', 'Jong-Ho Lee')
# dup skipped:  ('유승안', 'Seung-An Yu')
# dup skipped:  ('진정필', 'Jeong-Pil Jin')
# dup skipped:  ('손경호', 'Kyoung-Ho Son')
# dup skipped:  ('이동석', 'Dong-Seok Lee')
# dup skipped:  ('김대중', 'Dae-Joong Kim')
# dup skipped:  ('이척기', 'Cheok-Ki Lee')
# dup skipped:  ('김홍명', 'Hong-Myeong Kim')
# dup skipped:  ('김광윤', 'Kwang-Yoon Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('조양근', 'Yang-Geun Cho')
# dup skipped:  ('오효근', 'Hyo-Geun Oh')
# dup skipped:  ('진상봉', 'Sang-Bong Jin')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# dup skipped:  ('황병일', 'Byeong-Il Hwang')
# dup skipped:  ('송일섭', 'Il-Sub Song')
# dup skipped:  ('이효봉', 'Hyo-Bong Lee')
# newly added:  ('원근호', 'Geun-Ho Won')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# newly added:  ('유태완', 'Tae-Wahn Yu')
# dup skipped:  ('박선일', 'Sun-Il Park')
# finished code:7, year: 1990
# dup skipped:  ('지화동', 'Hwa-Dong Ji')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('고원부', 'Won-Bu Ko')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# newly added:  ('김석연', 'Seok-Yeon Kim')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('김락기', 'Rak-Gi Kim')
# dup skipped:  ('한희민', 'Hei-Min Han')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# newly added:  ('김기열', 'Ki-Yeol Kim')
# dup skipped:  ('성군철', 'Kun-Chul Sung')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('김종문', 'Jong-Moon Kim')
# dup skipped:  ('이종호', 'Jong-Ho Lee')
# dup skipped:  ('유승안', 'Seung-An Yu')
# dup skipped:  ('진정필', 'Jeong-Pil Jin')
# dup skipped:  ('이동석', 'Dong-Seok Lee')
# dup skipped:  ('김대중', 'Dae-Joong Kim')
# newly added:  ('김인권', 'In-Kwon Kim')
# dup skipped:  ('김홍명', 'Hong-Myeong Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('양용모', 'Yong-Mo Yang')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('조양근', 'Yang-Geun Cho')
# dup skipped:  ('진상봉', 'Sang-Bong Jin')
# newly added:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# newly added:  ('공용우', 'Yong-Wu Gong ')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# newly added:  ('임성우', 'Sung-Woo Lim')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# newly added:  ('김원근', 'Won-Geun Kim')
# newly added:  ('임돈영', 'Don-Young Lim')
# newly added:  ('김일훈', 'Il-Hoon Kim')
# dup skipped:  ('박선일', 'Sun-Il Park')
# finished code:7, year: 1991
# dup skipped:  ('지화동', 'Hwa-Dong Ji')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('조양근', 'Yang-Geun Cho')
# dup skipped:  ('김홍집', 'Hong-Jib Kim')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('김석연', 'Seok-Yeon Kim')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('김락기', 'Rak-Gi Kim')
# dup skipped:  ('한희민', 'Hei-Min Han')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('성군철', 'Kun-Chul Sung')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('이종호', 'Jong-Ho Lee')
# dup skipped:  ('진정필', 'Jeong-Pil Jin')
# newly added:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('김대중', 'Dae-Joong Kim')
# dup skipped:  ('김인권', 'In-Kwon Kim')
# newly added:  ('김일혁', 'Il-Hyuk Kim')
# dup skipped:  ('김홍명', 'Hong-Myeong Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('양용모', 'Yong-Mo Yang')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# newly added:  ('김재성', 'Jae-Sung Kim')
# dup skipped:  ('진상봉', 'Sang-Bong Jin')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# newly added:  ('신일호', 'Il-Ho Shin')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# dup skipped:  ('임성우', 'Sung-Woo Lim')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# newly added:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('김원근', 'Won-Geun Kim')
# dup skipped:  ('임돈영', 'Don-Young Lim')
# dup skipped:  ('김일훈', 'Il-Hoon Kim')
# newly added:  ('임규대', 'Gyu-Dae Lim')
# dup skipped:  ('박상현', 'Sang-Hyun Park')
# dup skipped:  ('박선일', 'Sun-Il Park')
# finished code:7, year: 1992
# dup skipped:  ('지화동', 'Hwa-Dong Ji')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('이종호', 'Jong-Ho Lee')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('김홍집', 'Hong-Jib Kim')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('김석연', 'Seok-Yeon Kim')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('김락기', 'Rak-Gi Kim')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# newly added:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('이국성', 'Guk-Sung Lee')
# dup skipped:  ('지화선', 'Hwa-Sun Ji')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# newly added:  ('우태원', 'Tae-Won Woo')
# dup skipped:  ('진정필', 'Jeong-Pil Jin')
# newly added:  ('고기성', 'Gi-Sung Ko')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('노장진', 'Jang-Jin Noh')
# dup skipped:  ('김인권', 'In-Kwon Kim')
# dup skipped:  ('김일혁', 'Il-Hyuk Kim')
# newly added:  ('김성열', 'Sung-Yeol Kim')
# newly added:  ('원현식', 'Hyun-Sik Won')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('양용모', 'Yong-Mo Yang')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('진상봉', 'Sang-Bong Jin')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# dup skipped:  ('이민호', 'Min-Ho Lee')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# dup skipped:  ('임성우', 'Sung-Woo Lim')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('김원근', 'Won-Geun Kim')
# dup skipped:  ('임돈영', 'Don-Young Lim')
# dup skipped:  ('임규대', 'Gyu-Dae Lim')
# finished code:7, year: 1993
# dup skipped:  ('지화동', 'Hwa-Dong Ji')
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('이중화', 'Joong-Hwa Lee')
# dup skipped:  ('이종호', 'Jong-Ho Lee')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('전형도', 'Hyung-Do Jeon')
# newly added:  ('신진수', 'Jin-Soo Shin')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('이민호', 'Min-Ho Lee')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('이정훈', 'Jeong-Hun Lee')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('전대영', 'Dae-Young Jeun')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('이국성', 'Guk-Sung Lee')
# dup skipped:  ('지화선', 'Hwa-Sun Ji')
# dup skipped:  ('장정순', 'Jung-Soon Jang')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('김홍집', 'Hong-Jib Kim')
# dup skipped:  ('우태원', 'Tae-Won Woo')
# dup skipped:  ('정진식', 'Jin-Sik Jung')
# dup skipped:  ('진정필', 'Jeong-Pil Jin')
# dup skipped:  ('고기성', 'Gi-Sung Ko')
# dup skipped:  ('길배진', 'Bae-Jin Gil')
# dup skipped:  ('김인권', 'In-Kwon Kim')
# dup skipped:  ('김성열', 'Sung-Yeol Kim')
# dup skipped:  ('원현식', 'Hyun-Sik Won')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('김재성', 'Jae-Sung Kim')
# newly added:  ('최호원', 'Ho-Won Choi ')
# dup skipped:  ('진상봉', 'Sang-Bong Jin')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# newly added:  ('이요한', 'Yo-Han Lee')
# newly added:  ('박지상', 'Ji-Sang Park')
# dup skipped:  ('김성한', 'Sung-Han Kim')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# newly added:  ('김정윤', 'Jung-Yoon Kim')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('김원근', 'Won-Geun Kim')
# dup skipped:  ('임돈영', 'Don-Young Lim')
# newly added:  ('장진성', 'Jin-Sung Jang')
# dup skipped:  ('임규대', 'Gyu-Dae Lim')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# dup skipped:  ('박상현', 'Sang-Hyun Park')
# finished code:7, year: 1994
# dup skipped:  ('김상국', 'Sang-Guk Kim')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('신진수', 'Jin-Soo Shin')
# dup skipped:  ('강정길', 'Jung-Gil Kang')
# dup skipped:  ('이민호', 'Min-Ho Lee')
# dup skipped:  ('황대연', 'Dae-Yeon Hwang')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# newly added:  ('김영진', 'Young-Jin Kim')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('이국성', 'Guk-Sung Lee')
# dup skipped:  ('나성열', 'Sung-Yeol Na')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('정진식', 'Jin-Sik Jung')
# dup skipped:  ('정영규', 'Young-Kyu Jung')
# dup skipped:  ('진정필', 'Jeong-Pil Jin')
# dup skipped:  ('고기성', 'Gi-Sung Ko')
# dup skipped:  ('길배진', 'Bae-Jin Gil')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('김일혁', 'Il-Hyuk Kim')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('정경훈', 'Kyung-Hoon Jung')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('김재성', 'Jae-Sung Kim')
# dup skipped:  ('최호원', 'Ho-Won Choi ')
# dup skipped:  ('진상봉', 'Sang-Bong Jin')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('박지상', 'Ji-Sang Park')
# dup skipped:  ('김민태', 'Min-Tae Kim')
# dup skipped:  ('김성한', 'Sung-Han Kim')
# newly added:  ('정의성', 'Ui-Seong Jung')
# dup skipped:  ('김일훈', 'Il-Hoon Kim')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# dup skipped:  ('김정윤', 'Jung-Yoon Kim')
# dup skipped:  ('박상현', 'Sang-Hyun Park')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('김원근', 'Won-Geun Kim')
# dup skipped:  ('장진성', 'Jin-Sung Jang')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# finished code:7, year: 1995
# newly added:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('정경훈', 'Kyung-Hoon Jung')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('허준', 'Jun Heo')
# newly added:  ('오중석', 'Joong-Seok Oh')
# dup skipped:  ('신진수', 'Jin-Soo Shin')
# dup skipped:  ('이민호', 'Min-Ho Lee')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# newly added:  ('정영환', 'Young-Hwan Jung')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('김영진', 'Young-Jin Kim')
# dup skipped:  ('김민태', 'Min-Tae Kim')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('이상열', 'Sang-Yeol Lee')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('홍원기', 'Won-Ki Hong')
# dup skipped:  ('정진식', 'Jin-Sik Jung')
# newly added:  ('김대헌', 'Dae-Heon Kim')
# dup skipped:  ('정영규', 'Young-Kyu Jung')
# dup skipped:  ('고기성', 'Gi-Sung Ko')
# dup skipped:  ('길배진', 'Bae-Jin Gil')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('김성한', 'Sung-Han Kim')
# dup skipped:  ('강봉수', 'Bong-Soo Kang')
# dup skipped:  ('박은진', 'Eun-Jin Park')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# newly added:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('김재성', 'Jae-Sung Kim')
# dup skipped:  ('최호원', 'Ho-Won Choi ')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# newly added:  ('엄종수', 'Jong-Soo Um')
# dup skipped:  ('박지상', 'Ji-Sang Park')
# dup skipped:  ('나성열', 'Sung-Yeol Na')
# newly added:  ('권오영', 'O-young Kwon')
# dup skipped:  ('김정윤', 'Jung-Yoon Kim')
# dup skipped:  ('박상현', 'Sang-Hyun Park')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('장진성', 'Jin-Sung Jang')
# dup skipped:  ('김주성', 'Ju-Sung Kim')
# dup skipped:  ('송지만', 'Ji-Man Song')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# newly added:  ('김수연', 'Su-Yeoun Kim')
# finished code:7, year: 1996
# dup skipped:  ('정기창', 'Ki-Chang Jung')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('정경훈', 'Kyung-Hoon Jung')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('오중석', 'Joong-Seok Oh')
# dup skipped:  ('신진수', 'Jin-Soo Shin')
# dup skipped:  ('이민호', 'Min-Ho Lee')
# newly added:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# newly added:  ('노상진', 'Sang-Jin Noh')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('김민태', 'Min-Tae Kim')
# dup skipped:  ('이상열', 'Sang-Yeol Lee')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('홍원기', 'Won-Ki Hong')
# dup skipped:  ('정진식', 'Jin-Sik Jung')
# dup skipped:  ('정영규', 'Young-Kyu Jung')
# dup skipped:  ('김대헌', 'Dae-Heon Kim')
# dup skipped:  ('고기성', 'Gi-Sung Ko')
# dup skipped:  ('길배진', 'Bae-Jin Gil')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('홍우태', 'Woo-Tai Hong')
# dup skipped:  ('노장진', 'Jang-Jin Noh')
# dup skipped:  ('이강돈', 'Kang-Don Lee')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('김재성', 'Jae-Sung Kim')
# dup skipped:  ('최호원', 'Ho-Won Choi ')
# dup skipped:  ('이은승', 'Eun-Seung Lee')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('오문현', 'Moon-Hyun Oh')
# dup skipped:  ('김충민', 'Chung-Min Kim')
# dup skipped:  ('전상렬', 'Sangr-Yul  Jeon')
# dup skipped:  ('권오영', 'O-young Kwon')
# dup skipped:  ('김정윤', 'Jung-Yoon Kim')
# newly added:  ('오주상', 'Ju-Sang Oh')
# dup skipped:  ('김태형', 'Tae-Hyung Kim')
# dup skipped:  ('김용선', 'Yong-Seon Kim')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('정영환', 'Young-Hwan Jung')
# newly added:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('장진성', 'Jin-Sung Jang')
# dup skipped:  ('송지만', 'Ji-Man Song')
# newly added:  ('장순재', 'Soon-Jae Jang')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# finished code:7, year: 1997
# dup skipped:  ('정기창', 'Ki-Chang Jung')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('정경훈', 'Kyung-Hoon Jung')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('신진수', 'Jin-Soo Shin')
# dup skipped:  ('이민호', 'Min-Ho Lee')
# dup skipped:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# dup skipped:  ('김민태', 'Min-Tae Kim')
# dup skipped:  ('이상열', 'Sang-Yeol Lee')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('홍원기', 'Won-Ki Hong')
# dup skipped:  ('고기성', 'Gi-Sung Ko')
# dup skipped:  ('길배진', 'Bae-Jin Gil')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('홍우태', 'Woo-Tai Hong')
# dup skipped:  ('노장진', 'Jang-Jin Noh')
# newly added:  ('부시', 'Michael Busch')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('이종운', 'Jong-Woon Lee')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('최호원', 'Ho-Won Choi ')
# newly added:  ('치멜리스', 'Joel Chimelis')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# newly added:  ('신경현', 'Kyung-Hyun Shin')
# dup skipped:  ('동봉철', 'Bong-chul Dong')
# dup skipped:  ('김충민', 'Chung-Min Kim')
# dup skipped:  ('전상렬', 'Sangr-Yul  Jeon')
# dup skipped:  ('권오영', 'O-young Kwon')
# dup skipped:  ('오주상', 'Ju-Sang Oh')
# newly added:  ('김기성', 'Ki-Sung Kim ')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('정영환', 'Young-Hwan Jung')
# dup skipped:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('송지만', 'Ji-Man Song')
# dup skipped:  ('공용우', 'Yong-Wu Gong ')
# dup skipped:  ('김재현', 'Jae-Hyeon Kim')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# finished code:7, year: 1998
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('정경훈', 'Kyung-Hoon Jung')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# dup skipped:  ('최호원', 'Ho-Won Choi ')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('송지만', 'Ji-Man Song')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# newly added:  ('윤근주', 'Geun-Ju Yoon')
# newly added:  ('문용민', 'Yong-Min Moon')
# dup skipped:  ('이상열', 'Sang-Yeol Lee')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('김경원', 'Kyung-Won Kim')
# dup skipped:  ('로마이어', 'Daniel Rohrmeier')
# newly added:  ('데이비스', 'Gerrod Jay Davis')
# dup skipped:  ('오규택', 'Kyu-Taek Oh')
# newly added:  ('오창선', 'Chang-Seon Oh')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('임창식', 'Chang-Sik Lim')
# dup skipped:  ('홍우태', 'Woo-Tai Hong')
# newly added:  ('황우구', 'Woo-Gu Hwang')
# dup skipped:  ('신경현', 'Kyung-Hyun Shin')
# dup skipped:  ('최익성', 'Ik-Sung Choi')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('박성기', 'Sung-Ki Park')
# newly added:  ('박정진', 'Jung-Jin Park')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('김충민', 'Chung-Min Kim')
# dup skipped:  ('권오영', 'O-young Kwon')
# dup skipped:  ('오주상', 'Ju-Sang Oh')
# dup skipped:  ('박태순', 'Tae-Soon Park')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('심재윤', 'Jae-Yoon Sim')
# dup skipped:  ('김재현', 'Jae-Hyeon Kim')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# finished code:7, year: 1999
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# dup skipped:  ('윤근주', 'Geun-Ju Yoon')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# newly added:  ('김장백', 'Jang-Baek Kim')
# dup skipped:  ('이상열', 'Sang-Yeol Lee')
# dup skipped:  ('문용민', 'Yong-Min Moon')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('김경원', 'Kyung-Won Kim')
# dup skipped:  ('로마이어', 'Daniel Rohrmeier')
# dup skipped:  ('데이비스', 'Gerrod Jay Davis')
# dup skipped:  ('송지만', 'Ji-Man Song')
# dup skipped:  ('오규택', 'Kyu-Taek Oh')
# dup skipped:  ('오창선', 'Chang-Seon Oh')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('홍우태', 'Woo-Tai Hong')
# dup skipped:  ('황우구', 'Woo-Gu Hwang')
# dup skipped:  ('심재윤', 'Jae-Yoon Sim')
# dup skipped:  ('신경현', 'Kyung-Hyun Shin')
# dup skipped:  ('김종석', 'Jong-Seok Kim')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('김재현', 'Jae-Hyeon Kim')
# dup skipped:  ('박정진', 'Jung-Jin Park')
# newly added:  ('허진석', 'Jin-Seok Heo ')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# newly added:  ('장재혁', 'Jae-Hyuk Jang ')
# newly added:  ('김병준', 'Byung-Jun Kim')
# dup skipped:  ('이상현', 'Sang-Hyun Lee')
# dup skipped:  ('신국환', 'Guk-Hwan Shin')
# dup skipped:  ('조규수', 'Gyu-Soo Jo')
# dup skipped:  ('이범호', 'Beom-Ho Lee')
# dup skipped:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('송유석', 'Yu-Seok Song')
# newly added:  ('전하진', 'Ha-Jin Jeon')
# finished code:7, year: 2000
# newly added:  ('방진호', 'Jin-Ho Bang')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# dup skipped:  ('강인권', 'In-Kwon Kang')
# newly added:  ('서창호', 'Chang-Ho Seo')
# dup skipped:  ('윤근주', 'Geun-Ju Yoon')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('지승민', 'Seung-Min Ji')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상군', 'Sang-Kun Lee')
# newly added:  ('워렌', 'Brian Warren')
# newly added:  ('차베스', 'Carlos Chavez')
# newly added:  ('에반스', 'David Evans')
# dup skipped:  ('문용민', 'Yong-Min Moon')
# newly added:  ('박정근', 'Jung-Geun Park')
# dup skipped:  ('김홍집', 'Hong-Jib Kim')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('김영진', 'Yeong-Jin Kim')
# dup skipped:  ('박정진', 'Jung-Jin Park')
# dup skipped:  ('김장백', 'Jang-Baek Kim')
# dup skipped:  ('송지만', 'Ji-Man Song')
# dup skipped:  ('데이비스', 'Gerrod Jay Davis')
# dup skipped:  ('김진삼', 'Jin-Sam Kim')
# newly added:  ('리스', 'Brandon Leese')
# newly added:  ('누네스', 'José Núñez')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('홍우태', 'Woo-Tai Hong')
# newly added:  ('윈스턴', 'Darrin Winston')
# dup skipped:  ('송유석', 'Yu-Seok Song')
# newly added:  ('김백만', 'Baek-Man Kim')
# dup skipped:  ('심재윤', 'Jae-Yoon Sim')
# dup skipped:  ('황우구', 'Woo-Gu Hwang')
# dup skipped:  ('신경현', 'Kyung-Hyun Shin')
# dup skipped:  ('김종석', 'Jong-Seok Kim')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('김재현', 'Jae-Hyeon Kim')
# dup skipped:  ('허진석', 'Jin-Seok Heo ')
# dup skipped:  ('김경원', 'Kyung-Won Kim')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('장재혁', 'Jae-Hyuk Jang ')
# dup skipped:  ('김병준', 'Byung-Jun Kim')
# newly added:  ('이송영', 'Song-Young Lee')
# newly added:  ('고상천', 'Sang-Chun Ko')
# dup skipped:  ('이상현', 'Sang-Hyun Lee')
# dup skipped:  ('신국환', 'Guk-Hwan Shin')
# dup skipped:  ('김정수', 'Jung-Soo Kim')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# newly added:  ('김태균', 'Tae-Gyun Kim')
# newly added:  ('김무성', 'Moo-sung Kim ')
# dup skipped:  ('조규수', 'Gyu-Soo Jo')
# dup skipped:  ('이범호', 'Beom-Ho Lee')
# newly added:  ('조정권', 'Jung-Kwon Cho')
# dup skipped:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('최영필', 'Yeong-Pil Choi')
# newly added:  ('김기동', 'Ki-Dong Kim')
# newly added:  ('최동연', 'Dong-Yeon Choi')
# finished code:7, year: 2001
# newly added:  ('김주', 'Joo Kim')
# dup skipped:  ('임주택', 'Joo-Taek Lim')
# newly added:  ('안영진', 'Young-Jin Ahn')
# newly added:  ('조윤채', 'Yoon-Chae Cho')
# dup skipped:  ('방진호', 'Jin-Ho Bang')
# newly added:  ('김경선', 'Kyung-Seon Kim')
# newly added:  ('서정', 'Jeong Seo')
# newly added:  ('윤경영', 'Kyoung-Young Yoon')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# dup skipped:  ('김준호', 'Jun-Ho Kim')
# dup skipped:  ('허준', 'Jun Heo')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('조효상', 'Hyo-Sang Cho')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# dup skipped:  ('김태균', 'Tae-Gyun Kim')
# newly added:  ('김병근', 'Byung-Keun Kim')
# dup skipped:  ('고상천', 'Sang-Chun Ko')
# dup skipped:  ('김병준', 'Byung-Jun Kim')
# dup skipped:  ('이도형', 'Do-Hyung Lee')
# newly added:  ('안승민', 'Seung-Min Ahn')
# dup skipped:  ('서창호', 'Chang-Ho Seo')
# dup skipped:  ('황우구', 'Woo-Gu Hwang')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('지승민', 'Seung-Min Ji')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('조규수', 'Gyu-Soo Jo')
# dup skipped:  ('파라', 'Jose Para')
# newly added:  ('유혜정', 'Hae-Jung Yoo')
# dup skipped:  ('이동현', 'Dong-Hyun Lee')
# dup skipped:  ('박정근', 'Jung-Geun Park')
# dup skipped:  ('문용민', 'Yong-Min Moon')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('박정진', 'Jung-Jin Park')
# newly added:  ('길태곤', 'Tai-Gon Gil')
# dup skipped:  ('김장백', 'Jang-Baek Kim')
# newly added:  ('신민기', 'Min-Ki Shin')
# dup skipped:  ('데이비스', 'Gerrod Jay Davis')
# dup skipped:  ('송지만', 'Ji-Man Song')
# newly added:  ('연지', 'Eric DeBari Junge')
# dup skipped:  ('김홍집', 'Hong-Jib Kim')
# newly added:  ('디아즈', 'Víctor Díaz')
# dup skipped:  ('신재웅', 'Jae-Woong Shin')
# dup skipped:  ('조현', 'Hyun Cho')
# dup skipped:  ('김백만', 'Baek-Man Kim')
# newly added:  ('션헨', 'Sean Michael Henn')
# newly added:  ('배스', 'Brian Bass')
# dup skipped:  ('이범호', 'Beom-Ho Lee')
# dup skipped:  ('김종석', 'Jong-Seok Kim')
# newly added:  ('김재우', 'Jae-Woo Kim')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# newly added:  ('가르시아', 'Amaury Garcia')
# dup skipped:  ('허진석', 'Jin-Seok Heo ')
# newly added:  ('신주영', 'Joo-Young Shin')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# newly added:  ('신해수', 'Hae-Su Shin')
# dup skipped:  ('채상병', 'Sang-Byung Chae')
# newly added:  ('정희상', 'Hui-Sang Jeong')
# dup skipped:  ('정병희', 'Byeong-Heui Jeong')
# dup skipped:  ('이송영', 'Song-Young Lee')
# newly added:  ('최연오', 'Yeon-Oh Choi')
# newly added:  ('이영기', 'Young-Ki Lee')
# dup skipped:  ('이상현', 'Sang-Hyun Lee')
# dup skipped:  ('신국환', 'Guk-Hwan Shin')
# dup skipped:  ('김정수', 'Jung-Soo Kim')
# dup skipped:  ('오창선', 'Chang-Seon Oh')
# dup skipped:  ('마정길', 'Jung-Gil Ma')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('조현수', 'Hyun-Soo Cho')
# dup skipped:  ('조정권', 'Jung-Kwon Cho')
# dup skipped:  ('장재혁', 'Jae-Hyuk Jang ')
# dup skipped:  ('김무성', 'Moo-sung Kim ')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# newly added:  ('박병우', 'Byeong-u Park')
# newly added:  ('최우석', 'Woo-Suk Choi')
# newly added:  ('피코타', 'Lenin Alberto Picota')
# newly added:  ('장재훈', 'Jae-Hun Jang')
# dup skipped:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('최진호', 'Jin-Ho Choi')
# newly added:  ('임신호', 'Shin--ho Lim')
# dup skipped:  ('최영필', 'Yeong-Pil Choi')
# newly added:  ('박찬호', 'Chan-Ho Park ')
# newly added:  ('김대원', 'Dae-won Kim ')
# newly added:  ('박상규', 'Sang-Gyu Park')
# dup skipped:  ('정성열', 'Sung-Yeol Jung')
# dup skipped:  ('김회권', 'Hoi-Kwon Kim')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# newly added:  ('송혁', 'Hyuk Song')
# dup skipped:  ('양승학', 'Seung-Hak Yang')
# newly added:  ('조성우', 'Seong-u Jo')
# newly added:  ('데폴라', 'Julio Cesar DePaula')
# newly added:  ('송우석', 'Woo-Seok Song')
# newly added:  ('임경훈', 'Kyong-Hoon Lim')
# dup skipped:  ('이상우', 'Sang-Woo Lee')
# dup skipped:  ('명재철', 'Jae-Cheol Myeong')
# finished code:7, year: 2002
# dup skipped:  ('김경선', 'Kyung-Seon Kim')
# dup skipped:  ('안영진', 'Young-Jin Ahn')
# dup skipped:  ('김주', 'Joo Kim')
# dup skipped:  ('데이비스', 'Gerrod Jay Davis')
# dup skipped:  ('서정', 'Jeong Seo')
# newly added:  ('이양기', 'Yang-Gi Lee')
# dup skipped:  ('조규수', 'Gyu-Soo Jo')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho')
# newly added:  ('한상훈', 'Sang-Hun Han')
# dup skipped:  ('김준호', 'Jun-Ho Kim')
# dup skipped:  ('임수민', 'Soo-Min Lim')
# dup skipped:  ('백재호', 'Jae-Ho Baek')
# dup skipped:  ('김수연', 'Su-Yeoun Kim')
# dup skipped:  ('김병근', 'Byung-Keun Kim')
# dup skipped:  ('조현수', 'Hyun-Soo Cho')
# dup skipped:  ('고상천', 'Sang-Chun Ko')
# dup skipped:  ('이도형', 'Do-Hyung Lee')
# newly added:  ('맹진국', 'Jin-Guk Maeng')
# dup skipped:  ('안승민', 'Seung-Min Ahn')
# dup skipped:  ('황우구', 'Woo-Gu Hwang')
# dup skipped:  ('김승권', 'Seong-Kon Kim')
# dup skipped:  ('구대성', 'Das-Sung Koo')
# dup skipped:  ('강석천', 'Seok-Chun Kang')
# dup skipped:  ('이상목', 'Sang-Mok Lee')
# dup skipped:  ('유혜정', 'Hae-Jung Yoo')
# dup skipped:  ('문용민', 'Yong-Min Moon')
# dup skipped:  ('이동현', 'Dong-Hyun Lee')
# dup skipped:  ('송진우', 'Jin-Woo Song')
# dup skipped:  ('심광호', 'Gwang-Ho Sim')
# dup skipped:  ('박정진', 'Jung-Jin Park')
# dup skipped:  ('길태곤', 'Tai-Gon Gil')
# dup skipped:  ('김장백', 'Jang-Baek Kim')
# dup skipped:  ('송지만', 'Ji-Man Song')
# dup skipped:  ('디아즈', 'Víctor Díaz')
# dup skipped:  ('김홍집', 'Hong-Jib Kim')
# dup skipped:  ('연지', 'Eric DeBari Junge')
# dup skipped:  ('조윤채', 'Yoon-Chae Cho')
# dup skipped:  ('김백만', 'Baek-Man Kim')
# dup skipped:  ('배스', 'Brian Bass')
# dup skipped:  ('션헨', 'Sean Michael Henn')
# dup skipped:  ('이범호', 'Beom-Ho Lee')
# dup skipped:  ('임재철', 'Jae-Chul Lim')
# dup skipped:  ('김종석', 'Jong-Seok Kim')
# dup skipped:  ('김재우', 'Jae-Woo Kim')
# dup skipped:  ('이영우', 'Young-Woo Lee')
# dup skipped:  ('장종훈', 'Jong-Hoon Jang')
# dup skipped:  ('신민기', 'Min-Ki Shin')
# dup skipped:  ('허진석', 'Jin-Seok Heo ')
# dup skipped:  ('기론', 'Emiliano Giron')
# dup skipped:  ('안영명', 'Yeong-Myeong Ahn')
# dup skipped:  ('신주영', 'Joo-Young Shin')
# dup skipped:  ('한용덕', 'Yong-Duk Han')
# dup skipped:  ('신해수', 'Hae-Su Shin')
# dup skipped:  ('채상병', 'Sang-Byung Chae')
# dup skipped:  ('정병희', 'Byeong-Heui Jeong')
# dup skipped:  ('정희상', 'Hui-Sang Jeong')
# dup skipped:  ('이송영', 'Song-Young Lee')
# dup skipped:  ('최연오', 'Yeon-Oh Choi')
# dup skipped:  ('윤경영', 'Kyoung-Young Yoon')
# newly added:  ('에스트라다', 'Horacio Estrada')
# newly added:  ('메히아', 'Roberto Antonio Mejía Díaz')
# dup skipped:  ('이영기', 'Young-Ki Lee')
# dup skipped:  ('이상현', 'Sang-Hyun Lee')
# dup skipped:  ('박정근', 'Jung-Geun Park')
# dup skipped:  ('마정길', 'Jung-Gil Ma')
# newly added:  ('윤규진', 'Gyu-Jin Yun')
# dup skipped:  ('지연규', 'Yeun-Gyu Ji')
# dup skipped:  ('김태균', 'Tae-Gyun Kim')
# dup skipped:  ('조정권', 'Jung-Kwon Cho')
# dup skipped:  ('김무성', 'Moo-sung Kim ')
# dup skipped:  ('장재혁', 'Jae-Hyuk Jang ')
# dup skipped:  ('정민철', 'Min-Chul Jung')
# dup skipped:  ('박병우', 'Byeong-u Park')
# dup skipped:  ('최우석', 'Woo-Suk Choi')
# dup skipped:  ('피코타', 'Lenin Alberto Picota')
# dup skipped:  ('장재훈', 'Jae-Hun Jang')
# dup skipped:  ('김해님', 'Hae-Nim Kim')
# dup skipped:  ('최진호', 'Jin-Ho Choi')
# dup skipped:  ('최영필', 'Yeong-Pil Choi')
# dup skipped:  ('임신호', 'Shin--ho Lim')
# dup skipped:  ('박찬호', 'Chan-Ho Park ')
# dup skipped:  ('박상규', 'Sang-Gyu Park')
# dup skipped:  ('정성열', 'Sung-Yeol Jung')
# dup skipped:  ('김회권', 'Hoi-Kwon Kim')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# dup skipped:  ('송혁', 'Hyuk Song')
# dup skipped:  ('양승학', 'Seung-Hak Yang')
# dup skipped:  ('조성우', 'Seong-u Jo')
# ...
# dup skipped:  ('김범준', 'Beom-Jun Kim')
# newly added:  ('김승일', 'Seung-il Kim')
# finished code:7, year: 2020
# dup skipped:  ('조현진', 'Hyun-Jin Cho')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# dup skipped:  ('노태형', 'Tae-Hyung Noh')
# newly added:  ('이준기', 'June-Ki Lee')
# newly added:  ('김규연', 'Kyu-Yeon Kim')
# newly added:  ('안진', 'Jin Ahn')
# dup skipped:  ('조한민', 'Han-Min Jo')
# newly added:  ('문승진', 'Seung-jin Moon')
# dup skipped:  ('윤대경', 'Dae-Kyung Yun')
# dup skipped:  ('이성곤', 'Seong-Kon Lee')
# newly added:  ('안창호', 'Chang-Ho An')
# dup skipped:  ('이도윤', 'Do-Yun Lee')
# dup skipped:  ('노시환', 'Si-Hwan Roh')
# newly added:  ('이종완', 'Jong-Wahn Lee')
# dup skipped:  ('박정현', 'Jung-Hyun Park')
# dup skipped:  ('남지민', 'Ji-Min Nam')
# dup skipped:  ('임준섭', 'Joon-Seop Lim')
# dup skipped:  ('김건', 'Geon Kim')
# dup skipped:  ('최재훈', 'Jae-Hun Choi')
# newly added:  ('페레즈', 'Hernán Alejandro Pérez')
# newly added:  ('김기중', 'Ki-Joong Kim')
# dup skipped:  ('하주석', 'Joo-Seok Ha')
# dup skipped:  ('노수광', 'Soo-Gwang Noh')
# dup skipped:  ('윤호솔', 'Ho-Sol Yoon')
# dup skipped:  ('강상원', 'Sang-Won Kang')
# dup skipped:  ('킹험', 'Nick Kingham')
# newly added:  ('카펜터', 'Ryan Nicholas Carpenter')
# dup skipped:  ('임종찬', 'Jong-Chan Lim')
# dup skipped:  ('김태연', 'Tae-Yeon Kim')
# newly added:  ('힐리', 'Ryon Cristopher Healy')
# dup skipped:  ('허관회', 'Kwan-Hoi Heo')
# dup skipped:  ('이해창', 'Hae-Chang Lee')
# dup skipped:  ('장시환', 'Si-Hwan Jang')
# dup skipped:  ('김기탁', 'Ki-Tak Kim')
# dup skipped:  ('장운호', 'Un-ho Jang')
# dup skipped:  ('신정락', 'Jung-Rak Shin')
# dup skipped:  ('윤산흠', 'San-Heum Yoon')
# dup skipped:  ('김진욱', 'Jin-Wook Kim')
# dup skipped:  ('정진호', 'Jin-Ho Jeong')
# dup skipped:  ('최인호', 'In-Ho Choi')
# dup skipped:  ('장민재', 'Min-Jae Jang')
# dup skipped:  ('김진영', 'Jin-Young Kim')
# dup skipped:  ('문동욱', 'Dong-Wook Moon')
# dup skipped:  ('김민하', 'Min-Ha Kim')
# dup skipped:  ('신지후', 'Jee-Hoo Shin')
# dup skipped:  ('박성웅', 'Sung-Woong Park')
# dup skipped:  ('박상언', 'Sang-Un Park')
# dup skipped:  ('정은원', 'Eun-Won Jung')
# dup skipped:  ('백용환', 'Yong-Hwan Baek')
# dup skipped:  ('정기훈', 'Gi-Hoon Jeong')
# dup skipped:  ('김도현', 'Do-Hyun Kim')
# dup skipped:  ('장웅정', 'Woong-Jung Chang')
# dup skipped:  ('김범수', 'Beom-Soo Kim')
# dup skipped:  ('이승관', 'Seung-Gwan Lee')
# dup skipped:  ('이충호', 'Chung-Ho Lee')
# dup skipped:  ('이성열', 'Sung-Yeol Lee')
# dup skipped:  ('이원석', 'Won-Seok Lee')
# dup skipped:  ('이시원', 'Si-Won Lee')
# dup skipped:  ('김태균', 'Tae-Gyun Kim')
# dup skipped:  ('김민우', 'Min-Woo Kim')
# dup skipped:  ('서균', 'Kyun Seo')
# dup skipped:  ('강재민', 'Jae-Min Kang')
# dup skipped:  ('송윤준', 'Yoon-Joon Song')
# dup skipped:  ('정우람', 'Woo-Ram Jung')
# dup skipped:  ('오동욱', 'Dong-Uk Oh')
# dup skipped:  ('한승주', 'Seung-Joo Han')
# dup skipped:  ('황영국', 'Yeong-Guk Hwang')
# newly added:  ('배동현', 'Dong-Hyun Bae')
# newly added:  ('장규현', 'Kyu-Hyun Jang')
# newly added:  ('장지승', 'Ji-Seung Jang')
# dup skipped:  ('박한결', 'Han-Kyul Park')
# newly added:  ('정민규', 'Min-Kyu Jung')
# dup skipped:  ('권용우', 'Yong-Woo Gwon')
# dup skipped:  ('주현상', 'Hyun-Sang Ju')
# newly added:  ('송호정', 'Ho-Jung Song')
# dup skipped:  ('유로결', 'Ro-Kyeol Yoo')
# dup skipped:  ('김지수', 'Ji-Soo Kim')
# dup skipped:  ('최이경', 'Yee-kyung Choi')
# dup skipped:  ('김승일', 'Seung-il Kim')
# dup skipped:  ('박준범', 'Jun-Beom Park')
# newly added:  ('조은', 'Eun Cho')
# dup skipped:  ('정인욱', 'In-Wook Jung')
# dup skipped:  ('김태욱', 'Tae-Wook Kim')
# finished code:7, year: 2021
# newly added:  ('문동주', 'Dong-Ju Moon')
# newly added:  ('민승기', 'Seung-Gi Min')
# dup skipped:  ('김민기', 'Min-Gi Kim')
# newly added:  ('전승우', 'Seung-woo Jeon')
# dup skipped:  ('최현준', 'Hyun-Jun Choi')
# dup skipped:  ('황영국', 'Yeong-Guk Hwang')
# dup skipped:  ('송호정', 'Ho-Jung Song')
# newly added:  ('이상혁', 'Sang-Hyeok Lee')
# dup skipped:  ('윤대경', 'Dae-Kyung Yun')
# dup skipped:  ('김건', 'Geon Kim')
# newly added:  ('김준석', 'Jun-Seok Kim')
# dup skipped:  ('이도윤', 'Do-Yun Lee')
# dup skipped:  ('노시환', 'Si-Hwan Roh')
# dup skipped:  ('박정현', 'Jung-Hyun Park')
# dup skipped:  ('이성곤', 'Seong-Kon Lee')
# dup skipped:  ('남지민', 'Ji-Min Nam')
# newly added:  ('터크먼', 'Mike Tauchman')
# dup skipped:  ('최재훈', 'Jae-Hun Choi')
# dup skipped:  ('강상원', 'Sang-Won Kang')
# dup skipped:  ('김기중', 'Ki-Joong Kim')
# dup skipped:  ('하주석', 'Joo-Seok Ha')
# dup skipped:  ('노수광', 'Soo-Gwang Noh')
# dup skipped:  ('김재영', 'Jae-Young Kim')
# dup skipped:  ('킹험', 'Nick Kingham')
# newly added:  ('페냐', 'Félix Ricardo Peña')
# newly added:  ('라미레즈', 'Yefry Ramírez Alcala')
# dup skipped:  ('카펜터', 'Ryan Nicholas Carpenter')
# dup skipped:  ('임종찬', 'Jong-Chan Lim')
# dup skipped:  ('원혁재', 'Hyuk-Jae Won')
# dup skipped:  ('김태연', 'Tae-Yeon Kim')
# dup skipped:  ('허관회', 'Kwan-Hoi Heo')
# dup skipped:  ('이해창', 'Hae-Chang Lee')
# dup skipped:  ('윤호솔', 'Ho-Sol Yoon')
# dup skipped:  ('장시환', 'Si-Hwan Jang')
# dup skipped:  ('김기탁', 'Ki-Tak Kim')
# dup skipped:  ('장운호', 'Un-ho Jang')
# dup skipped:  ('박준영', 'Jun-Yeong Park')
# dup skipped:  ('윤산흠', 'San-Heum Yoon')
# dup skipped:  ('유로결', 'Ro-Kyeol Yoo')
# dup skipped:  ('류희운', 'Hui-Woon Ryu')
# dup skipped:  ('장민재', 'Min-Jae Jang')
# dup skipped:  ('김인환', 'In-Hwan Kim')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# dup skipped:  ('신정락', 'Jung-Rak Shin')
# dup skipped:  ('신지후', 'Jee-Hoo Shin')
# dup skipped:  ('정민규', 'Min-Kyu Jung')
# dup skipped:  ('박상언', 'Sang-Un Park')
# dup skipped:  ('정은원', 'Eun-Won Jung')
# dup skipped:  ('백용환', 'Yong-Hwan Baek')
# dup skipped:  ('이진영', 'Jin-Young Lee')
# dup skipped:  ('장웅정', 'Woong-Jung Chang')
# dup skipped:  ('조은', 'Eun Cho')
# dup skipped:  ('김범수', 'Beom-Soo Kim')
# dup skipped:  ('이승관', 'Seung-Gwan Lee')
# dup skipped:  ('이충호', 'Chung-Ho Lee')
# dup skipped:  ('이원석', 'Won-Seok Lee')
# dup skipped:  ('장진혁', 'Jin-Hyuk Jang')
# dup skipped:  ('김민우', 'Min-Woo Kim')
# dup skipped:  ('임준섭', 'Joon-Seop Lim')
# dup skipped:  ('강재민', 'Jae-Min Kang')
# dup skipped:  ('송윤준', 'Yoon-Joon Song')
# dup skipped:  ('정우람', 'Woo-Ram Jung')
# dup skipped:  ('박상원', 'Sang-Won Park')
# dup skipped:  ('한승주', 'Seung-Joo Han')
# dup skipped:  ('김규연', 'Kyu-Yeon Kim')
# dup skipped:  ('이민우', 'Min-Woo Lee')
# dup skipped:  ('박윤철', 'Yun-Chul Park')
# dup skipped:  ('장규현', 'Kyu-Hyun Jang')
# dup skipped:  ('장지승', 'Ji-Seung Jang')
# newly added:  ('허인서', 'In-Seo Heo')
# newly added:  ('유민', 'Min Yoo')
# newly added:  ('유상빈', 'Hsiang-Pin Liu')
# dup skipped:  ('주현상', 'Hyun-Sang Ju')
# dup skipped:  ('정이황', 'Yi-Hwang Jung')
# dup skipped:  ('변우혁', 'Woo-Hyuk Byun')
# newly added:  ('권광민', 'Kwang-Min Kwon')
# dup skipped:  ('최이경', 'Yee-kyung Choi')
# newly added:  ('이재민', 'Jae-Min Lee')
# dup skipped:  ('이준기', 'June-Ki Lee')
# dup skipped:  ('안창호', 'Chang-Ho An')
# dup skipped:  ('이종완', 'Jong-Wahn Lee')
# dup skipped:  ('이성원', 'Seong-Won Lee')
# newly added:  ('양경모', 'Gyeong-Mo Yang')
# dup skipped:  ('오세훈', 'Se-Hun OH')
# newly added:  ('김겸재', 'Kyeom-jae Kim')
# newly added:  ('이성민', 'Sung-Min Lee')
# dup skipped:  ('신현수', 'Hyun-Soo Shin')
# newly added:  ('노석진', 'Seok-jin Noh')
# dup skipped:  ('문승진', 'Seung-jin Moon')
# dup skipped:  ('조현진', 'Hyun-Jin Cho')
# dup skipped:  ('신제왕', 'Je-Wang Shin')
# finished code:7, year: 2022
# dup skipped:  ('문동주', 'Dong-Ju Moon')
# dup skipped:  ('민승기', 'Seung-Gi Min')
# dup skipped:  ('양경모', 'Gyeong-Mo Yang')
# dup skipped:  ('김민기', 'Min-Gi Kim')
# newly added:  ('윌리엄스', 'Nick Williams')
# dup skipped:  ('김겸재', 'Kyeom-jae Kim')
# dup skipped:  ('이승관', 'Seung-Gwan Lee')
# dup skipped:  ('윤대경', 'Dae-Kyung Yun')
# dup skipped:  ('노석진', 'Seok-jin Noh')
# dup skipped:  ('오선진', 'Sun-Jin Oh')
# dup skipped:  ('이도윤', 'Do-Yun Lee')
# dup skipped:  ('노시환', 'Si-Hwan Roh')
# dup skipped:  ('박정현', 'Jung-Hyun Park')
# dup skipped:  ('송윤준', 'Yoon-Joon Song')
# dup skipped:  ('남지민', 'Ji-Min Nam')
# dup skipped:  ('이상혁', 'Sang-Hyeok Lee')
# newly added:  ('오그레디', "Brian O'Grady")
# dup skipped:  ('최재훈', 'Jae-Hun Choi')
# dup skipped:  ('이명기', 'Myung-Ki Lee')
# dup skipped:  ('김기중', 'Ki-Joong Kim')
# dup skipped:  ('하주석', 'Joo-Seok Ha')
# dup skipped:  ('노수광', 'Soo-Gwang Noh')
# dup skipped:  ('류희운', 'Hui-Woon Ryu')
# dup skipped:  ('김재영', 'Jae-Young Kim')
# dup skipped:  ('페냐', 'Félix Ricardo Peña')
# dup skipped:  ('채은성', 'Eun-Seong Chae')
# dup skipped:  ('원혁재', 'Hyuk-Jae Won')
# dup skipped:  ('김태연', 'Tae-Yeon Kim')
# dup skipped:  ('한승혁', 'Seung-Hyeok Han')
# dup skipped:  ('이민우', 'Min-Woo Lee')
# dup skipped:  ('장시환', 'Si-Hwan Jang')
# dup skipped:  ('박준영', 'Jun-Yeong Park')
# dup skipped:  ('장운호', 'Un-ho Jang')
# dup skipped:  ('박윤철', 'Yun-Chul Park')
# dup skipped:  ('윤산흠', 'San-Heum Yoon')
# dup skipped:  ('유로결', 'Ro-Kyeol Yoo')
# newly added:  ('스미스', 'Burch Taylor Smith')
# newly added:  ('산체스', 'Ricardo Jose Sánchez')
# dup skipped:  ('장민재', 'Min-Jae Jang')
# dup skipped:  ('김인환', 'In-Hwan Kim')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# dup skipped:  ('이재민', 'Jae-Min Lee')
# dup skipped:  ('신지후', 'Jee-Hoo Shin')
# dup skipped:  ('정민규', 'Min-Kyu Jung')
# dup skipped:  ('최인호', 'In-Ho Choi')
# dup skipped:  ('박상언', 'Sang-Un Park')
# dup skipped:  ('정은원', 'Eun-Won Jung')
# dup skipped:  ('이성곤', 'Seong-Kon Lee')
# dup skipped:  ('이진영', 'Jin-Young Lee')
# dup skipped:  ('이태양', 'Tae-Yang Lee')
# dup skipped:  ('김범수', 'Beom-Soo Kim')
# dup skipped:  ('허관회', 'Kwan-Hoi Heo')
# dup skipped:  ('이충호', 'Chung-Ho Lee')
# dup skipped:  ('이원석', 'Won-Seok Lee')
# dup skipped:  ('장진혁', 'Jin-Hyuk Jang')
# dup skipped:  ('김민우', 'Min-Woo Kim')
# newly added:  ('김서현', 'Seo-Hyeon Kim')
# dup skipped:  ('강재민', 'Jae-Min Kang')
# dup skipped:  ('권광민', 'Kwang-Min Kwon')
# dup skipped:  ('정우람', 'Woo-Ram Jung')
# dup skipped:  ('박상원', 'Sang-Won Park')
# dup skipped:  ('한승주', 'Seung-Joo Han')
# dup skipped:  ('김규연', 'Kyu-Yeon Kim')
# dup skipped:  ('류원석', 'Won-Suk Ryu')
# dup skipped:  ('김현우', 'Hyun-woo Kim ')
# dup skipped:  ('장지승', 'Ji-Seung Jang')
# dup skipped:  ('허인서', 'In-Seo Heo')
# newly added:  ('문현빈', 'Hyun-Bin Moon')
# dup skipped:  ('유상빈', 'Hsiang-Pin Liu')
# dup skipped:  ('주현상', 'Hyun-Sang Ju')
# dup skipped:  ('정이황', 'Yi-Hwang Jung')
# dup skipped:  ('김범준', 'Beom-Jun Kim')
# dup skipped:  ('장지수', 'Ji-Soo Jang')
# dup skipped:  ('오세훈', 'Se-Hun OH')
# newly added:  ('한경빈', 'Kyung-Bin Han')
# newly added:  ('이민준', 'Min-Jun Lee')
# dup skipped:  ('이재용', 'Jae-Yong Lee')
# dup skipped:  ('김건', 'Geon Kim')
# dup skipped:  ('이성원', 'Seong-Won Lee')
# newly added:  ('김관우', 'Kwan-Woo Kim')
# newly added:  ('김해찬', 'Hae-Chan Kim')
# newly added:  ('한서구', 'Seo-Gu Han')
# newly added:  ('송성훈', 'Seong-Hun Song')
# dup skipped:  ('최원준', 'Won-Jun Choi')
# newly added:  ('박재규', 'Jae-Gyu Park')
# newly added:  ('천보웅', 'Bo-Woong Cheon')
# newly added:  ('김예준', 'Ye-Jun Kim')
# newly added:  ('이석제', 'Seok-Je Lee')
# newly added:  ('고영재', 'Young-Jae Gp')
# newly added:  ('성지훈', 'Ji-Hoon Sung')
# newly added:  ('이정재', 'Jung-Jae Lee')
# newly added:  ('김석훈', 'Seok-Hoon Kim')
# newly added:  ('신우재', 'Shin Wojae')
# dup skipped:  ('안진', 'Jin Ahn')
# finished code:7, year: 2023
# dup skipped:  ('문동주', 'Dong-Ju Moon')
# newly added:  ('서정훈', 'Jung-hoon Seo')
# newly added:  ('권동욱', 'Dong-wook Kwon')
# dup skipped:  ('김민기', 'Min-Gi Kim')
# dup skipped:  ('안치홍', 'Chi-Hong An')
# newly added:  ('김선동', 'Seon-dong Kim')
# dup skipped:  ('윤대경', 'Dae-Kyung Yun')
# dup skipped:  ('한경빈', 'Kyung-Bin Han')
# dup skipped:  ('이도윤', 'Do-Yun Lee')
# dup skipped:  ('노시환', 'Si-Hwan Roh')
# dup skipped:  ('박정현', 'Jung-Hyun Park')
# dup skipped:  ('김강민', 'Kang-Min Kim')
# dup skipped:  ('허관회', 'Kwan-Hoi Heo')
# dup skipped:  ('남지민', 'Ji-Min Nam')
# dup skipped:  ('이재용', 'Jae-Yong Lee')
# dup skipped:  ('최재훈', 'Jae-Hun Choi')
# dup skipped:  ('이명기', 'Myung-Ki Lee')
# dup skipped:  ('김기중', 'Ki-Joong Kim')
# dup skipped:  ('하주석', 'Joo-Seok Ha')
# dup skipped:  ('권광민', 'Kwang-Min Kwon')
# dup skipped:  ('이상규', 'Sang-Kyu Lee')
# dup skipped:  ('이충호', 'Chung-Ho Lee')
# newly added:  ('바리아', 'Jaime Barria')
# dup skipped:  ('페냐', 'Félix Ricardo Peña')
# dup skipped:  ('채은성', 'Eun-Seong Chae')
# dup skipped:  ('임종찬', 'Jong-Chan Lim')
# dup skipped:  ('김태연', 'Tae-Yeon Kim')
# dup skipped:  ('한승혁', 'Seung-Hyeok Han')
# dup skipped:  ('이민우', 'Min-Woo Lee')
# dup skipped:  ('장시환', 'Si-Hwan Jang')
# newly added:  ('황준서', 'Jun-seo Hwang')
# newly added:  ('페라자', 'Yonathan Jesús Perlaza')
# dup skipped:  ('정이황', 'Yi-Hwang Jung')
# dup skipped:  ('이재원', 'Jae-Won Lee')
# dup skipped:  ('윤산흠', 'San-Heum Yoon')
# dup skipped:  ('유로결', 'Ro-Kyeol Yoo')
# dup skipped:  ('산체스', 'Ricardo Jose Sánchez')
# dup skipped:  ('장민재', 'Min-Jae Jang')
# dup skipped:  ('김인환', 'In-Hwan Kim')
# dup skipped:  ('김종수', 'Jong-Soo Kim')
# dup skipped:  ('배민서', 'Min-Seo Bae')
# dup skipped:  ('장지수', 'Ji-Soo Jang')
# dup skipped:  ('최인호', 'In-Ho Choi')
# dup skipped:  ('박상언', 'Sang-Un Park')
# dup skipped:  ('정은원', 'Eun-Won Jung')
# dup skipped:  ('이진영', 'Jin-Young Lee')
# dup skipped:  ('이태양', 'Tae-Yang Lee')
# dup skipped:  ('김범수', 'Beom-Soo Kim')
# dup skipped:  ('조한민', 'Han-Min Jo')
# dup skipped:  ('이민준', 'Min-Jun Lee')
# dup skipped:  ('이원석', 'Won-Seok Lee')
# dup skipped:  ('장진혁', 'Jin-Hyuk Jang')
# dup skipped:  ('김민우', 'Min-Woo Kim')
# dup skipped:  ('김서현', 'Seo-Hyeon Kim')
# newly added:  ('와이스', 'Ryan Weiss')
# dup skipped:  ('김건', 'Geon Kim')
# dup skipped:  ('정우람', 'Woo-Ram Jung')
# dup skipped:  ('박상원', 'Sang-Won Park')
# dup skipped:  ('한승주', 'Seung-Joo Han')
# dup skipped:  ('김규연', 'Kyu-Yeon Kim')
# dup skipped:  ('배동현', 'Dong-Hyun Bae')
# newly added:  ('김도빈', 'Do-bin Kim')
# dup skipped:  ('문현빈', 'Hyun-Bin Moon')
# dup skipped:  ('이상혁', 'Sang-Hyeok Lee')
# dup skipped:  ('주현상', 'Hyun-Sang Ju')
# dup skipped:  ('오세훈', 'Se-Hun OH')
# newly added:  ('조동욱', 'Dong-wook Jo')
# dup skipped:  ('김승일', 'Seung-il Kim')
# dup skipped:  ('김범준', 'Beom-Jun Kim')
# dup skipped:  ('허인서', 'In-Seo Heo')
# newly added:  ('황영묵', 'Young-mook Hwang')
# dup skipped:  ('장규현', 'Kyu-Hyun Jang')
# dup skipped:  ('성지훈', 'Ji-Hoon Sung')
# dup skipped:  ('류현진', 'Hyun-Jin Ryu')
# dup skipped:  ('문승진', 'Seung-jin Moon')
# dup skipped:  ('송호정', 'Ho-Jung Song')
# dup skipped:  ('조은', 'Eun Cho')
# dup skipped:  ('양경모', 'Gyeong-Mo Yang')
# dup skipped:  ('유민', 'Min Yoo')
# newly added:  ('이기창', 'Gi-chang Lee')
# newly added:  ('최준서', 'Jun-seo Choi')
# newly added:  ('이승현', 'Seung-hyeon Lee')
# newly added:  ('원종혁', 'Jong-hyeok Won')
# newly added:  ('권현', 'Hyeon Kwon')
# newly added:  ('승지환', 'Ji-hwan Seung')
# dup skipped:  ('김진욱', 'Jin-Wook Kim')
# dup skipped:  ('이성민', 'Sung-Min Lee')
# dup skipped:  ('신우재', 'Shin Wojae')
# newly added:  ('정안석', 'An-seok Jeong')
# finished code:7, year: 2024
# already done, skip over code:12, year: 2013
# already done, skip over code:12, year: 2014
# already done, skip over code:12, year: 2015
# already done, skip over code:12, year: 2016
# already done, skip over code:12, year: 2017
# already done, skip over code:12, year: 2018
# already done, skip over code:12, year: 2019
# already done, skip over code:12, year: 2020
# already done, skip over code:12, year: 2021
# already done, skip over code:12, year: 2022
# already done, skip over code:12, year: 2023
# already done, skip over code:12, year: 2024
# already done, skip over code:13, year: 2015
# already done, skip over code:13, year: 2016
# already done, skip over code:13, year: 2017
# already done, skip over code:13, year: 2018
# already done, skip over code:13, year: 2019
# already done, skip over code:13, year: 2020
# already done, skip over code:13, year: 2021
# already done, skip over code:13, year: 2022
# already done, skip over code:13, year: 2023
# already done, skip over code:13, year: 2024
# already done, skip over code:11, year: 2008
# already done, skip over code:11, year: 2009
# already done, skip over code:11, year: 2010
# already done, skip over code:11, year: 2011
# already done, skip over code:11, year: 2012
# already done, skip over code:11, year: 2013
# already done, skip over code:11, year: 2014
# already done, skip over code:11, year: 2015
# already done, skip over code:11, year: 2016
# already done, skip over code:11, year: 2017
# already done, skip over code:11, year: 2018
# already done, skip over code:11, year: 2019
# already done, skip over code:11, year: 2020
# already done, skip over code:11, year: 2021
# already done, skip over code:11, year: 2022
# already done, skip over code:11, year: 2023
# already done, skip over code:11, year: 2024
# already done, skip over code:8, year: 1991
# already done, skip over code:8, year: 1992
# already done, skip over code:8, year: 1993
# already done, skip over code:8, year: 1994
# already done, skip over code:8, year: 1995
# already done, skip over code:8, year: 1996
# already done, skip over code:8, year: 1997
# already done, skip over code:8, year: 1998
# already done, skip over code:8, year: 1999
