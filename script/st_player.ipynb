# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd
import csv
import os
import re
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
from helper.url_parser import get_ct_code_and_year, team_url_to_back_number_url

# %%
session = Session(1000000) # doesn't really matter for statiz

# %%
initial_url = "https://statiz.sporki.com/team/" # starting point
front_url = "https://statiz.sporki.com" # front part of URL in which hrefs will be concatenated on.

# %% [markdown]
# ## Dup Check Setup

# %%
# initial header row setup
file_path = '../data/st_player.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name_kor", "name_eng", "date_of_birth", "url"]
        writer.writerow(header)

# %%
# initial header row setup 2
file_path = '../data/st_finished_team_year.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file2:
        writer2 = csv.writer(file2)
        header = ["code", "year"]
        writer2.writerow(header)

# %%
# to filter duplicate
# both removed the header row
added_team_and_year = set([tuple(row) for row in csv.reader(open('../data/st_finished_team_year.csv', 'r'))][1:])
added_player = set([tuple(row) for row in csv.reader(open('../data/st_player.csv', 'r'))][1:])

# %%
# print(added_team_and_year)
# print(len(added_team_and_year))
# print(len(added_player))

# %% [markdown]
# ## Main Code

# %%
teams_data = session.fetch(initial_url).content.decode("utf-8") # page that contains all teams' links
teams_html = BSoup(teams_data, "lxml")
teams = teams_html.find(class_="team_list").find_all(class_="select_con")

# %%
for team in teams:
    
    years = team.find_all("a")

    for year in years:
        
        current_ct_code, current_year = get_ct_code_and_year(year['href'])
        # print(current_ct_code, current_year)
        # skip over the fully processed year with the given team.
        if (str(current_ct_code), str(current_year)) in added_team_and_year:
            print(f"already done, skip over code:{current_ct_code}, year: {current_year}")
            continue
        team_url = team_url_to_back_number_url(year['href'])
        team_data = session.fetch(team_url).content.decode("utf-8")
        team_html = BSoup(team_data, "lxml")
        players = team_html.find_all(class_="item away")[2:]


        with open("../data/st_player.csv", 'a', newline='') as players_info:
                
            writer = csv.writer(players_info)

            for player in players:
                player_url = front_url + player.find("a")['href']
                player_data = session.fetch(player_url).content.decode("utf-8")
                player_html = BSoup(player_data, "lxml")

                # segment that contains Korean and English name of the player.
                player_name = player_html.find(class_="name")
                # sometimes there is a blank page that doesn't contain any info about the player.
                if not player_name:
                    continue
                player_name = player_name.text.strip()
                name_kor = player_name.split('(')[0].strip()
                name_eng = player_name.split('(')[1][:-1]

                # segment that contains the date of birth of the player.
                dob = player_html.find(class_="man_info").find("li").text
                dob = re.findall(r'\d+', dob)
                dob = "-".join(dob)
                
                player_row = (name_kor, name_eng, dob, player_url)
    
                if player_row not in added_player:
                    added_player.add(player_row)
                    writer.writerow(player_row)
                    print("newly added: ", player_row)
                else:
                    print("dup skipped: ", player_row)

            print(f"finished code:{current_ct_code}, year: {current_year}")

        with open('../data/st_finished_team_year.csv', 'a', newline='') as done_team_year:
            writer2 = csv.writer(done_team_year)
            writer2.writerow((current_ct_code, current_year))
            added_team_and_year.add(((str(current_ct_code), str(current_year))))
# Out:
# already done, skip over code:2, year: 1982
# already done, skip over code:2, year: 1983
# already done, skip over code:2, year: 1984
# already done, skip over code:2, year: 1985
# already done, skip over code:2, year: 1986
# already done, skip over code:2, year: 1987
# already done, skip over code:2, year: 1988
# already done, skip over code:2, year: 1989
# already done, skip over code:2, year: 1990
# already done, skip over code:2, year: 1991
# already done, skip over code:2, year: 1992
# already done, skip over code:2, year: 1993
# already done, skip over code:2, year: 1994
# already done, skip over code:2, year: 1995
# already done, skip over code:2, year: 1996
# already done, skip over code:2, year: 1997
# already done, skip over code:2, year: 1998
# already done, skip over code:2, year: 1999
# already done, skip over code:2, year: 2000
# already done, skip over code:2, year: 2001
# already done, skip over code:2, year: 2002
# already done, skip over code:2, year: 2003
# already done, skip over code:2, year: 2004
# already done, skip over code:2, year: 2005
# already done, skip over code:2, year: 2006
# already done, skip over code:2, year: 2007
# already done, skip over code:2, year: 2008
# already done, skip over code:2, year: 2009
# already done, skip over code:2, year: 2010
# already done, skip over code:2, year: 2011
# already done, skip over code:2, year: 2012
# already done, skip over code:2, year: 2013
# already done, skip over code:2, year: 2014
# already done, skip over code:2, year: 2015
# already done, skip over code:2, year: 2016
# already done, skip over code:2, year: 2017
# already done, skip over code:2, year: 2018
# already done, skip over code:2, year: 2019
# already done, skip over code:2, year: 2020
# already done, skip over code:2, year: 2021
# already done, skip over code:2, year: 2022
# already done, skip over code:2, year: 2023
# already done, skip over code:2, year: 2024
# already done, skip over code:1, year: 1982
# already done, skip over code:1, year: 1983
# already done, skip over code:1, year: 1984
# already done, skip over code:1, year: 1985
# already done, skip over code:1, year: 1986
# already done, skip over code:1, year: 1987
# already done, skip over code:1, year: 1988
# already done, skip over code:1, year: 1989
# already done, skip over code:1, year: 1990
# already done, skip over code:1, year: 1991
# already done, skip over code:1, year: 1992
# already done, skip over code:1, year: 1993
# already done, skip over code:1, year: 1994
# already done, skip over code:1, year: 1995
# already done, skip over code:1, year: 1996
# already done, skip over code:1, year: 1997
# already done, skip over code:1, year: 1998
# already done, skip over code:1, year: 1999
# already done, skip over code:1, year: 2000
# already done, skip over code:1, year: 2001
# already done, skip over code:1, year: 2002
# already done, skip over code:1, year: 2003
# already done, skip over code:1, year: 2004
# already done, skip over code:1, year: 2005
# already done, skip over code:1, year: 2006
# already done, skip over code:1, year: 2007
# already done, skip over code:1, year: 2008
# already done, skip over code:1, year: 2009
# already done, skip over code:1, year: 2010
# already done, skip over code:1, year: 2011
# already done, skip over code:1, year: 2012
# already done, skip over code:1, year: 2013
# already done, skip over code:1, year: 2014
# already done, skip over code:1, year: 2015
# already done, skip over code:1, year: 2016
# already done, skip over code:1, year: 2017
# already done, skip over code:1, year: 2018
# already done, skip over code:1, year: 2019
# already done, skip over code:1, year: 2020
# already done, skip over code:1, year: 2021
# already done, skip over code:1, year: 2022
# already done, skip over code:1, year: 2023
# already done, skip over code:1, year: 2024
# already done, skip over code:6, year: 1982
# already done, skip over code:6, year: 1983
# already done, skip over code:6, year: 1984
# already done, skip over code:6, year: 1985
# already done, skip over code:6, year: 1986
# already done, skip over code:6, year: 1987
# already done, skip over code:6, year: 1988
# already done, skip over code:6, year: 1989
# already done, skip over code:6, year: 1990
# already done, skip over code:6, year: 1991
# already done, skip over code:6, year: 1992
# already done, skip over code:6, year: 1993
# already done, skip over code:6, year: 1994
# already done, skip over code:6, year: 1995
# already done, skip over code:6, year: 1996
# already done, skip over code:6, year: 1997
# already done, skip over code:6, year: 1998
# already done, skip over code:6, year: 1999
# already done, skip over code:6, year: 2000
# already done, skip over code:6, year: 2001
# already done, skip over code:6, year: 2002
# already done, skip over code:6, year: 2003
# already done, skip over code:6, year: 2004
# already done, skip over code:6, year: 2005
# already done, skip over code:6, year: 2006
# already done, skip over code:6, year: 2007
# already done, skip over code:6, year: 2008
# already done, skip over code:6, year: 2009
# already done, skip over code:6, year: 2010
# already done, skip over code:6, year: 2011
# already done, skip over code:6, year: 2012
# already done, skip over code:6, year: 2013
# dup skipped:  ('안규영', 'Gyu-Young An', '1988-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10729')
# newly added:  ('정기훈', 'Gi-Hoon Jeong', '1995-02-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12985')
# dup skipped:  ('이재우', 'Jae-Woo Lee', '1980-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10219')
# dup skipped:  ('김동길', 'Dong-Gil Kim', '1987-03-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10688')
# newly added:  ('칸투', 'Jorge Luís Cantú Guzmán', '1982-01-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11201')
# newly added:  ('문진제', 'Jin-Je Moon', '1991-08-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11209')
# dup skipped:  ('최영진', 'Yeong-Jin Choi', '1988-05-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10934')
# newly added:  ('양종민', 'Jong-Min Yang', '1990-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10248')
# dup skipped:  ('최주환', 'Joo-Hwan Choi', '1988-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10182')
# dup skipped:  ('김강', 'Kang Kim', '1988-10-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10547')
# dup skipped:  ('오성민', 'Sung-Min Oh', '1985-11-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10709')
# dup skipped:  ('원용묵', 'Yong-Muk Won', '1986-06-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10212')
# dup skipped:  ('최재훈', 'Jae-Hun Choi', '1989-08-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10170')
# dup skipped:  ('허경민', 'Kyeong-Min Heo', '1990-08-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10184')
# dup skipped:  ('고영민', 'Yeong-Min Ko', '1984-02-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10171')
# dup skipped:  ('천상웅', 'Sang-Ung Cheon', '1991-05-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10735')
# dup skipped:  ('오현택', 'Hyun-Taek Oh', '1985-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10210')
# dup skipped:  ('이원석', 'Won-Seok Lee', '1986-10-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10180')
# dup skipped:  ('오재원', 'Jae-Won Oh', '1985-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10178')
# dup skipped:  ('김동주', 'Dong-Joo Kim', '1976-02-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10173')
# dup skipped:  ('양현', 'Hyeon Yang', '1992-08-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10730')
# newly added:  ('마야', 'Yunieski Maya', '1981-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11293')
# dup skipped:  ('김강률', 'Kang-Ryul Kim', '1988-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10690')
# dup skipped:  ('홍성흔', 'Seong-Heun Hong', '1977-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10256')
# dup skipped:  ('정대현', 'Dae-Hyeon Jeong', '1991-07-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10224')
# dup skipped:  ('오장훈', 'Jang-Hun Oh', '1984-05-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10250')
# dup skipped:  ('양의지', 'Eui-Ji Yang', '1987-06-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10165')
# dup skipped:  ('니코스키', 'Christopher John Nitkowski', '1973-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10204')
# dup skipped:  ('왓슨', 'Matthew Kyle Watson', '1978-09-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10190')
# dup skipped:  ('김응민', 'Eung-Min Kim', '1991-10-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10890')
# dup skipped:  ('성영훈', 'Yeong-Hun Seong', '1990-06-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10208')
# dup skipped:  ('김명제', 'Myeong-Jae Kim', '1987-01-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10197')
# dup skipped:  ('이석만', 'Seok-Man Lee', '1980-05-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10215')
# dup skipped:  ('김명성', 'Myeong-Seong Kim', '1988-04-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10680')
# dup skipped:  ('유희관', 'Hee-Gwan Yoo', '1986-06-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10213')
# dup skipped:  ('핸킨스', 'Derek James Hankins', '1983-07-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11181')
# newly added:  ('볼스테드', 'Christopher Kenneth Volstad', '1986-09-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11202')
# dup skipped:  ('프록터', 'Scott Christopher Proctor', '1977-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10919')
# dup skipped:  ('세데뇨', 'Juan Cedeño', '1983-08-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10209')
# dup skipped:  ('정수빈', 'Soo-Bin Jeong', '1990-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10195')
# dup skipped:  ('김재환', 'Jae-Hwan Kim', '1988-09-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10643')
# dup skipped:  ('강동연', 'Dong-Yeon Kang', '1992-12-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10883')
# dup skipped:  ('진야곱', 'Ya-Gob Jin', '1989-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10229')
# dup skipped:  ('조승수', 'Seung-Soo Jo', '1990-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10227')
# dup skipped:  ('오재일', 'Jae-Il Oh', '1986-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10400')
# newly added:  ('허준혁', 'Jun-Hyeok Huh', '1990-09-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10305')
# dup skipped:  ('노경은', 'Kyeong-Eun Noh', '1984-03-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10203')
# dup skipped:  ('윤요한', 'Yo-han Yoon', '1989-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10214')
# newly added:  ('장민석', 'Min-Seok Jang', '1982-05-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10416')
# dup skipped:  ('니퍼트', 'Dustin Nippert', '1981-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10641')
# dup skipped:  ('정재훈', 'Jae-Hoon Jung', '1980-01-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10225')
# dup skipped:  ('윤명준', 'Myeong-Jun Yoon', '1989-06-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10885')
# dup skipped:  ('조규수', 'Gyu-Soo Jo', '1981-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10226')
# dup skipped:  ('최형록', 'Hyeong-rok Choi', '1989-08-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11208')
# dup skipped:  ('이용찬', 'Yong-Chan Lee', '1989-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10217')
# dup skipped:  ('이정호', 'Jeong-Ho Lee', '1992-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10731')
# dup skipped:  ('홍상삼', 'Sang-Sam Hong', '1990-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10230')
# dup skipped:  ('이현승', 'Hyun-Seung Lee', '1983-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10221')
# dup skipped:  ('민병헌', 'Byeong-Heon Min', '1987-03-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10188')
# dup skipped:  ('김현수', 'Hyun-Soo Kim', '1988-01-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10187')
# dup skipped:  ('임태훈', 'Tae-Hun Lim', '1988-09-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10222')
# dup skipped:  ('김재호', 'Jae-Ho Kim', '1985-03-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10174')
# newly added:  ('김진형', 'Jin-Hyeong Kim', '1990-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10186')
# dup skipped:  ('김준호', 'Jun-Ho Kim ', '1991-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10185')
# dup skipped:  ('장우람', 'Woo-Ram Jang', '1988-09-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10889')
# dup skipped:  ('한주성', 'Joo-Seong Han', '1995-02-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11203')
# dup skipped:  ('이현호', 'Hyeon-Ho Lee', '1992-07-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10677')
# dup skipped:  ('배상현', 'Sang-Hyun Bae', '1990-10-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10176')
# dup skipped:  ('박건우', 'Geon-Woo Park', '1990-09-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10189')
# dup skipped:  ('이승학', 'Seung-Hak Lee', '1979-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10216')
# dup skipped:  ('최현진', 'Hyun-Jin Choi', '1992-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10733')
# dup skipped:  ('김인태', 'In-Tae Kim', '1994-07-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11098')
# dup skipped:  ('장민익', 'Min-Ik Jang', '1991-02-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10223')
# newly added:  ('최병욱', 'Byeong-Wook Choi', '1989-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11204')
# dup skipped:  ('김경호', 'Gyeong-Ho Kim', '1995-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11207')
# dup skipped:  ('이우성', 'Woo-Sung Lee', '1994-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11099')
# dup skipped:  ('함덕주', 'Deok-Ju Ham', '1995-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11094')
# dup skipped:  ('박종섭', 'Jong-Seop Park', '1983-04-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10175')
# dup skipped:  ('천영웅', 'Young-Ung Cheon', '1994-03-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11096')
# dup skipped:  ('변시원', 'Si-Won Byun', '1993-04-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10882')
# newly added:  ('김수완', 'Soo-Wahn Kim', '1989-07-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10647')
# dup skipped:  ('정성훈', 'Sung-Hoon Jung', '1977-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10531')
# dup skipped:  ('송주영', 'Joo-Young Song', '1994-12-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11095')
# dup skipped:  ('유창준', 'Chang-Jun Yoo', '1989-07-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11185')
# dup skipped:  ('이성곤', 'Seong-Kon Lee', '1992-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11206')
# newly added:  ('전용훈', 'Yong-Hun Jeon', '1995-03-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11205')
# dup skipped:  ('지승민', 'Seung-Min Ji', '1978-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10228')
# dup skipped:  ('이정민', 'Jeong-Min Lee ', '1988-08-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10181')
# dup skipped:  ('이현민', 'Hyun-Min Lee', '1990-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10900')
# dup skipped:  ('박민정', 'Min-Jeong Park', '1988-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10884')
# dup skipped:  ('권영준', 'Young-Jun Kwon', '1988-04-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10893')
# dup skipped:  ('김현민', 'Hyun-Min Kim', '1992-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10897')
# dup skipped:  ('백진우', 'Jin-Woo Baek', '1988-11-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10898')
# dup skipped:  ('이태오', 'Tae-Oh Lee', '1993-12-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10887')
# dup skipped:  ('강화영', 'Hwa-Yeong Kang', '1993-05-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10886')
# dup skipped:  ('신동규', 'Dong-Kyu Shin', '1989-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10896')
# dup skipped:  ('여승철', 'Yeo Seung-cheol', '1984-05-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11210')
# dup skipped:  ('김상훈', 'Sang-hoon Kim', '1990-03-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10199')
# finished code:6, year: 2014
# dup skipped:  ('정기훈', 'Gi-Hoon Jeong', '1995-02-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12985')
# dup skipped:  ('이재우', 'Jae-Woo Lee', '1980-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10219')
# newly added:  ('장승현', 'Seung-Hyeon Jang', '1994-03-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11097')
# newly added:  ('로메로', 'Deibinson Romero', '1986-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11494')
# dup skipped:  ('칸투', 'Jorge Luís Cantú Guzmán', '1982-01-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11201')
# dup skipped:  ('김동길', 'Dong-Gil Kim', '1987-03-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10688')
# newly added:  ('루츠', 'Zach Lutz', '1986-06-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11382')
# dup skipped:  ('문진제', 'Jin-Je Moon', '1991-08-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11209')
# dup skipped:  ('최영진', 'Yeong-Jin Choi', '1988-05-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10934')
# dup skipped:  ('양종민', 'Jong-Min Yang', '1990-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10248')
# newly added:  ('신민재', 'Min-Jae Shin', '1996-01-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=13056')
# dup skipped:  ('최주환', 'Joo-Hwan Choi', '1988-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10182')
# dup skipped:  ('류지혁', 'Ji-Hyeok Ryu', '1994-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10894')
# newly added:  ('사공엽', 'Yeop Sagong', '1992-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11385')
# dup skipped:  ('김강', 'Kang Kim', '1988-10-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10547')
# dup skipped:  ('강동연', 'Dong-Yeon Kang', '1992-12-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10883')
# dup skipped:  ('원용묵', 'Yong-Muk Won', '1986-06-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10212')
# dup skipped:  ('오성민', 'Sung-Min Oh', '1985-11-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10709')
# dup skipped:  ('최재훈', 'Jae-Hun Choi', '1989-08-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10170')
# dup skipped:  ('허경민', 'Kyeong-Min Heo', '1990-08-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10184')
# dup skipped:  ('고영민', 'Yeong-Min Ko', '1984-02-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10171')
# dup skipped:  ('천상웅', 'Sang-Ung Cheon', '1991-05-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10735')
# dup skipped:  ('오현택', 'Hyun-Taek Oh', '1985-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10210')
# dup skipped:  ('조승수', 'Seung-Soo Jo', '1990-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10227')
# dup skipped:  ('이원석', 'Won-Seok Lee', '1986-10-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10180')
# dup skipped:  ('오재원', 'Jae-Won Oh', '1985-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10178')
# dup skipped:  ('성영훈', 'Yeong-Hun Seong', '1990-06-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10208')
# dup skipped:  ('양현', 'Hyeon Yang', '1992-08-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10730')
# newly added:  ('스와잭', 'Anthony Swarzak', '1985-09-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11496')
# dup skipped:  ('마야', 'Yunieski Maya', '1981-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11293')
# dup skipped:  ('김강률', 'Kang-Ryul Kim', '1988-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10690')
# dup skipped:  ('홍성흔', 'Seong-Heun Hong', '1977-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10256')
# dup skipped:  ('정진호', 'Jin-Ho Jeong', '1988-10-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10645')
# dup skipped:  ('오장훈', 'Jang-Hun Oh', '1984-05-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10250')
# dup skipped:  ('니코스키', 'Christopher John Nitkowski', '1973-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10204')
# dup skipped:  ('왓슨', 'Matthew Kyle Watson', '1978-09-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10190')
# dup skipped:  ('양의지', 'Eui-Ji Yang', '1987-06-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10165')
# dup skipped:  ('김응민', 'Eung-Min Kim', '1991-10-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10890')
# dup skipped:  ('김명성', 'Myeong-Seong Kim', '1988-04-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10680')
# dup skipped:  ('김명제', 'Myeong-Jae Kim', '1987-01-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10197')
# dup skipped:  ('이석만', 'Seok-Man Lee', '1980-05-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10215')
# newly added:  ('장원준', 'Won-Jun Jang', '1985-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10299')
# dup skipped:  ('유희관', 'Hee-Gwan Yoo', '1986-06-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10213')
# dup skipped:  ('유민상', 'Min-Sang Yoo', '1989-04-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10895')
# dup skipped:  ('핸킨스', 'Derek James Hankins', '1983-07-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11181')
# dup skipped:  ('프록터', 'Scott Christopher Proctor', '1977-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10919')
# dup skipped:  ('세데뇨', 'Juan Cedeño', '1983-08-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10209')
# dup skipped:  ('정수빈', 'Soo-Bin Jeong', '1990-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10195')
# dup skipped:  ('김재환', 'Jae-Hwan Kim', '1988-09-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10643')
# dup skipped:  ('국해성', 'Hae-Seong Kuk', '1989-10-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10172')
# dup skipped:  ('이원재', 'Won-Jae Lee', '1988-12-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10218')
# dup skipped:  ('진야곱', 'Ya-Gob Jin', '1989-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10229')
# dup skipped:  ('오재일', 'Jae-Il Oh', '1986-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10400')
# dup skipped:  ('박건우', 'Geon-Woo Park', '1990-09-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10189')
# dup skipped:  ('노경은', 'Kyeong-Eun Noh', '1984-03-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10203')
# dup skipped:  ('윤요한', 'Yo-han Yoon', '1989-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10214')
# dup skipped:  ('김수완', 'Soo-Wahn Kim', '1989-07-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10647')
# dup skipped:  ('니퍼트', 'Dustin Nippert', '1981-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10641')
# newly added:  ('채원후', 'Chae Wonhu', '1995-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11387')
# dup skipped:  ('윤명준', 'Myeong-Jun Yoon', '1989-06-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10885')
# dup skipped:  ('조규수', 'Gyu-Soo Jo', '1981-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10226')
# dup skipped:  ('최형록', 'Hyeong-rok Choi', '1989-08-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11208')
# dup skipped:  ('이용찬', 'Yong-Chan Lee', '1989-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10217')
# dup skipped:  ('이정호', 'Jeong-Ho Lee', '1992-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10731')
# dup skipped:  ('홍상삼', 'Sang-Sam Hong', '1990-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10230')
# dup skipped:  ('이현승', 'Hyun-Seung Lee', '1983-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10221')
# dup skipped:  ('민병헌', 'Byeong-Heon Min', '1987-03-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10188')
# dup skipped:  ('김현수', 'Hyun-Soo Kim', '1988-01-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10187')
# dup skipped:  ('임태훈', 'Tae-Hun Lim', '1988-09-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10222')
# dup skipped:  ('김재호', 'Jae-Ho Kim', '1985-03-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10174')
# dup skipped:  ('김진형', 'Jin-Hyeong Kim', '1990-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10186')
# dup skipped:  ('김준호', 'Jun-Ho Kim ', '1991-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10185')
# dup skipped:  ('한주성', 'Joo-Seong Han', '1995-02-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11203')
# dup skipped:  ('장우람', 'Woo-Ram Jang', '1988-09-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10889')
# dup skipped:  ('허준혁', 'Jun-Hyeok Huh', '1990-09-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10305')
# dup skipped:  ('배상현', 'Sang-Hyun Bae', '1990-10-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10176')
# dup skipped:  ('이현호', 'Hyeon-Ho Lee', '1992-07-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10677')
# dup skipped:  ('최현진', 'Hyun-Jin Choi', '1992-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10733')
# dup skipped:  ('이승학', 'Seung-Hak Lee', '1979-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10216')
# dup skipped:  ('김인태', 'In-Tae Kim', '1994-07-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11098')
# dup skipped:  ('장민익', 'Min-Ik Jang', '1991-02-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10223')
# dup skipped:  ('최병욱', 'Byeong-Wook Choi', '1989-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11204')
# dup skipped:  ('김경호', 'Gyeong-Ho Kim', '1995-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11207')
# dup skipped:  ('이우성', 'Woo-Sung Lee', '1994-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11099')
# dup skipped:  ('함덕주', 'Deok-Ju Ham', '1995-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11094')
# dup skipped:  ('박종섭', 'Jong-Seop Park', '1983-04-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10175')
# dup skipped:  ('천영웅', 'Young-Ung Cheon', '1994-03-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11096')
# dup skipped:  ('장민석', 'Min-Seok Jang', '1982-05-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10416')
# dup skipped:  ('변시원', 'Si-Won Byun', '1993-04-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10882')
# newly added:  ('남경호', 'Kyeong-Ho Nam', '1996-04-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11381')
# dup skipped:  ('정성훈', 'Sung-Hoon Jung', '1977-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10531')
# dup skipped:  ('송주영', 'Joo-Young Song', '1994-12-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11095')
# dup skipped:  ('안규영', 'Gyu-Young An', '1988-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10729')
# dup skipped:  ('김동한', 'Dong-Han Kim', '1988-06-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10734')
# dup skipped:  ('유창준', 'Chang-Jun Yoo', '1989-07-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11185')
# dup skipped:  ('전용훈', 'Yong-Hun Jeon', '1995-03-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11205')
# dup skipped:  ('지승민', 'Seung-Min Ji', '1978-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10228')
# dup skipped:  ('이정민', 'Jeong-Min Lee ', '1988-08-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10181')
# dup skipped:  ('김진수', 'Jin-Soo Kim', '1979-04-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10164')
# dup skipped:  ('이현민', 'Hyun-Min Lee', '1990-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10900')
# dup skipped:  ('박민정', 'Min-Jeong Park', '1988-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10884')
# dup skipped:  ('권영준', 'Young-Jun Kwon', '1988-04-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10893')
# newly added:  ('이용호', 'Yong-Ho Lee', '2012-01-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10888')
# dup skipped:  ('김현민', 'Hyun-Min Kim', '1992-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10897')
# newly added:  ('박소준', 'So-Joon Park', '1995-01-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11491')
# newly added:  ('정진철', 'Jin-Cheol Jung', '1991-12-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11386')
# dup skipped:  ('백진우', 'Jin-Woo Baek', '1988-11-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10898')
# dup skipped:  ('이태오', 'Tae-Oh Lee', '1993-12-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10887')
# newly added:  ('박종욱', 'Jong-Wook Park', '1996-03-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11384')
# dup skipped:  ('신동규', 'Dong-Kyu Shin', '1989-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10896')
# dup skipped:  ('강화영', 'Hwa-Yeong Kang', '1993-05-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10886')
# dup skipped:  ('여승철', 'Yeo Seung-cheol', '1984-05-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11210')
# newly added:  ('홍재용', 'Yong-jea Hong', '1989-07-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11417')
# newly added:  ('최용제', 'Yong-Je Choi', '1991-07-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12649')
# newly added:  ('박성민', 'Seong-Min Park', '1992-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11383')
# finished code:6, year: 2015
# dup skipped:  ('정기훈', 'Gi-Hoon Jeong', '1995-02-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12985')
# newly added:  ('이찬기', 'Chan-Gi Lee', '1993-05-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12610')
# dup skipped:  ('오현택', 'Hyun-Taek Oh', '1985-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10210')
# newly added:  ('신창희', 'Chang-Hee Shin', '1996-04-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12608')
# dup skipped:  ('최용제', 'Yong-Je Choi', '1991-07-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12649')
# newly added:  ('서예일', 'Ye-Il Seo', '1993-06-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12523')
# dup skipped:  ('로메로', 'Deibinson Romero', '1986-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11494')
# newly added:  ('홍성호', 'Sung-Ho Hong', '1997-07-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12606')
# dup skipped:  ('김동길', 'Dong-Gil Kim', '1987-03-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10688')
# dup skipped:  ('최병욱', 'Byeong-Wook Choi', '1989-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11204')
# newly added:  ('오석', 'Suk OH', '1993-09-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12611')
# dup skipped:  ('최주환', 'Joo-Hwan Choi', '1988-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10182')
# newly added:  ('황경태', 'Kyung-Tae Hwang', '1996-08-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12604')
# dup skipped:  ('류지혁', 'Ji-Hyeok Ryu', '1994-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10894')
# newly added:  ('정덕현', 'Deok-Hyun Jung', '1998-01-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12607')
# newly added:  ('조수행', 'Su-Haeng Cho', '1993-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12524')
# dup skipped:  ('윤명준', 'Myeong-Jun Yoon', '1989-06-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10885')
# dup skipped:  ('오성민', 'Sung-Min Oh', '1985-11-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10709')
# dup skipped:  ('최재훈', 'Jae-Hun Choi', '1989-08-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10170')
# dup skipped:  ('허경민', 'Kyeong-Min Heo', '1990-08-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10184')
# dup skipped:  ('고영민', 'Yeong-Min Ko', '1984-02-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10171')
# dup skipped:  ('천상웅', 'Sang-Ung Cheon', '1991-05-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10735')
# dup skipped:  ('국해성', 'Hae-Seong Kuk', '1989-10-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10172')
# dup skipped:  ('이원석', 'Won-Seok Lee', '1986-10-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10180')
# dup skipped:  ('이우성', 'Woo-Sung Lee', '1994-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11099')
# dup skipped:  ('김강률', 'Kang-Ryul Kim', '1988-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10690')
# dup skipped:  ('이용호', 'Yong-Ho Lee', '2012-01-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10888')
# dup skipped:  ('안규영', 'Gyu-Young An', '1988-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10729')
# dup skipped:  ('홍성흔', 'Seong-Heun Hong', '1977-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10256')
# dup skipped:  ('남경호', 'Kyeong-Ho Nam', '1996-04-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11381')
# dup skipped:  ('오재원', 'Jae-Won Oh', '1985-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10178')
# dup skipped:  ('왓슨', 'Matthew Kyle Watson', '1978-09-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10190')
# dup skipped:  ('니코스키', 'Christopher John Nitkowski', '1973-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10204')
# dup skipped:  ('양의지', 'Eui-Ji Yang', '1987-06-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10165')
# newly added:  ('보우덴', 'Michael Bowdent', '1986-09-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12515')
# dup skipped:  ('김명제', 'Myeong-Jae Kim', '1987-01-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10197')
# dup skipped:  ('홍상삼', 'Sang-Sam Hong', '1990-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10230')
# dup skipped:  ('장원준', 'Won-Jun Jang', '1985-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10299')
# dup skipped:  ('이석만', 'Seok-Man Lee', '1980-05-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10215')
# dup skipped:  ('유희관', 'Hee-Gwan Yoo', '1986-06-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10213')
# dup skipped:  ('세데뇨', 'Juan Cedeño', '1983-08-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10209')
# dup skipped:  ('핸킨스', 'Derek James Hankins', '1983-07-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11181')
# dup skipped:  ('왈론드', 'Leslie Dale Walrond', '1976-11-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10211')
# dup skipped:  ('프록터', 'Scott Christopher Proctor', '1977-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10919')
# newly added:  ('고봉재', 'Bong-Jae Ko', '1993-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12605')
# dup skipped:  ('정수빈', 'Soo-Bin Jeong', '1990-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10195')
# dup skipped:  ('김재환', 'Jae-Hwan Kim', '1988-09-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10643')
# dup skipped:  ('정진호', 'Jin-Ho Jeong', '1988-10-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10645')
# dup skipped:  ('진야곱', 'Ya-Gob Jin', '1989-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10229')
# dup skipped:  ('오재일', 'Jae-Il Oh', '1986-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10400')
# dup skipped:  ('박건우', 'Geon-Woo Park', '1990-09-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10189')
# newly added:  ('고원준', 'Won-Jun Go', '1990-06-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10424')
# dup skipped:  ('윤요한', 'Yo-han Yoon', '1989-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10214')
# dup skipped:  ('김인태', 'In-Tae Kim', '1994-07-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11098')
# dup skipped:  ('니퍼트', 'Dustin Nippert', '1981-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10641')
# dup skipped:  ('정재훈', 'Jae-Hoon Jung', '1980-01-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10225')
# dup skipped:  ('조규수', 'Gyu-Soo Jo', '1981-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10226')
# newly added:  ('양구열', 'Gu-Yeol Yang', '1994-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12609')
# newly added:  ('에반스', 'Nick Evans', '1986-01-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12517')
# dup skipped:  ('이용찬', 'Yong-Chan Lee', '1989-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10217')
# dup skipped:  ('강동연', 'Dong-Yeon Kang', '1992-12-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10883')
# dup skipped:  ('박세혁', 'Se-Hyuk Park', '1990-01-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10891')
# dup skipped:  ('이현승', 'Hyun-Seung Lee', '1983-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10221')
# dup skipped:  ('민병헌', 'Byeong-Heon Min', '1987-03-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10188')
# dup skipped:  ('김성배', 'Sung-Bae Kim', '1981-01-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10201')
# dup skipped:  ('김재호', 'Jae-Ho Kim', '1985-03-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10174')
# dup skipped:  ('김준호', 'Jun-Ho Kim ', '1991-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10185')
# dup skipped:  ('장우람', 'Woo-Ram Jang', '1988-09-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10889')
# dup skipped:  ('배상현', 'Sang-Hyun Bae', '1990-10-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10176')
# dup skipped:  ('허준혁', 'Jun-Hyeok Huh', '1990-09-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10305')
# dup skipped:  ('최현진', 'Hyun-Jin Choi', '1992-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10733')
# dup skipped:  ('이현호', 'Hyeon-Ho Lee', '1992-07-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10677')
# dup skipped:  ('신동규', 'Dong-Kyu Shin', '1989-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10896')
# newly added:  ('박진우', 'Jin-Woo Park', '1990-02-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11358')
# dup skipped:  ('김경호', 'Gyeong-Ho Kim', '1995-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11207')
# dup skipped:  ('함덕주', 'Deok-Ju Ham', '1995-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11094')
# dup skipped:  ('임진우', 'Jin-Woo Lim', '1987-05-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10374')
# dup skipped:  ('천영웅', 'Young-Ung Cheon', '1994-03-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11096')
# dup skipped:  ('박종섭', 'Jong-Seop Park', '1983-04-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10175')
# dup skipped:  ('박민정', 'Min-Jeong Park', '1988-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10884')
# dup skipped:  ('박성민', 'Seong-Min Park', '1992-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11383')
# dup skipped:  ('정성훈', 'Sung-Hoon Jung', '1977-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10531')
# dup skipped:  ('송주영', 'Joo-Young Song', '1994-12-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11095')
# dup skipped:  ('지승민', 'Seung-Min Ji', '1978-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10228')
# dup skipped:  ('이정민', 'Jeong-Min Lee ', '1988-08-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10181')
# dup skipped:  ('조승수', 'Seung-Soo Jo', '1990-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10227')
# dup skipped:  ('김진수', 'Jin-Soo Kim', '1979-04-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10164')
# dup skipped:  ('이현민', 'Hyun-Min Lee', '1990-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10900')
# dup skipped:  ('권영준', 'Young-Jun Kwon', '1988-04-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10893')
# newly added:  ('이영하', 'Young-Ha Lee', '1997-11-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12568')
# dup skipped:  ('김현민', 'Hyun-Min Kim', '1992-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10897')
# dup skipped:  ('정진철', 'Jin-Cheol Jung', '1991-12-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11386')
# dup skipped:  ('백진우', 'Jin-Woo Baek', '1988-11-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10898')
# newly added:  ('홍영현', 'Young-Hyun Hong', '1991-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12665')
# dup skipped:  ('강화영', 'Hwa-Yeong Kang', '1993-05-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10886')
# dup skipped:  ('이태오', 'Tae-Oh Lee', '1993-12-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10887')
# newly added:  ('노유성', 'Yoo-Sung Noh', '1993-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12580')
# finished code:6, year: 2016
# dup skipped:  ('오현택', 'Hyun-Taek Oh', '1985-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10210')
# newly added:  ('박유연', 'Yoo-Yeon Park', '1998-12-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12892')
# dup skipped:  ('서예일', 'Ye-Il Seo', '1993-06-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12523')
# newly added:  ('방건우', 'Geon-Woo Bang', '1996-04-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12978')
# dup skipped:  ('장승현', 'Seung-Hyeon Jang', '1994-03-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11097')
# dup skipped:  ('이찬기', 'Chan-Gi Lee', '1993-05-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12610')
# dup skipped:  ('정진철', 'Jin-Cheol Jung', '1991-12-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11386')
# dup skipped:  ('황경태', 'Kyung-Tae Hwang', '1996-08-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12604')
# newly added:  ('이유찬', 'Yu-Chan Lee', '1998-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12894')
# dup skipped:  ('류지혁', 'Ji-Hyeok Ryu', '1994-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10894')
# dup skipped:  ('정기훈', 'Gi-Hoon Jeong', '1995-02-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12985')
# dup skipped:  ('조수행', 'Su-Haeng Cho', '1993-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12524')
# dup skipped:  ('박세혁', 'Se-Hyuk Park', '1990-01-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10891')
# dup skipped:  ('홍영현', 'Young-Hyun Hong', '1991-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12665')
# newly added:  ('신성현', 'Seong-Hyeon Shin', '1990-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11492')
# dup skipped:  ('허경민', 'Kyeong-Min Heo', '1990-08-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10184')
# dup skipped:  ('문진제', 'Jin-Je Moon', '1991-08-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11209')
# dup skipped:  ('국해성', 'Hae-Seong Kuk', '1989-10-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10172')
# dup skipped:  ('김승회', 'Seung-Hoi Kim', '1981-02-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10202')
# dup skipped:  ('고원준', 'Won-Jun Go', '1990-06-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10424')
# dup skipped:  ('조승수', 'Seung-Soo Jo', '1990-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10227')
# dup skipped:  ('임진우', 'Jin-Woo Lim', '1987-05-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10374')
# dup skipped:  ('안규영', 'Gyu-Young An', '1988-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10729')
# dup skipped:  ('이용호', 'Yong-Ho Lee', '2012-01-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10888')
# dup skipped:  ('정진호', 'Jin-Ho Jeong', '1988-10-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10645')
# dup skipped:  ('오재원', 'Jae-Won Oh', '1985-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10178')
# dup skipped:  ('양의지', 'Eui-Ji Yang', '1987-06-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10165')
# dup skipped:  ('보우덴', 'Michael Bowdent', '1986-09-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12515')
# dup skipped:  ('김강률', 'Kang-Ryul Kim', '1988-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10690')
# dup skipped:  ('장원준', 'Won-Jun Jang', '1985-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10299')
# dup skipped:  ('유희관', 'Hee-Gwan Yoo', '1986-06-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10213')
# dup skipped:  ('고봉재', 'Bong-Jae Ko', '1993-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12605')
# dup skipped:  ('정수빈', 'Soo-Bin Jeong', '1990-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10195')
# dup skipped:  ('김재환', 'Jae-Hwan Kim', '1988-09-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10643')
# dup skipped:  ('이성곤', 'Seong-Kon Lee', '1992-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11206')
# dup skipped:  ('이원재', 'Won-Jae Lee', '1988-12-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10218')
# dup skipped:  ('오재일', 'Jae-Il Oh', '1986-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10400')
# dup skipped:  ('박건우', 'Geon-Woo Park', '1990-09-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10189')
# dup skipped:  ('김성배', 'Sung-Bae Kim', '1981-01-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10201')
# dup skipped:  ('김인태', 'In-Tae Kim', '1994-07-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11098')
# dup skipped:  ('니퍼트', 'Dustin Nippert', '1981-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10641')
# dup skipped:  ('최병욱', 'Byeong-Wook Choi', '1989-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11204')
# dup skipped:  ('에반스', 'Nick Evans', '1986-01-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12517')
# dup skipped:  ('이용찬', 'Yong-Chan Lee', '1989-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10217')
# newly added:  ('김명신', 'Myeong-Shin Kim', '1993-11-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12847')
# dup skipped:  ('홍상삼', 'Sang-Sam Hong', '1990-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10230')
# dup skipped:  ('이현승', 'Hyun-Seung Lee', '1983-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10221')
# dup skipped:  ('민병헌', 'Byeong-Heon Min', '1987-03-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10188')
# dup skipped:  ('이영하', 'Young-Ha Lee', '1997-11-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12568')
# dup skipped:  ('남경호', 'Kyeong-Ho Nam', '1996-04-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11381')
# dup skipped:  ('김재호', 'Jae-Ho Kim', '1985-03-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10174')
# dup skipped:  ('최주환', 'Joo-Hwan Choi', '1988-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10182')
# dup skipped:  ('한주성', 'Joo-Seong Han', '1995-02-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11203')
# dup skipped:  ('이우성', 'Woo-Sung Lee', '1994-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11099')
# dup skipped:  ('이현호', 'Hyeon-Ho Lee', '1992-07-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10677')
# dup skipped:  ('장민익', 'Min-Ik Jang', '1991-02-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10223')
# dup skipped:  ('박진우', 'Jin-Woo Park', '1990-02-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11358')
# newly added:  ('문원', 'Won Moon', '1998-08-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12848')
# newly added:  ('지윤', 'Yoon Ji', '1997-10-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12891')
# dup skipped:  ('함덕주', 'Deok-Ju Ham', '1995-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11094')
# newly added:  ('박찬범', 'Chan-Beom Park', '1997-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12895')
# newly added:  ('최원준', 'Won-Jun Choi', '1994-12-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12852')
# newly added:  ('박성환', 'Seong-Hwan Park', '1998-05-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12849')
# newly added:  ('백민규', 'Min-Gyu Baek', '1998-01-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12893')
# newly added:  ('박치국', 'Chi-Guk Park', '1998-03-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12850')
# dup skipped:  ('유창준', 'Chang-Jun Yoo', '1989-07-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11185')
# ...
# dup skipped:  ('신준우', 'Jun-Woo Shin', '2001-06-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14695')
# dup skipped:  ('이명종', 'Myeong-Jong Lee', '2002-12-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15073')
# dup skipped:  ('오상원', 'Sang-Won Oh', '2004-07-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15474')
# dup skipped:  ('박승주', 'Seung-Ju Park', '1994-02-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12989')
# dup skipped:  ('김동규', 'Dong-Gyu Kim', '2004-07-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15485')
# newly added:  ('고영우', 'Young-woo Ko', '2001-06-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16128')
# newly added:  ('박범준', 'Bum-jun Park', '2004-05-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16133')
# dup skipped:  ('원종현', 'Jong-Hyeon Won', '1987-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11161')
# dup skipped:  ('박찬혁', 'Chan-Hyeok Park', '2003-04-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15068')
# dup skipped:  ('김선기', 'Seon-Gi Kim ', '1991-09-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=13092')
# dup skipped:  ('하영민', 'Young-Min Ha', '1995-05-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11222')
# dup skipped:  ('최주환', 'Joo-Hwan Choi', '1988-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10182')
# newly added:  ('헤이수스', 'Enmanuel Jose De Jesus', '1996-12-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16138')
# dup skipped:  ('양지율', 'Ji-Yool Yang', '1998-12-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12854')
# dup skipped:  ('변상권', 'Sang-Kwon Byun', '1997-04-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=13223')
# dup skipped:  ('박주홍', 'Ju-Hong Park', '2001-04-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14580')
# dup skipped:  ('정찬헌', 'Chan-Heon Jeong', '1990-01-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10533')
# dup skipped:  ('노운현', 'Woon-Hyun Noh', '2003-06-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15027')
# dup skipped:  ('김동혁', 'Dong-Hyeok Kim', '2001-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14674')
# dup skipped:  ('장재영', 'Jae-Young Jang', '2002-05-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14784')
# newly added:  ('전준표', 'Jun-pyo Jun', '2005-05-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16122')
# newly added:  ('손현기', 'Hyun-gi Son', '2005-10-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16125')
# dup skipped:  ('박성빈', 'Sung-Bin Park', '2004-04-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15479')
# dup skipped:  ('김동욱', 'Dong-Wook Kim', '1997-05-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14681')
# dup skipped:  ('이종민', 'Jong-Min Lee', '2001-06-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14576')
# dup skipped:  ('김인범', 'In-Beom Kim', '2000-01-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14480')
# newly added:  ('김연주', 'Yeon-ju Kim', '2004-02-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16127')
# dup skipped:  ('후라도', 'Ariel Bolívar Jurado Agrazal', '1996-01-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15531')
# dup skipped:  ('주승빈', 'Seung-Bin Joo', '2004-03-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15072')
# dup skipped:  ('이승원', 'Seung-Won Lee', '2004-07-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15476')
# dup skipped:  ('김준형', 'Jun-hyoung Kim', '2002-07-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14848')
# newly added:  ('송지후', 'Ji-hoo Song', '2005-01-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16130')
# dup skipped:  ('윤석원', 'Suk-Won Yoon', '2003-07-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15071')
# dup skipped:  ('박준형', 'Jun-Hyeong Park', '1999-03-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14211')
# newly added:  ('김지성', 'Ji-sung Kim', '2004-05-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=16131')
# dup skipped:  ('서유신', 'Yu-shin Seo', '2000-08-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15483')
# dup skipped:  ('윤정현', 'Jung-Hyeon Yoon', '1993-05-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14131')
# dup skipped:  ('조성훈', 'Seong-Hun Cho', '1999-03-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=13125')
# dup skipped:  ('우승원', 'Seung-Won Woo', '2004-06-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15478')
# dup skipped:  ('이호열', 'Ho-Yeol Lee', '2004-11-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15480')
# dup skipped:  ('변헌성', 'Heon-Sung Byun', '2004-05-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15481')
# dup skipped:  ('안겸', 'Gyeom Ahn', '2004-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15482')
# finished code:11, year: 2024
# dup skipped:  ('안언학', 'Un-Hak Ahn', '1962-01-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1243')
# dup skipped:  ('조용호', 'Yong-Ho Cho', '1965-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1358')
# dup skipped:  ('이승희', 'Seung-Hee Lee', '1959-04-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1251')
# dup skipped:  ('김기태', 'Ki-Tae Kim', '1969-05-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11474')
# dup skipped:  ('서창기', 'Chang-Ki Seo', '1965-03-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1389')
# dup skipped:  ('김호', 'Ho Kim', '1967-05-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1581')
# newly added:  ('정학원', 'Hak-Won Jung', '1968-08-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1601')
# dup skipped:  ('김평호', 'Pyung-Ho Kim', '1963-12-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1270')
# dup skipped:  ('윤혁', 'Hyuk Yoon', '1967-05-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1592')
# dup skipped:  ('송인호', 'In-Ho Song', '1968-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1590')
# dup skipped:  ('김호근', 'Ho-Geun Kim', '1960-06-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1155')
# dup skipped:  ('박진석', 'Jin-Seok Park', '1968-01-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1630')
# dup skipped:  ('강상진', 'Sang-Jin Kang', '1962-04-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1317')
# dup skipped:  ('진동한', 'Dong-Han Jin', '1961-06-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1231')
# dup skipped:  ('양후승', 'Hoo-Seung Yang', '1961-09-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1244')
# dup skipped:  ('유동효', 'Dong-Hyo Yoo', '1965-04-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1397')
# dup skipped:  ('이상대', 'Sang-Dae Lee', '1967-01-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1451')
# dup skipped:  ('이창원', 'Chang-Won Lee', '1963-02-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1305')
# dup skipped:  ('조규제', 'Kyu-Je Cho', '1967-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1608')
# dup skipped:  ('권영진', 'Young-Jin Kwon', '1968-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1617')
# dup skipped:  ('김만후', 'Man-Hoo Kim', '1964-03-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1341')
# dup skipped:  ('강길용', 'Gil-Yong Kang', '1968-10-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1612')
# dup skipped:  ('최해식', 'Hae-Sik Choi', '1968-09-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1607')
# dup skipped:  ('김상재', 'Sang-Jae Kim', '1968-04-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1655')
# dup skipped:  ('전종화', 'Jong-Hwa Jeon', '1965-08-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12713')
# dup skipped:  ('김봉근', 'Bong-Geun Kim', '1961-03-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1223')
# dup skipped:  ('한오종', 'Oh-Jong Han', '1961-06-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1268')
# newly added:  ('정인조', 'In-Jo Jung', '1964-11-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1643')
# dup skipped:  ('박성기', 'Sung-Ki Park', '1969-01-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1629')
# dup skipped:  ('이연수', 'Yeon-Soo Lee', '1963-03-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1350')
# dup skipped:  ('김기덕', 'Ki-Duk Kim', '1968-06-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1619')
# dup skipped:  ('박기택', 'Gi-Taek Park', '1968-11-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11436')
# dup skipped:  ('박종철', 'Jong-Cheol Park', '1971-10-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11440')
# newly added:  ('김경수', 'Kyung-Soo Kim', '1967-04-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1574')
# dup skipped:  ('최준호', 'Jun-Ho Choi', '1966-10-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1492')
# newly added:  ('공봉구', 'Bong-Gu Gong', '1967-07-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1572')
# dup skipped:  ('이재홍', 'Jae-Hong Lee', '1963-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1485')
# dup skipped:  ('최한림', 'Han-Rim Choi', '1971-11-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1645')
# dup skipped:  ('김원형', 'Won-Hyong Kim', '1972-07-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14890')
# newly added:  ('김동수', 'Dong-Soo Kim', '1968-08-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1622')
# dup skipped:  ('손문곤', 'Mun-Gon Son', '1965-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1326')
# newly added:  ('김기완', 'Ki-Wahn Kim', '1966-06-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1621')
# newly added:  ('구대진', 'Dae-Jin Koo', '1967-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1615')
# newly added:  ('김영운', 'Young-Woon Kim', '1966-04-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1576')
# newly added:  ('강남규', 'Nam-Kyu Kang', '1968-08-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1569')
# newly added:  ('고승훈', 'Seung-Hoon Ko', '1969-01-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1571')
# newly added:  ('유성기', 'Sung-Ki Yoo', '1972-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1591')
# dup skipped:  ('박경완', 'Kyung-Wahn Park', '1972-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10080')
# finished code:8, year: 1991
# dup skipped:  ('김원식', 'Won-Sik Kim', '1966-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1384')
# dup skipped:  ('조용호', 'Yong-Ho Cho', '1965-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1358')
# dup skipped:  ('이승희', 'Seung-Hee Lee', '1959-04-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1251')
# dup skipped:  ('김기태', 'Ki-Tae Kim', '1969-05-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11474')
# dup skipped:  ('서창기', 'Chang-Ki Seo', '1965-03-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1389')
# dup skipped:  ('김호', 'Ho Kim', '1967-05-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1581')
# dup skipped:  ('정학원', 'Hak-Won Jung', '1968-08-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1601')
# dup skipped:  ('김평호', 'Pyung-Ho Kim', '1963-12-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1270')
# dup skipped:  ('윤혁', 'Hyuk Yoon', '1967-05-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1592')
# dup skipped:  ('송인호', 'In-Ho Song', '1968-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1590')
# dup skipped:  ('김호근', 'Ho-Geun Kim', '1960-06-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1155')
# dup skipped:  ('박진석', 'Jin-Seok Park', '1968-01-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1630')
# dup skipped:  ('진동한', 'Dong-Han Jin', '1961-06-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1231')
# dup skipped:  ('김성규', 'Sung-Kyu Kim', '1965-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1372')
# dup skipped:  ('양후승', 'Hoo-Seung Yang', '1961-09-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1244')
# dup skipped:  ('유동효', 'Dong-Hyo Yoo', '1965-04-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1397')
# dup skipped:  ('이상대', 'Sang-Dae Lee', '1967-01-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1451')
# dup skipped:  ('이현택', 'Hyun-Taek Lee', '1964-09-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1398')
# dup skipped:  ('조규제', 'Kyu-Je Cho', '1967-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1608')
# dup skipped:  ('권영진', 'Young-Jin Kwon', '1968-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1617')
# dup skipped:  ('김만후', 'Man-Hoo Kim', '1964-03-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1341')
# newly added:  ('김석기', 'Seok-Ki Kim', '1967-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1698')
# dup skipped:  ('강길용', 'Gil-Yong Kang', '1968-10-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1612')
# dup skipped:  ('최해식', 'Hae-Sik Choi', '1968-09-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1607')
# dup skipped:  ('김상재', 'Sang-Jae Kim', '1968-04-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1655')
# dup skipped:  ('전종화', 'Jong-Hwa Jeon', '1965-08-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12713')
# dup skipped:  ('임창식', 'Chang-Sik Lim', '1969-03-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1715')
# dup skipped:  ('김봉근', 'Bong-Geun Kim', '1961-03-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1223')
# newly added:  ('황태호', 'Tae-Ho Hwang', '1967-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1718')
# newly added:  ('유태영', 'Tae-Young Yoo', '1969-12-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1677')
# dup skipped:  ('박성기', 'Sung-Ki Park', '1969-01-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1629')
# dup skipped:  ('이연수', 'Yeon-Soo Lee', '1963-03-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1350')
# dup skipped:  ('김기덕', 'Ki-Duk Kim', '1968-06-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1619')
# dup skipped:  ('김풍기', 'Poong-Gi Kim', '1966-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11430')
# dup skipped:  ('박기택', 'Gi-Taek Park', '1968-11-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11436')
# dup skipped:  ('최해명', 'Hae-Myung Choi', '1964-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1427')
# dup skipped:  ('김경수', 'Kyung-Soo Kim', '1967-04-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1574')
# dup skipped:  ('최준호', 'Jun-Ho Choi', '1966-10-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1492')
# dup skipped:  ('이재홍', 'Jae-Hong Lee', '1963-09-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1485')
# newly added:  ('김형태', 'Hyung-Tae Kim', '1969-09-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1663')
# dup skipped:  ('이동석', 'Dong-Seok Lee', '1964-01-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1366')
# dup skipped:  ('최한림', 'Han-Rim Choi', '1971-11-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1645')
# dup skipped:  ('김원형', 'Won-Hyong Kim', '1972-07-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14890')
# dup skipped:  ('손문곤', 'Mun-Gon Son', '1965-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1326')
# newly added:  ('신현대', 'Hyun-Dae Shin', '1969-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1710')
# newly added:  ('유영원', 'Young-Won Yoo', '1969-09-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1675')
# newly added:  ('우효동', 'Hyo-Dong Woo', '1970-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11437')
# dup skipped:  ('유성기', 'Sung-Ki Yoo', '1972-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1591')
# dup skipped:  ('박경완', 'Kyung-Wahn Park', '1972-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10080')
# finished code:8, year: 1992
# dup skipped:  ('김진욱', 'Jin-Wook Kim', '1960-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12962')
# dup skipped:  ('조용호', 'Yong-Ho Cho', '1965-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1358')
