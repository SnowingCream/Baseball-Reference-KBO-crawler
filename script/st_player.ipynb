# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd
import csv
import os
import re
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
from helper.url_parser import get_ct_code_and_year, team_url_to_back_number_url

# %%
session = Session(1000000) # doesn't really matter for statiz

# %%
initial_url = "https://statiz.sporki.com/team/" # starting point
front_url = "https://statiz.sporki.com" # front part of URL in which hrefs will be concatenated on.

# %% [markdown]
# ## Dup Check Setup

# %%
# initial header row setup
file_path = '../data/st_player.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name_kor", "name_eng", "date_of_birth", "url"]
        writer.writerow(header)

# %%
# initial header row setup 2
file_path = '../data/st_finished_team_year.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file2:
        writer2 = csv.writer(file2)
        header = ["code", "year"]
        writer2.writerow(header)

# %%
# to filter duplicate
# both removed the header row
added_team_and_year = set([tuple(row) for row in csv.reader(open('../data/st_finished_team_year.csv', 'r'))][1:])
added_player = set([tuple(row) for row in csv.reader(open('../data/st_player.csv', 'r'))][1:])

# %%
# print(added_team_and_year)
# print(len(added_team_and_year))
# print(len(added_player))

# %% [markdown]
# ## Main Code

# %%
teams_data = session.fetch(initial_url).content.decode("utf-8") # page that contains all teams' links
teams_html = BSoup(teams_data, "lxml")
teams = teams_html.find(class_="team_list").find_all(class_="select_con")

# %%
for team in teams:
    
    years = team.find_all("a")

    for year in years:
        
        current_ct_code, current_year = get_ct_code_and_year(year['href'])
        # print(current_ct_code, current_year)
        # skip over the fully processed year with the given team.
        if (str(current_ct_code), str(current_year)) in added_team_and_year:
            print(f"already done, skip over code:{current_ct_code}, year: {current_year}")
            continue
        team_url = team_url_to_back_number_url(year['href'])
        team_data = session.fetch(team_url).content.decode("utf-8")
        team_html = BSoup(team_data, "lxml")
        players = team_html.find_all(class_="item away")[2:]


        with open("../data/st_player.csv", 'a', newline='') as players_info:
                
            writer = csv.writer(players_info)

            for player in players:
                player_url = front_url + player.find("a")['href']
                player_data = session.fetch(player_url).content.decode("utf-8")
                player_html = BSoup(player_data, "lxml")

                # segment that contains Korean and English name of the player.
                player_name = player_html.find(class_="name")
                # sometimes there is a blank page that doesn't contain any info about the player.
                if not player_name:
                    continue
                player_name = player_name.text.strip()
                name_kor = player_name.split('(')[0].strip()
                name_eng = player_name.split('(')[1][:-1]

                # segment that contains the date of birth of the player.
                dob = player_html.find(class_="man_info").find("li").text
                dob = re.findall(r'\d+', dob)
                dob = "-".join(dob)
                
                player_row = (name_kor, name_eng, dob, player_url)
    
                if player_row not in added_player:
                    added_player.add(player_row)
                    writer.writerow(player_row)
                    print("newly added: ", player_row)
                else:
                    print("dup skipped: ", player_row)

            print(f"finished code:{current_ct_code}, year: {current_year}")

        with open('../data/st_finished_team_year.csv', 'a', newline='') as done_team_year:
            writer2 = csv.writer(done_team_year)
            writer2.writerow((current_ct_code, current_year))
            added_team_and_year.add(((str(current_ct_code), str(current_year))))
# Out:
# already done, skip over code:2, year: 1982
# already done, skip over code:2, year: 1983
# already done, skip over code:2, year: 1984
# already done, skip over code:2, year: 1985
# already done, skip over code:2, year: 1986
# already done, skip over code:2, year: 1987
# already done, skip over code:2, year: 1988
# already done, skip over code:2, year: 1989
# already done, skip over code:2, year: 1990
# already done, skip over code:2, year: 1991
# already done, skip over code:2, year: 1992
# already done, skip over code:2, year: 1993
# already done, skip over code:2, year: 1994
# already done, skip over code:2, year: 1995
# already done, skip over code:2, year: 1996
# already done, skip over code:2, year: 1997
# already done, skip over code:2, year: 1998
# already done, skip over code:2, year: 1999
# already done, skip over code:2, year: 2000
# already done, skip over code:2, year: 2001
# already done, skip over code:2, year: 2002
# already done, skip over code:2, year: 2003
# already done, skip over code:2, year: 2004
# already done, skip over code:2, year: 2005
# already done, skip over code:2, year: 2006
# already done, skip over code:2, year: 2007
# already done, skip over code:2, year: 2008
# already done, skip over code:2, year: 2009
# already done, skip over code:2, year: 2010
# already done, skip over code:2, year: 2011
# already done, skip over code:2, year: 2012
# already done, skip over code:2, year: 2013
# already done, skip over code:2, year: 2014
# already done, skip over code:2, year: 2015
# already done, skip over code:2, year: 2016
# already done, skip over code:2, year: 2017
# already done, skip over code:2, year: 2018
# already done, skip over code:2, year: 2019
# already done, skip over code:2, year: 2020
# already done, skip over code:2, year: 2021
# already done, skip over code:2, year: 2022
# already done, skip over code:2, year: 2023
# already done, skip over code:2, year: 2024
# already done, skip over code:1, year: 1982
# already done, skip over code:1, year: 1983
# already done, skip over code:1, year: 1984
# already done, skip over code:1, year: 1985
# already done, skip over code:1, year: 1986
# already done, skip over code:1, year: 1987
# already done, skip over code:1, year: 1988
# already done, skip over code:1, year: 1989
# already done, skip over code:1, year: 1990
# already done, skip over code:1, year: 1991
# already done, skip over code:1, year: 1992
# already done, skip over code:1, year: 1993
# already done, skip over code:1, year: 1994
# already done, skip over code:1, year: 1995
# already done, skip over code:1, year: 1996
# already done, skip over code:1, year: 1997
# already done, skip over code:1, year: 1998
# already done, skip over code:1, year: 1999
# already done, skip over code:1, year: 2000
# already done, skip over code:1, year: 2001
# already done, skip over code:1, year: 2002
# already done, skip over code:1, year: 2003
# already done, skip over code:1, year: 2004
# already done, skip over code:1, year: 2005
# already done, skip over code:1, year: 2006
# already done, skip over code:1, year: 2007
# already done, skip over code:1, year: 2008
# already done, skip over code:1, year: 2009
# already done, skip over code:1, year: 2010
# already done, skip over code:1, year: 2011
# already done, skip over code:1, year: 2012
# already done, skip over code:1, year: 2013
# already done, skip over code:1, year: 2014
# already done, skip over code:1, year: 2015
# already done, skip over code:1, year: 2016
# already done, skip over code:1, year: 2017
# already done, skip over code:1, year: 2018
# already done, skip over code:1, year: 2019
# already done, skip over code:1, year: 2020
# already done, skip over code:1, year: 2021
# already done, skip over code:1, year: 2022
# already done, skip over code:1, year: 2023
# already done, skip over code:1, year: 2024
# already done, skip over code:6, year: 1982
# already done, skip over code:6, year: 1983
# already done, skip over code:6, year: 1984
# already done, skip over code:6, year: 1985
# already done, skip over code:6, year: 1986
# already done, skip over code:6, year: 1987
# already done, skip over code:6, year: 1988
# already done, skip over code:6, year: 1989
# dup skipped:  ('김만조', 'Man-Jo Kim', '1969-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1696')
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# dup skipped:  ('송명철', 'Myung-Chul Song', '1970-05-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1446')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('김광수', 'Kwang-soo Kim', '1959-01-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1035')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('송재박', 'Jae-Park Song', '1956-10-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1390')
# dup skipped:  ('곽연수', 'Yeon-Su Kwak', '1967-03-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1430')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('계형철', 'Hyeong-Cheol Kye', '1953-04-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1114')
# dup skipped:  ('김동현', 'Dong-Hyun Kim', '1966-10-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1471')
# dup skipped:  ('최치용', 'Chi-Yong Choi', '1971-07-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1538')
# dup skipped:  ('양세종', 'Se-jong Yang', '1958-01-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1020')
# dup skipped:  ('김진욱', 'Jin-Wook Kim', '1960-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12962')
# dup skipped:  ('박노준', 'No-Jun Park', '1962-10-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1292')
# dup skipped:  ('신경식', 'Kyung-Sik Shin', '1961-08-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1019')
# dup skipped:  ('구천서', 'Chun-Seo Gu', '1963-08-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1001')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('조범현', 'Beom-Hyeon Cho', '1960-10-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11476')
# dup skipped:  ('이진', 'Jin Lee ', '1966-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1461')
# dup skipped:  ('김보선', 'Bo-Sun Kim', '1966-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1546')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# dup skipped:  ('안대환', 'Dae-Hwan An', '1962-09-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1339')
# dup skipped:  ('장호연', 'Ho-Yeon Jang', '1960-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1177')
# dup skipped:  ('길홍규', 'Hong-Gyu Gil', '1965-03-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1378')
# dup skipped:  ('김광림', 'Gwang-Lim Kim', '1961-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1203')
# dup skipped:  ('구동우', 'Dong-Woo Gu', '1966-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1468')
# dup skipped:  ('윤석환', 'Seog-Hwan Yun', '1961-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1227')
# dup skipped:  ('김진규', 'Jin-Kyu Kim', '1962-06-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15156')
# dup skipped:  ('서일권', 'Il-Gwon Seo', '1961-10-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1388')
# dup skipped:  ('정삼룡', 'Sam-Ryong Jung', '1965-09-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1528')
# newly added:  ('정재호', 'Jae-Ho Jung', '1967-10-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1530')
# newly added:  ('서준룡', 'Jun-Ryong Seo ', '1967-08-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1515')
# dup skipped:  ('최동창', 'Dong-Chang Choi', '1965-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1311')
# newly added:  ('최덕현', 'Deok-Hyun Choi', '1971-07-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1603')
# newly added:  ('손병희', 'Byung-Hee Son', '1971-04-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1551')
# dup skipped:  ('이복근', 'Bok-Geun Lee', '1962-04-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1275')
# newly added:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# dup skipped:  ('박형열', 'Hyung-Yeol Park', '1967-11-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1325')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# dup skipped:  ('김호근', 'Ho-Geun Kim', '1960-06-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1155')
# dup skipped:  ('하창우', 'Chang-Woo Ha', '1969-10-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1419')
# dup skipped:  ('이상훈', 'Sang-Hoon Lee', '1963-10-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1349')
# newly added:  ('노석기', 'Seok-Gi Noh', '1971-08-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1705')
# dup skipped:  ('강규성', 'Gyu-Seong Kang', '1969-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1466')
# newly added:  ('조정수', 'Jung-Su Cho', '1969-05-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1558')
# dup skipped:  ('김형균', 'Hyung-Gyun Kim', '1969-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1474')
# dup skipped:  ('최규순', 'Gyu-Soon Choi ', '1967-01-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=13921')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# dup skipped:  ('김원식', 'Won-Sik Kim', '1966-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1384')
# newly added:  ('권영구', 'Young-Gu Kwon', '1971-08-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1543')
# newly added:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# finished code:6, year: 1990
# dup skipped:  ('김만조', 'Man-Jo Kim', '1969-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1696')
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# dup skipped:  ('송명철', 'Myung-Chul Song', '1970-05-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1446')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# dup skipped:  ('김광수', 'Kwang-soo Kim', '1959-01-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1035')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# newly added:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('곽연수', 'Yeon-Su Kwak', '1967-03-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1430')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('계형철', 'Hyeong-Cheol Kye', '1953-04-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1114')
# dup skipped:  ('김동현', 'Dong-Hyun Kim', '1966-10-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1471')
# dup skipped:  ('최치용', 'Chi-Yong Choi', '1971-07-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1538')
# dup skipped:  ('최동창', 'Dong-Chang Choi', '1965-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1311')
# newly added:  ('한명수', 'Myeong-Soo Han ', '1966-11-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1493')
# dup skipped:  ('김진욱', 'Jin-Wook Kim', '1960-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12962')
# dup skipped:  ('박노준', 'No-Jun Park', '1962-10-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1292')
# dup skipped:  ('구천서', 'Chun-Seo Gu', '1963-08-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1001')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('김경문', 'Kyeong-Mun Kim', '1958-11-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11469')
# newly added:  ('김익재', 'Ik-Jae Kim', '1968-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1627')
# dup skipped:  ('이진', 'Jin Lee ', '1966-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1461')
# dup skipped:  ('김보선', 'Bo-Sun Kim', '1966-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1546')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# dup skipped:  ('안대환', 'Dae-Hwan An', '1962-09-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1339')
# dup skipped:  ('장호연', 'Ho-Yeon Jang', '1960-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1177')
# dup skipped:  ('길홍규', 'Hong-Gyu Gil', '1965-03-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1378')
# dup skipped:  ('김광림', 'Gwang-Lim Kim', '1961-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1203')
# dup skipped:  ('구동우', 'Dong-Woo Gu', '1966-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1468')
# newly added:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('김진규', 'Jin-Kyu Kim', '1962-06-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15156')
# dup skipped:  ('서일권', 'Il-Gwon Seo', '1961-10-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1388')
# dup skipped:  ('정삼룡', 'Sam-Ryong Jung', '1965-09-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1528')
# dup skipped:  ('서준룡', 'Jun-Ryong Seo ', '1967-08-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1515')
# dup skipped:  ('최덕현', 'Deok-Hyun Choi', '1971-07-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1603')
# dup skipped:  ('손병희', 'Byung-Hee Son', '1971-04-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1551')
# dup skipped:  ('이복근', 'Bok-Geun Lee', '1962-04-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1275')
# dup skipped:  ('강영수', 'Young-Soo Kang', '1965-02-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1428')
# dup skipped:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# dup skipped:  ('박형열', 'Hyung-Yeol Park', '1967-11-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1325')
# dup skipped:  ('하창우', 'Chang-Woo Ha', '1969-10-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1419')
# dup skipped:  ('이상훈', 'Sang-Hoon Lee', '1963-10-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1349')
# newly added:  ('김인철', 'In-Chul Kim', '1974-08-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1656')
# dup skipped:  ('노석기', 'Seok-Gi Noh', '1971-08-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1705')
# newly added:  ('최영술', 'Young-Sool Choi', '1972-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1604')
# dup skipped:  ('강규성', 'Gyu-Seong Kang', '1969-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1466')
# newly added:  ('이전진', 'Jeon-Jin Lee', '1972-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1679')
# dup skipped:  ('조정수', 'Jung-Su Cho', '1969-05-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1558')
# dup skipped:  ('김형균', 'Hyung-Gyun Kim', '1969-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1474')
# newly added:  ('권영일', 'Young-Il Kwon', '1968-01-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1616')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# dup skipped:  ('김원식', 'Won-Sik Kim', '1966-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1384')
# dup skipped:  ('권영구', 'Young-Gu Kwon', '1971-08-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1543')
# newly added:  ('최재룡', 'Jae-Ryong Choi', '1964-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1605')
# newly added:  ('조중석', 'Joong-Seok Cho', '1972-03-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1717')
# newly added:  ('박천유', 'Cheon-Yoo Park', '1968-12-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1586')
# dup skipped:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# finished code:6, year: 1991
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# dup skipped:  ('송명철', 'Myung-Chul Song', '1970-05-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1446')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# newly added:  ('안경현', 'Kyung-Hyun An', '1970-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10099')
# dup skipped:  ('김광수', 'Kwang-soo Kim', '1959-01-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1035')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('곽연수', 'Yeon-Su Kwak', '1967-03-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1430')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('이광우', 'Kwang-Woo Lee', '1965-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1426')
# dup skipped:  ('김동현', 'Dong-Hyun Kim', '1966-10-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1471')
# dup skipped:  ('최동창', 'Dong-Chang Choi', '1965-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1311')
# dup skipped:  ('권명철', 'Myeong-Cheol Kwon', '1969-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1695')
# dup skipped:  ('김진욱', 'Jin-Wook Kim', '1960-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12962')
# newly added:  ('이상현', 'Sang-Hyun Lee', '1969-07-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1712')
# dup skipped:  ('구천서', 'Chun-Seo Gu', '1963-08-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1001')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# dup skipped:  ('김익재', 'Ik-Jae Kim', '1968-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1627')
# dup skipped:  ('이진', 'Jin Lee ', '1966-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1461')
# dup skipped:  ('김보선', 'Bo-Sun Kim', '1966-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1546')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# dup skipped:  ('안대환', 'Dae-Hwan An', '1962-09-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1339')
# dup skipped:  ('장호연', 'Ho-Yeon Jang', '1960-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1177')
# dup skipped:  ('길홍규', 'Hong-Gyu Gil', '1965-03-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1378')
# dup skipped:  ('김광림', 'Gwang-Lim Kim', '1961-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1203')
# dup skipped:  ('구동우', 'Dong-Woo Gu', '1966-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1468')
# dup skipped:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('김진규', 'Jin-Kyu Kim', '1962-06-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15156')
# newly added:  ('장원진', 'Won-Jin Jang', '1969-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1682')
# dup skipped:  ('정삼룡', 'Sam-Ryong Jung', '1965-09-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1528')
# newly added:  ('고원부', 'Won-Bu Ko', '1962-04-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1278')
# dup skipped:  ('최덕현', 'Deok-Hyun Choi', '1971-07-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1603')
# dup skipped:  ('손병희', 'Byung-Hee Son', '1971-04-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1551')
# dup skipped:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# dup skipped:  ('강영수', 'Young-Soo Kang', '1965-02-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1428')
# dup skipped:  ('박형열', 'Hyung-Yeol Park', '1967-11-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1325')
# dup skipped:  ('하창우', 'Chang-Woo Ha', '1969-10-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1419')
# dup skipped:  ('이상훈', 'Sang-Hoon Lee', '1963-10-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1349')
# dup skipped:  ('김인철', 'In-Chul Kim', '1974-08-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1656')
# dup skipped:  ('김만조', 'Man-Jo Kim', '1969-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1696')
# dup skipped:  ('노석기', 'Seok-Gi Noh', '1971-08-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1705')
# dup skipped:  ('최영술', 'Young-Sool Choi', '1972-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1604')
# dup skipped:  ('이전진', 'Jeon-Jin Lee', '1972-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1679')
# dup skipped:  ('강규성', 'Gyu-Seong Kang', '1969-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1466')
# dup skipped:  ('김형균', 'Hyung-Gyun Kim', '1969-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1474')
# dup skipped:  ('조중석', 'Joong-Seok Cho', '1972-03-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1717')
# dup skipped:  ('권영일', 'Young-Il Kwon', '1968-01-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1616')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# newly added:  ('소상영', 'Sang-Young So', '1973-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1741')
# newly added:  ('조경택', 'Kyeong-Taek Cho', '1970-11-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12707')
# finished code:6, year: 1992
# newly added:  ('김종성', 'Jong-Sung Kim', '1969-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1736')
# newly added:  ('황일권', 'Il-Kwon Hwang', '1969-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1760')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# dup skipped:  ('안경현', 'Kyung-Hyun An', '1970-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10099')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('곽연수', 'Yeon-Su Kwak', '1967-03-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1430')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('이광우', 'Kwang-Woo Lee', '1965-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1426')
# dup skipped:  ('김동현', 'Dong-Hyun Kim', '1966-10-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1471')
# dup skipped:  ('강규성', 'Gyu-Seong Kang', '1969-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1466')
# dup skipped:  ('최동창', 'Dong-Chang Choi', '1965-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1311')
# dup skipped:  ('권명철', 'Myeong-Cheol Kwon', '1969-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1695')
# newly added:  ('박상근', 'Sang-Geun Park', '1970-07-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1773')
# dup skipped:  ('이상현', 'Sang-Hyun Lee', '1969-07-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1712')
# newly added:  ('김경원', 'Kyung-Won Kim', '1971-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1761')
# dup skipped:  ('구천서', 'Chun-Seo Gu', '1963-08-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1001')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('송명철', 'Myung-Chul Song', '1970-05-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1446')
# dup skipped:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# dup skipped:  ('김익재', 'Ik-Jae Kim', '1968-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1627')
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# dup skipped:  ('이진', 'Jin Lee ', '1966-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1461')
# dup skipped:  ('김보선', 'Bo-Sun Kim', '1966-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1546')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# dup skipped:  ('안대환', 'Dae-Hwan An', '1962-09-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1339')
# dup skipped:  ('장호연', 'Ho-Yeon Jang', '1960-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1177')
# dup skipped:  ('길홍규', 'Hong-Gyu Gil', '1965-03-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1378')
# dup skipped:  ('김광림', 'Gwang-Lim Kim', '1961-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1203')
# dup skipped:  ('구동우', 'Dong-Woo Gu', '1966-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1468')
# dup skipped:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('김진규', 'Jin-Kyu Kim', '1962-06-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=15156')
# newly added:  ('조영상', 'Young-Sang Cho', '1970-10-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1557')
# dup skipped:  ('장원진', 'Won-Jin Jang', '1969-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1682')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho', '1970-11-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12707')
# newly added:  ('추성건', 'Sung-Geon Chu', '1970-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1757')
# newly added:  ('김민호', 'Min-Ho Kim', '1969-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1724')
# dup skipped:  ('강영수', 'Young-Soo Kang', '1965-02-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1428')
# dup skipped:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# newly added:  ('이용호', 'Young-Ho Lee', '1970-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1777')
# dup skipped:  ('하창우', 'Chang-Woo Ha', '1969-10-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1419')
# dup skipped:  ('김인철', 'In-Chul Kim', '1974-08-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1656')
# dup skipped:  ('김만조', 'Man-Jo Kim', '1969-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1696')
# dup skipped:  ('노석기', 'Seok-Gi Noh', '1971-08-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1705')
# dup skipped:  ('최영술', 'Young-Sool Choi', '1972-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1604')
# dup skipped:  ('이전진', 'Jeon-Jin Lee', '1972-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1679')
# dup skipped:  ('조중석', 'Joong-Seok Cho', '1972-03-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1717')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# dup skipped:  ('소상영', 'Sang-Young So', '1973-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1741')
# finished code:6, year: 1993
# dup skipped:  ('황일권', 'Il-Kwon Hwang', '1969-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1760')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# dup skipped:  ('안경현', 'Kyung-Hyun An', '1970-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10099')
# dup skipped:  ('심정수', 'Jung-Soo Sim', '1975-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1811')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('곽연수', 'Yeon-Su Kwak', '1967-03-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1430')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('이광우', 'Kwang-Woo Lee', '1965-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1426')
# dup skipped:  ('강규성', 'Gyu-Seong Kang', '1969-03-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1466')
# newly added:  ('한태균', 'Tae-Kyun Han', '1971-03-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1863')
# dup skipped:  ('권명철', 'Myeong-Cheol Kwon', '1969-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1695')
# dup skipped:  ('박상근', 'Sang-Geun Park', '1970-07-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1773')
# dup skipped:  ('김경원', 'Kyung-Won Kim', '1971-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1761')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('송명철', 'Myung-Chul Song', '1970-05-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1446')
# dup skipped:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# dup skipped:  ('김익재', 'Ik-Jae Kim', '1968-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1627')
# newly added:  ('이도형', 'Do-Hyung Lee', '1975-05-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10543')
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# newly added:  ('홍우태', 'Woo-Tai Hong', '1971-11-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1864')
# newly added:  ('류택현', 'Taek-Hyun Ryu', '1971-10-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10507')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# newly added:  ('나영철', 'Young-Chul Na', '1971-10-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1846')
# dup skipped:  ('장호연', 'Ho-Yeon Jang', '1960-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1177')
# newly added:  ('윤기수', 'Ki-soo Yoon', '1971-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1814')
# dup skipped:  ('구동우', 'Dong-Woo Gu', '1966-12-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1468')
# dup skipped:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('조영상', 'Young-Sang Cho', '1970-10-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1557')
# dup skipped:  ('장원진', 'Won-Jin Jang', '1969-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1682')
# dup skipped:  ('조경택', 'Kyeong-Taek Cho', '1970-11-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=12707')
# dup skipped:  ('추성건', 'Sung-Geon Chu', '1970-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1757')
# dup skipped:  ('김민호', 'Min-Ho Kim', '1969-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1724')
# dup skipped:  ('김종성', 'Jong-Sung Kim', '1969-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1736')
# dup skipped:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# dup skipped:  ('강영수', 'Young-Soo Kang', '1965-02-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1428')
# dup skipped:  ('이용호', 'Young-Ho Lee', '1970-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1777')
# dup skipped:  ('하창우', 'Chang-Woo Ha', '1969-10-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1419')
# dup skipped:  ('김인철', 'In-Chul Kim', '1974-08-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1656')
# newly added:  ('함석원', 'Seok-Won Ham', '1975-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1832')
# newly added:  ('조연제', 'Yeon-Je Cho', '1975-06-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1825')
# dup skipped:  ('최영술', 'Young-Sool Choi', '1972-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1604')
# newly added:  ('김명호', 'Myung-Ho Kim', '1975-08-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1793')
# dup skipped:  ('이전진', 'Jeon-Jin Lee', '1972-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1679')
# newly added:  ('박종무', 'Jong-Moo Park', '1975-03-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1806')
# dup skipped:  ('조중석', 'Joong-Seok Cho', '1972-03-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1717')
# newly added:  ('길랑균', 'Lang-Gyun Gil', '1968-10-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1791')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# newly added:  ('김정규', 'Jung-Kyu Kim', '1973-08-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1798')
# newly added:  ('공유선', 'Yu-Sun Gong', '1974-08-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1790')
# dup skipped:  ('소상영', 'Sang-Young So', '1973-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1741')
# dup skipped:  ('김광현', 'Kwang-Hyun Kim', '1971-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1792')
# newly added:  ('마원성', 'Won-Seong Ma', '1974-04-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1847')
# finished code:6, year: 1994
# dup skipped:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('황일권', 'Il-Kwon Hwang', '1969-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1760')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# dup skipped:  ('안경현', 'Kyung-Hyun An', '1970-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10099')
# dup skipped:  ('윤기수', 'Ki-soo Yoon', '1971-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1814')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# newly added:  ('정수근', 'Soo-Keun Jung', '1977-01-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10264')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('이광우', 'Kwang-Woo Lee', '1965-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1426')
# dup skipped:  ('한태균', 'Tae-Kyun Han', '1971-03-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1863')
# dup skipped:  ('권명철', 'Myeong-Cheol Kwon', '1969-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1695')
# dup skipped:  ('박상근', 'Sang-Geun Park', '1970-07-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1773')
# newly added:  ('여준홍', 'Jun-Hong Yeo', '1976-04-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1961')
# dup skipped:  ('김경원', 'Kyung-Won Kim', '1971-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1761')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('송명철', 'Myung-Chul Song', '1970-05-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1446')
# dup skipped:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# dup skipped:  ('김익재', 'Ik-Jae Kim', '1968-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1627')
# dup skipped:  ('이도형', 'Do-Hyung Lee', '1975-05-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10543')
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# dup skipped:  ('홍우태', 'Woo-Tai Hong', '1971-11-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1864')
# dup skipped:  ('류택현', 'Taek-Hyun Ryu', '1971-10-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10507')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# dup skipped:  ('나영철', 'Young-Chul Na', '1971-10-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1846')
# dup skipped:  ('장호연', 'Ho-Yeon Jang', '1960-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1177')
# dup skipped:  ('심정수', 'Jung-Soo Sim', '1975-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1811')
# newly added:  ('서석영', 'Seok-Young Seo', '1972-04-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1881')
# newly added:  ('김유봉', 'Yu-Bong Kim', '1976-06-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1897')
# dup skipped:  ('진필중', 'Pil-Jung Jin', '1972-10-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1894')
# newly added:  ('송재용', 'Jae-Yong Song', '1972-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1903')
# dup skipped:  ('장원진', 'Won-Jin Jang', '1969-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1682')
# newly added:  ('전형도', 'Hyung-Do Jeon', '1971-10-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1823')
# dup skipped:  ('추성건', 'Sung-Geon Chu', '1970-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1757')
# dup skipped:  ('김민호', 'Min-Ho Kim', '1969-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1724')
# dup skipped:  ('김종성', 'Jong-Sung Kim', '1969-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1736')
# dup skipped:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# dup skipped:  ('이용호', 'Young-Ho Lee', '1970-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1777')
# dup skipped:  ('함석원', 'Seok-Won Ham', '1975-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1832')
# dup skipped:  ('최영술', 'Young-Sool Choi', '1972-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1604')
# dup skipped:  ('이전진', 'Jeon-Jin Lee', '1972-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1679')
# dup skipped:  ('조중석', 'Joong-Seok Cho', '1972-03-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1717')
# dup skipped:  ('길랑균', 'Lang-Gyun Gil', '1968-10-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1791')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# dup skipped:  ('김정규', 'Jung-Kyu Kim', '1973-08-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1798')
# dup skipped:  ('소상영', 'Sang-Young So', '1973-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1741')
# dup skipped:  ('김광현', 'Kwang-Hyun Kim', '1971-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1792')
# dup skipped:  ('마원성', 'Won-Seong Ma', '1974-04-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1847')
# newly added:  ('이보형', 'Bo-Hyung Lee', '1972-04-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1888')
# finished code:6, year: 1995
# newly added:  ('박찬협', 'Chan-Hyub Park', '1977-05-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=2151')
# newly added:  ('한명윤', 'Myung-Yoon Han', '1977-09-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1969')
# dup skipped:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('박현영', 'Hyun-Young Park', '1968-08-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1347')
# dup skipped:  ('안경현', 'Kyung-Hyun An', '1970-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10099')
# dup skipped:  ('윤기수', 'Ki-soo Yoon', '1971-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1814')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('임형석', 'Hyung-Seok Lim', '1968-01-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1524')
# dup skipped:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('정수근', 'Soo-Keun Jung', '1977-01-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10264')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# dup skipped:  ('이광우', 'Kwang-Woo Lee', '1965-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1426')
# newly added:  ('박석안', 'Seok-An Park', '1972-04-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1931')
# dup skipped:  ('황일권', 'Il-Kwon Hwang', '1969-06-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1760')
# dup skipped:  ('한태균', 'Tae-Kyun Han', '1971-03-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1863')
# dup skipped:  ('권명철', 'Myeong-Cheol Kwon', '1969-10-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1695')
# dup skipped:  ('박상근', 'Sang-Geun Park', '1970-07-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1773')
# dup skipped:  ('여준홍', 'Jun-Hong Yeo', '1976-04-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1961')
# dup skipped:  ('김경원', 'Kyung-Won Kim', '1971-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1761')
# dup skipped:  ('박철순', 'Cheol-Sun Park', '1956-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1105')
# dup skipped:  ('김태형', 'Tae-Hyeong Kim', '1967-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11472')
# newly added:  ('최기문', 'Ki-Moon Choi', '1973-06-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=14231')
# dup skipped:  ('이도형', 'Do-Hyung Lee', '1975-05-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10543')
# dup skipped:  ('홍길남', 'Gil-Nam Hong', '1971-02-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1495')
# dup skipped:  ('홍우태', 'Woo-Tai Hong', '1971-11-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1864')
# dup skipped:  ('류택현', 'Taek-Hyun Ryu', '1971-10-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10507')
# dup skipped:  ('김형석', 'Hyung-Seok Kim', '1962-08-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1239')
# dup skipped:  ('최용희', 'Yong-Hee Choi', '1972-04-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1860')
# dup skipped:  ('심정수', 'Jung-Soo Sim', '1975-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1811')
# dup skipped:  ('서석영', 'Seok-Young Seo', '1972-04-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1881')
# dup skipped:  ('김유봉', 'Yu-Bong Kim', '1976-06-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1897')
# dup skipped:  ('진필중', 'Pil-Jung Jin', '1972-10-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1894')
# dup skipped:  ('송재용', 'Jae-Yong Song', '1972-03-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1903')
# dup skipped:  ('장원진', 'Won-Jin Jang', '1969-06-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1682')
# dup skipped:  ('강영수', 'Young-Soo Kang', '1973-06-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1918')
# dup skipped:  ('전형도', 'Hyung-Do Jeon', '1971-10-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1823')
# dup skipped:  ('추성건', 'Sung-Geon Chu', '1970-08-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1757')
# dup skipped:  ('김민호', 'Min-Ho Kim', '1969-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1724')
# dup skipped:  ('김종성', 'Jong-Sung Kim', '1969-07-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1736')
# dup skipped:  ('김상호', 'Sang-Ho Kim', '1965-10-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1380')
# dup skipped:  ('이용호', 'Young-Ho Lee', '1970-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1777')
# dup skipped:  ('이보형', 'Bo-Hyung Lee', '1972-04-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1888')
# dup skipped:  ('함석원', 'Seok-Won Ham', '1975-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1832')
# newly added:  ('박명환', 'Myung-Hwan Park', '1977-06-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10510')
# newly added:  ('홍재호', 'Jae-Ho Hong', '1974-02-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1947')
# dup skipped:  ('이전진', 'Jeon-Jin Lee', '1972-11-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1679')
# dup skipped:  ('조중석', 'Joong-Seok Cho', '1972-03-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1717')
# dup skipped:  ('김상진', 'Sang-Jin Kim', '1970-03-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1624')
# dup skipped:  ('김정규', 'Jung-Kyu Kim', '1973-08-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1798')
# dup skipped:  ('소상영', 'Sang-Young So', '1973-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1741')
# dup skipped:  ('김광현', 'Kwang-Hyun Kim', '1971-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1792')
# dup skipped:  ('마원성', 'Won-Seong Ma', '1974-04-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1847')
# finished code:6, year: 1996
# dup skipped:  ('박찬협', 'Chan-Hyub Park', '1977-05-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=2151')
# newly added:  ('문희성', 'Hee-Sung Moon', '1973-02-22', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1979')
# newly added:  ('이경필', 'Kyung-Pil Lee', '1974-05-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=2011')
# dup skipped:  ('한명윤', 'Myung-Yoon Han', '1977-09-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1969')
# dup skipped:  ('강병규', 'Byung-Kyu Kang', '1972-05-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1613')
# dup skipped:  ('안경현', 'Kyung-Hyun An', '1970-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10099')
# dup skipped:  ('윤기수', 'Ki-soo Yoon', '1971-03-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1814')
# newly added:  ('강규철', 'Kyu-Chul Kang', '1974-05-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1970')
# dup skipped:  ('이명수', 'Myong-Soo Lee', '1966-07-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1450')
# dup skipped:  ('이종민', 'Jong-Min Lee', '1972-12-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1595')
# dup skipped:  ('강형석', 'Hyung-Seok Kang', '1968-01-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1501')
# dup skipped:  ('정수근', 'Soo-Keun Jung', '1977-01-20', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10264')
# dup skipped:  ('김종석', 'Jong-Seok Kim', '1971-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=1436')
# ...
# dup skipped:  ('천상웅', 'Sang-Ung Cheon', '1991-05-30', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10735')
# dup skipped:  ('오현택', 'Hyun-Taek Oh', '1985-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10210')
# dup skipped:  ('이원석', 'Won-Seok Lee', '1986-10-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10180')
# dup skipped:  ('임재철', 'Jae-Chul Lim', '1976-04-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10193')
# dup skipped:  ('김동주', 'Dong-Joo Kim', '1976-02-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10173')
# dup skipped:  ('양현', 'Hyeon Yang', '1992-08-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10730')
# dup skipped:  ('김창훈', 'Chang-Hoon Kim', '1985-10-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10671')
# dup skipped:  ('김강률', 'Kang-Ryul Kim', '1988-08-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10690')
# dup skipped:  ('홍성흔', 'Seong-Heun Hong', '1977-02-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10256')
# dup skipped:  ('정대현', 'Dae-Hyeon Jeong', '1991-07-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10224')
# dup skipped:  ('니코스키', 'Christopher John Nitkowski', '1973-03-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10204')
# dup skipped:  ('양의지', 'Eui-Ji Yang', '1987-06-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10165')
# dup skipped:  ('왓슨', 'Matthew Kyle Watson', '1978-09-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10190')
# dup skipped:  ('김태영', 'Tae-Yeoung Kim', '1980-04-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10198')
# dup skipped:  ('김명제', 'Myeong-Jae Kim', '1987-01-05', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10197')
# dup skipped:  ('이석만', 'Seok-Man Lee', '1980-05-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10215')
# dup skipped:  ('김명성', 'Myeong-Seong Kim', '1988-04-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10680')
# dup skipped:  ('유희관', 'Hee-Gwan Yoo', '1986-06-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10213')
# dup skipped:  ('핸킨스', 'Derek James Hankins', '1983-07-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11181')
# dup skipped:  ('프록터', 'Scott Christopher Proctor', '1977-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10919')
# newly added:  ('올슨', 'Garrett Olson', '1983-10-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11177')
# dup skipped:  ('세데뇨', 'Juan Cedeño', '1983-08-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10209')
# dup skipped:  ('정수빈', 'Soo-Bin Jeong', '1990-10-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10195')
# dup skipped:  ('김선우', 'Sun-Woo Kim', '1977-09-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10200')
# dup skipped:  ('강동연', 'Dong-Yeon Kang', '1992-12-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10883')
# dup skipped:  ('진야곱', 'Ya-Gob Jin', '1989-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10229')
# newly added:  ('정혁진', 'Hyeok-Jin Jung', '1994-07-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11093')
# dup skipped:  ('오재일', 'Jae-Il Oh', '1986-10-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10400')
# dup skipped:  ('원용묵', 'Yong-Muk Won', '1986-06-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10212')
# dup skipped:  ('윤요한', 'Yo-han Yoon', '1989-05-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10214')
# dup skipped:  ('노경은', 'Kyeong-Eun Noh', '1984-03-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10203')
# dup skipped:  ('이종욱', 'Jong-Wook Lee', '1980-06-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10192')
# dup skipped:  ('니퍼트', 'Dustin Nippert', '1981-05-06', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10641')
# dup skipped:  ('정재훈', 'Jae-Hoon Jung', '1980-01-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10225')
# dup skipped:  ('윤명준', 'Myeong-Jun Yoon', '1989-06-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10885')
# dup skipped:  ('조규수', 'Gyu-Soo Jo', '1981-09-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10226')
# dup skipped:  ('박민석', 'Min-Seok Park', '1989-07-04', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10205')
# dup skipped:  ('최형록', 'Hyeong-rok Choi', '1989-08-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11208')
# dup skipped:  ('박세혁', 'Se-Hyuk Park', '1990-01-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10891')
# dup skipped:  ('이용찬', 'Yong-Chan Lee', '1989-01-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10217')
# dup skipped:  ('이정호', 'Jeong-Ho Lee', '1992-04-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10731')
# dup skipped:  ('홍상삼', 'Sang-Sam Hong', '1990-02-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10230')
# dup skipped:  ('이혜천', 'Hye-Chun Lee', '1979-03-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10642')
# dup skipped:  ('민병헌', 'Byeong-Heon Min', '1987-03-10', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10188')
# dup skipped:  ('김현수', 'Hyun-Soo Kim', '1988-01-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10187')
# dup skipped:  ('임태훈', 'Tae-Hun Lim', '1988-09-28', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10222')
# dup skipped:  ('김강', 'Kang Kim', '1988-10-16', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10547')
# dup skipped:  ('김재호', 'Jae-Ho Kim', '1985-03-21', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10174')
# dup skipped:  ('김준호', 'Jun-Ho Kim ', '1991-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10185')
# dup skipped:  ('한주성', 'Joo-Seong Han', '1995-02-26', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11203')
# dup skipped:  ('오장훈', 'Jang-Hun Oh', '1984-05-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10250')
# dup skipped:  ('장우람', 'Woo-Ram Jang', '1988-09-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10889')
# dup skipped:  ('배상현', 'Sang-Hyun Bae', '1990-10-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10176')
# dup skipped:  ('이현호', 'Hyeon-Ho Lee', '1992-07-14', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10677')
# dup skipped:  ('박건우', 'Geon-Woo Park', '1990-09-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10189')
# dup skipped:  ('이승학', 'Seung-Hak Lee', '1979-06-02', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10216')
# newly added:  ('김인태', 'In-Tae Kim', '1994-07-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11098')
# dup skipped:  ('신동규', 'Dong-Kyu Shin', '1989-10-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10896')
# dup skipped:  ('이현승', 'Hyun-Seung Lee', '1983-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10221')
# newly added:  ('함덕주', 'Deok-Ju Ham', '1995-01-13', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11094')
# dup skipped:  ('김경호', 'Gyeong-Ho Kim', '1995-07-31', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11207')
# dup skipped:  ('이우성', 'Woo-Sung Lee', '1994-07-17', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11099')
# dup skipped:  ('서동환', 'Dong-Hwan Seo', '1986-03-27', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10207')
# dup skipped:  ('천영웅', 'Young-Ung Cheon', '1994-03-23', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11096')
# dup skipped:  ('박종섭', 'Jong-Seop Park', '1983-04-18', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10175')
# dup skipped:  ('변시원', 'Si-Won Byun', '1993-04-01', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10882')
# dup skipped:  ('박민정', 'Min-Jeong Park', '1988-10-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10884')
# dup skipped:  ('송주영', 'Joo-Young Song', '1994-12-08', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11095')
# dup skipped:  ('정성훈', 'Sung-Hoon Jung', '1977-12-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10531')
# dup skipped:  ('안규영', 'Gyu-Young An', '1988-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10729')
# dup skipped:  ('곽용섭', 'Yong-Seob Kwak', '1983-02-03', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10464')
# newly added:  ('유창준', 'Chang-Jun Yoo', '1989-07-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11185')
# dup skipped:  ('지승민', 'Seung-Min Ji', '1978-09-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10228')
# dup skipped:  ('성영훈', 'Yeong-Hun Seong', '1990-06-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10208')
# dup skipped:  ('이정민', 'Jeong-Min Lee ', '1988-08-25', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10181')
# dup skipped:  ('김진수', 'Jin-Soo Kim', '1979-04-19', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10164')
# dup skipped:  ('이현민', 'Hyun-Min Lee', '1990-07-11', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10900')
# dup skipped:  ('권영준', 'Young-Jun Kwon', '1988-04-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10893')
# dup skipped:  ('김현민', 'Hyun-Min Kim', '1992-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10897')
# dup skipped:  ('백진우', 'Jin-Woo Baek', '1988-11-24', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10898')
# dup skipped:  ('이태오', 'Tae-Oh Lee', '1993-12-15', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10887')
# dup skipped:  ('강화영', 'Hwa-Yeong Kang', '1993-05-07', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10886')
# dup skipped:  ('여승철', 'Yeo Seung-cheol', '1984-05-29', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=11210')
# dup skipped:  ('오재원', 'Jae-Won Oh', '1985-02-09', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10178')
# finished code:6, year: 2013
# dup skipped:  ('안규영', 'Gyu-Young An', '1988-04-12', 'https://statiz.sporki.com/player/?m=playerinfo&p_no=10729')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 25
#      23 for player in players:
#      24     player_url = front_url + player.find("a")['href']
# ---> 25     player_data = session.fetch(player_url).content.decode("utf-8")
#      26     player_html = BSoup(player_data, "lxml")
#      28     # segment that contains Korean and English name of the player.
#
# File /opt/homebrew/anaconda3/Study/Baseball/script/helper/session.py:33, in Session.fetch(self, url)
#      31 def fetch(self, url : str) -> requests.Response:
# ---> 33     response = self.session.get(url)
#      34     self.handle_call_rate()
#      36     if response.status_code != 200:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/anaconda3/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /opt/homebrew/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/homebrew/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/homebrew/anaconda3/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File /opt/homebrew/anaconda3/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/anaconda3/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
