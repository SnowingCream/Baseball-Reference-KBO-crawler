# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
import csv
import os

# %%
session = Session()

# %%
front_url = "https://www.baseball-reference.com" # front part of URL in which hrefs will be concatenated on.

# %% [markdown]
# ## Dup Check Setup

# %%
# initial header row setup
file_path = '../data/br_player.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name_eng","date_of_birth", "url"]
        writer.writerow(header)

# %%
# initial header row setup
file_path = '../data/br_finished_team_year.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["year", "team"]
        writer.writerow(header)

# %%
# to filter duplicate
# both removed the header row
added_team_and_year = set([tuple(row) for row in csv.reader(open('../data/br_finished_team_year.csv', 'r'))][1:])
added_player = set([tuple(row) for row in csv.reader(open('../data/br_player.csv', 'r'))][1:])

# %% [markdown]
# ## Main Code

# %%
df = pd.read_csv('../data/br_team_year.csv')
team_urls = df.values.tolist() # all urls of KBO teams

# %%
for year, team, url in team_urls:

    if (str(year), team, url) in added_team_and_year:
        print(f"already done, skip over year: {year} team: {team}")
        continue
    
    team_data = session.fetch(url).content.decode("utf-8") # eacm team's data
    team_html = BSoup(team_data, "lxml")
    comment_wrapper = team_html.find(id="all_standard_roster") # tag that contains desired table as a comment inside
    comment = comment_wrapper.find(string=lambda text: isinstance(text, Comment)) # extract comment
    players = BSoup(comment, "lxml").find_all("tr")[1:] # convert to HTML without header row

    with open('../data/br_player.csv', 'a', newline='') as players_info:

        writer = csv.writer(players_info)
    
        for player in players:
            player_link = player.find('a') # ex) <a href="/register/player.fcgi?id=ahn---000seu">Seung Han Ahn</a>
    
            name_eng = player_link.text
            player_url = front_url + player_link['href']
            
            player_data = session.fetch(player_url).content.decode("utf-8")
            player_html = BSoup(player_data, "lxml")
            dob = player_html.find(id = "necro-birth")['data-birth']
    
            player_row = (name_eng, dob, player_url)
                
            if player_row not in added_player: # filter based on the unique id in the href link
                added_player.add(player_row) 
                writer.writerow(player_row) 
                print("newly added: ", player_row)
            else:
                print("dup skipped: ", player_row)


    print(f"Finished processing {year} {team}.")

    with open('../data/br_finished_team_year.csv', 'a', newline='') as done_team_year:
        writer2 = csv.writer(done_team_year)
        writer2.writerow((year, team, url))
        added_team_and_year.add((year, team, url))
# Out:
# already done, skip over name: 2024, year: Doosan Bears
# already done, skip over name: 2024, year: Hanwha Eagles
# already done, skip over name: 2024, year: Kia Tigers
# already done, skip over name: 2024, year: Kiwoom Heroes
# already done, skip over name: 2024, year: KT Wiz
# already done, skip over name: 2024, year: LG Twins
# already done, skip over name: 2024, year: Lotte Giants
# already done, skip over name: 2024, year: NC Dinos
# already done, skip over name: 2024, year: Samsung Lions
# already done, skip over name: 2024, year: SSG Landers
# already done, skip over name: 2023, year: Doosan Bears
# already done, skip over name: 2023, year: Hanwha Eagles
# already done, skip over name: 2023, year: Kia Tigers
# already done, skip over name: 2023, year: Kiwoom Heroes
# already done, skip over name: 2023, year: KT Wiz
# already done, skip over name: 2023, year: LG Twins
# already done, skip over name: 2023, year: Lotte Giants
# already done, skip over name: 2023, year: NC Dinos
# already done, skip over name: 2023, year: Samsung Lions
# already done, skip over name: 2023, year: SSG Landers
# already done, skip over name: 2022, year: Doosan Bears
# already done, skip over name: 2022, year: Hanwha Eagles
# already done, skip over name: 2022, year: Kia Tigers
# already done, skip over name: 2022, year: Kiwoom Heroes
# already done, skip over name: 2022, year: KT Wiz
# already done, skip over name: 2022, year: LG Twins
# already done, skip over name: 2022, year: Lotte Giants
# already done, skip over name: 2022, year: NC Dinos
# already done, skip over name: 2022, year: Samsung Lions
# already done, skip over name: 2022, year: SSG Landers
# already done, skip over name: 2021, year: Doosan Bears
# already done, skip over name: 2021, year: Hanwha Eagles
# already done, skip over name: 2021, year: Kia Tigers
# already done, skip over name: 2021, year: Kiwoom Heroes
# already done, skip over name: 2021, year: KT Wiz
# already done, skip over name: 2021, year: LG Twins
# already done, skip over name: 2021, year: Lotte Giants
# already done, skip over name: 2021, year: NC Dinos
# already done, skip over name: 2021, year: Samsung Lions
# already done, skip over name: 2021, year: SSG Landers
# already done, skip over name: 2020, year: Doosan Bears
# already done, skip over name: 2020, year: Hanwha Eagles
# already done, skip over name: 2020, year: Kia Tigers
# already done, skip over name: 2020, year: Kiwoom Heroes
# already done, skip over name: 2020, year: KT Wiz
# already done, skip over name: 2020, year: LG Twins
# already done, skip over name: 2020, year: Lotte Giants
# already done, skip over name: 2020, year: NC Dinos
# already done, skip over name: 2020, year: Samsung Lions
# already done, skip over name: 2020, year: SK Wyverns
# already done, skip over name: 2019, year: Doosan Bears
# already done, skip over name: 2019, year: Hanwha Eagles
# already done, skip over name: 2019, year: Kia Tigers
# already done, skip over name: 2019, year: Kiwoom Heroes
# already done, skip over name: 2019, year: KT Wiz
# already done, skip over name: 2019, year: LG Twins
# already done, skip over name: 2019, year: Lotte Giants
# already done, skip over name: 2019, year: NC Dinos
# already done, skip over name: 2019, year: Samsung Lions
# already done, skip over name: 2019, year: SK Wyverns
# already done, skip over name: 2018, year: Doosan Bears
# already done, skip over name: 2018, year: Hanwha Eagles
# already done, skip over name: 2018, year: Kia Tigers
# already done, skip over name: 2018, year: KT Wiz
# already done, skip over name: 2018, year: LG Twins
# already done, skip over name: 2018, year: Lotte Giants
# already done, skip over name: 2018, year: NC Dinos
# already done, skip over name: 2018, year: Nexen Heroes
# already done, skip over name: 2018, year: Samsung Lions
# already done, skip over name: 2018, year: SK Wyverns
# already done, skip over name: 2017, year: Doosan Bears
# already done, skip over name: 2017, year: Hanwha Eagles
# already done, skip over name: 2017, year: Kia Tigers
# already done, skip over name: 2017, year: KT Wiz
# already done, skip over name: 2017, year: LG Twins
# already done, skip over name: 2017, year: Lotte Giants
# already done, skip over name: 2017, year: NC Dinos
# already done, skip over name: 2017, year: Nexen Heroes
# already done, skip over name: 2017, year: Samsung Lions
# already done, skip over name: 2017, year: SK Wyverns
# already done, skip over name: 2016, year: Doosan Bears
# already done, skip over name: 2016, year: Hanwha Eagles
# already done, skip over name: 2016, year: Kia Tigers
# already done, skip over name: 2016, year: KT Wiz
# already done, skip over name: 2016, year: LG Twins
# already done, skip over name: 2016, year: Lotte Giants
# already done, skip over name: 2016, year: NC Dinos
# already done, skip over name: 2016, year: Nexen Heroes
# already done, skip over name: 2016, year: Samsung Lions
# already done, skip over name: 2016, year: SK Wyverns
# already done, skip over name: 2015, year: Doosan Bears
# already done, skip over name: 2015, year: Hanwha Eagles
# already done, skip over name: 2015, year: Kia Tigers
# already done, skip over name: 2015, year: KT Wiz
# already done, skip over name: 2015, year: LG Twins
# already done, skip over name: 2015, year: Lotte Giants
# already done, skip over name: 2015, year: NC Dinos
# already done, skip over name: 2015, year: Nexen Heroes
# already done, skip over name: 2015, year: Samsung Lions
# already done, skip over name: 2015, year: SK Wyverns
# already done, skip over name: 2014, year: Doosan Bears
# already done, skip over name: 2014, year: Hanwha Eagles
# already done, skip over name: 2014, year: Kia Tigers
# already done, skip over name: 2014, year: LG Twins
# already done, skip over name: 2014, year: Lotte Giants
# already done, skip over name: 2014, year: NC Dinos
# already done, skip over name: 2014, year: Nexen Heroes
# already done, skip over name: 2014, year: Samsung Lions
# already done, skip over name: 2014, year: SK Wyverns
# already done, skip over name: 2013, year: Doosan Bears
# already done, skip over name: 2013, year: Hanwha Eagles
# already done, skip over name: 2013, year: Kia Tigers
# already done, skip over name: 2013, year: LG Twins
# already done, skip over name: 2013, year: Lotte Giants
# already done, skip over name: 2013, year: NC Dinos
# already done, skip over name: 2013, year: Nexen Heroes
# already done, skip over name: 2013, year: Samsung Lions
# already done, skip over name: 2013, year: SK Wyverns
# already done, skip over name: 2012, year: Doosan Bears
# already done, skip over name: 2012, year: Hanwha Eagles
# already done, skip over name: 2012, year: Kia Tigers
# already done, skip over name: 2012, year: LG Twins
# already done, skip over name: 2012, year: Lotte Giants
# already done, skip over name: 2012, year: Nexen Heroes
# already done, skip over name: 2012, year: Samsung Lions
# already done, skip over name: 2012, year: SK Wyverns
# already done, skip over name: 2011, year: Doosan Bears
# already done, skip over name: 2011, year: Hanwha Eagles
# already done, skip over name: 2011, year: Kia Tigers
# already done, skip over name: 2011, year: LG Twins
# already done, skip over name: 2011, year: Lotte Giants
# already done, skip over name: 2011, year: Nexen Heroes
# already done, skip over name: 2011, year: Samsung Lions
# already done, skip over name: 2011, year: SK Wyverns
# already done, skip over name: 2010, year: Doosan Bears
# already done, skip over name: 2010, year: Hanwha Eagles
# already done, skip over name: 2010, year: Kia Tigers
# already done, skip over name: 2010, year: LG Twins
# already done, skip over name: 2010, year: Lotte Giants
# already done, skip over name: 2010, year: Nexen Heroes
# already done, skip over name: 2010, year: Samsung Lions
# already done, skip over name: 2010, year: SK Wyverns
# already done, skip over name: 2009, year: Doosan Bears
# already done, skip over name: 2009, year: Hanwha Eagles
# already done, skip over name: 2009, year: Kia Tigers
# already done, skip over name: 2009, year: LG Twins
# already done, skip over name: 2009, year: Lotte Giants
# already done, skip over name: 2009, year: Samsung Lions
# already done, skip over name: 2009, year: SK Wyverns
# already done, skip over name: 2009, year: Woori Heroes
# already done, skip over name: 2008, year: Doosan Bears
# already done, skip over name: 2008, year: Hanwha Eagles
# already done, skip over name: 2008, year: Kia Tigers
# already done, skip over name: 2008, year: LG Twins
# already done, skip over name: 2008, year: Lotte Giants
# already done, skip over name: 2008, year: Samsung Lions
# already done, skip over name: 2008, year: SK Wyverns
# already done, skip over name: 2008, year: Woori Heroes
# already done, skip over name: 2007, year: Doosan Bears
# already done, skip over name: 2007, year: Hanwha Eagles
# already done, skip over name: 2007, year: Hyundai Unicorns
# already done, skip over name: 2007, year: Kia Tigers
# already done, skip over name: 2007, year: LG Twins
# already done, skip over name: 2007, year: Lotte Giants
# already done, skip over name: 2007, year: Samsung Lions
# already done, skip over name: 2007, year: SK Wyverns
# already done, skip over name: 2006, year: Doosan Bears
# already done, skip over name: 2006, year: Hanwha Eagles
# already done, skip over name: 2006, year: Hyundai Unicorns
# already done, skip over name: 2006, year: Kia Tigers
# already done, skip over name: 2006, year: LG Twins
# already done, skip over name: 2006, year: Lotte Giants
# already done, skip over name: 2006, year: Samsung Lions
# already done, skip over name: 2006, year: SK Wyverns
# already done, skip over name: 2005, year: Doosan Bears
# already done, skip over name: 2005, year: Hanwha Eagles
# already done, skip over name: 2005, year: Hyundai Unicorns
# already done, skip over name: 2005, year: Kia Tigers
# already done, skip over name: 2005, year: LG Twins
# already done, skip over name: 2005, year: Lotte Giants
# already done, skip over name: 2005, year: Samsung Lions
# already done, skip over name: 2005, year: SK Wyverns
# already done, skip over name: 2004, year: Doosan Bears
# already done, skip over name: 2004, year: Hanwha Eagles
# already done, skip over name: 2004, year: Hyundai Unicorns
# already done, skip over name: 2004, year: Kia Tigers
# already done, skip over name: 2004, year: LG Twins
# already done, skip over name: 2004, year: Lotte Giants
# already done, skip over name: 2004, year: Samsung Lions
# already done, skip over name: 2004, year: SK Wyverns
# already done, skip over name: 2003, year: Doosan Bears
# already done, skip over name: 2003, year: Hanwha Eagles
# already done, skip over name: 2003, year: Hyundai Unicorns
# already done, skip over name: 2003, year: Kia Tigers
# already done, skip over name: 2003, year: LG Twins
# already done, skip over name: 2003, year: Lotte Giants
# already done, skip over name: 2003, year: Samsung Lions
# already done, skip over name: 2003, year: SK Wyverns
# already done, skip over name: 2002, year: Doosan Bears
# already done, skip over name: 2002, year: Hanwha Eagles
# already done, skip over name: 2002, year: Hyundai Unicorns
# already done, skip over name: 2002, year: Kia Tigers
# already done, skip over name: 2002, year: LG Twins
# already done, skip over name: 2002, year: Lotte Giants
# already done, skip over name: 2002, year: Samsung Lions
# already done, skip over name: 2002, year: SK Wyverns
# already done, skip over name: 2001, year: Doosan Bears
# already done, skip over name: 2001, year: Hanwha Eagles
# already done, skip over name: 2001, year: Hyundai Unicorns
# already done, skip over name: 2001, year: Kia Tigers
# already done, skip over name: 2001, year: LG Twins
# already done, skip over name: 2001, year: Lotte Giants
# already done, skip over name: 2001, year: Samsung Lions
# already done, skip over name: 2001, year: SK Wyverns
# already done, skip over name: 2000, year: Doosan Bears
# already done, skip over name: 2000, year: Haitai Tigers
# already done, skip over name: 2000, year: Hanwha Eagles
# already done, skip over name: 2000, year: Hyundai Unicorns
# already done, skip over name: 2000, year: LG Twins
# already done, skip over name: 2000, year: Lotte Giants
# already done, skip over name: 2000, year: Samsung Lions
# already done, skip over name: 2000, year: SK Wyverns
# already done, skip over name: 1999, year: Doosan Bears
# already done, skip over name: 1999, year: Haitai Tigers
# already done, skip over name: 1999, year: Hanwha Eagles
# already done, skip over name: 1999, year: Hyundai Unicorns
# already done, skip over name: 1999, year: LG Twins
# already done, skip over name: 1999, year: Lotte Giants
# already done, skip over name: 1999, year: Samsung Lions
# already done, skip over name: 1999, year: Ssangbangwool Raiders
# already done, skip over name: 1998, year: Haitai Tigers
# already done, skip over name: 1998, year: Hanwha Eagles
# already done, skip over name: 1998, year: Hyundai Unicorns
# already done, skip over name: 1998, year: LG Twins
# already done, skip over name: 1998, year: Lotte Giants
# already done, skip over name: 1998, year: OB Bears
# already done, skip over name: 1998, year: Samsung Lions
# already done, skip over name: 1998, year: Ssangbangwool Raiders
# already done, skip over name: 1997, year: Haitai Tigers
# already done, skip over name: 1997, year: Hanwha Eagles
# already done, skip over name: 1997, year: Hyundai Unicorns
# already done, skip over name: 1997, year: LG Twins
# already done, skip over name: 1997, year: Lotte Giants
# already done, skip over name: 1997, year: OB Bears
# already done, skip over name: 1997, year: Samsung Lions
# already done, skip over name: 1997, year: Ssangbangwool Raiders
# already done, skip over name: 1996, year: Haitai Tigers
# already done, skip over name: 1996, year: Hanwha Eagles
# already done, skip over name: 1996, year: Hyundai Unicorns
# already done, skip over name: 1996, year: LG Twins
# already done, skip over name: 1996, year: Lotte Giants
# already done, skip over name: 1996, year: OB Bears
# already done, skip over name: 1996, year: Samsung Lions
# already done, skip over name: 1996, year: Ssangbangwool Raiders
# already done, skip over name: 1995, year: Haitai Tigers
# already done, skip over name: 1995, year: Hanwha Eagles
# already done, skip over name: 1995, year: LG Twins
# already done, skip over name: 1995, year: Lotte Giants
# already done, skip over name: 1995, year: OB Bears
# already done, skip over name: 1995, year: Pacific Dolphins
# already done, skip over name: 1995, year: Samsung Lions
# already done, skip over name: 1995, year: Ssangbangwool Raiders
# already done, skip over name: 1994, year: Haitai Tigers
# already done, skip over name: 1994, year: Hanwha Eagles
# already done, skip over name: 1994, year: LG Twins
# already done, skip over name: 1994, year: Lotte Giants
# already done, skip over name: 1994, year: OB Bears
# already done, skip over name: 1994, year: Pacific Dolphins
# already done, skip over name: 1994, year: Samsung Lions
# already done, skip over name: 1994, year: Ssangbangwool Raiders
# already done, skip over name: 1993, year: Binggre Eagles
# already done, skip over name: 1993, year: Haitai Tigers
# already done, skip over name: 1993, year: LG Twins
# already done, skip over name: 1993, year: Lotte Giants
# already done, skip over name: 1993, year: OB Bears
# already done, skip over name: 1993, year: Pacific Dolphins
# already done, skip over name: 1993, year: Samsung Lions
# already done, skip over name: 1993, year: Ssangbangwool Raiders
# already done, skip over name: 1992, year: Binggre Eagles
# already done, skip over name: 1992, year: Haitai Tigers
# already done, skip over name: 1992, year: LG Twins
# already done, skip over name: 1992, year: Lotte Giants
# already done, skip over name: 1992, year: OB Bears
# already done, skip over name: 1992, year: Pacific Dolphins
# already done, skip over name: 1992, year: Samsung Lions
# already done, skip over name: 1992, year: Ssangbangwool Raiders
# already done, skip over name: 1991, year: Binggre Eagles
# already done, skip over name: 1991, year: Haitai Tigers
# already done, skip over name: 1991, year: LG Twins
# already done, skip over name: 1991, year: Lotte Giants
# already done, skip over name: 1991, year: OB Bears
# already done, skip over name: 1991, year: Pacific Dolphins
# response status not 200: 403
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 10
#       8 team_html = BSoup(team_data, "lxml")
#       9 comment_wrapper = team_html.find(id="all_standard_roster") # tag that contains desired table as a comment inside
# ---> 10 comment = comment_wrapper.find(string=lambda text: isinstance(text, Comment)) # extract comment
#      11 players = BSoup(comment, "lxml").find_all("tr")[1:] # convert to HTML without header row
#      13 with open('../data/br_player.csv', 'a', newline='') as players_info:
#
# AttributeError: 'NoneType' object has no attribute 'find'
