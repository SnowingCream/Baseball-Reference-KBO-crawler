# %%
import pandas as pd
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
import csv

# %%
session = Session()

# %%
front_url = "https://www.baseball-reference.com" # front part of URL in which hrefs will be concatenated on.

added_player_id = set() # to filter duplicate

# %%
df = pd.read_csv('../data/br_team_year.csv')
team_url_list = df.values.tolist() # all urls of KBO teams

# %%
with open('../data/br_player.csv', 'w', newline='') as file:

    writer = csv.writer(file)
    
    header = ["name_eng", "url"]
    writer.writerow(header)

    for name, year, url in team_url_list:
        team_data = session.fetch(url).content.decode("utf-8") # eacm team's data
        comment_wrapper = BSoup(team_data, "lxml").find(id="all_standard_roster") # tag that contains desired table as a comment inside
        comment = comment_wrapper.find(string=lambda text: isinstance(text, Comment)) # extract comment
        player_table = BSoup(comment, "lxml").find_all("tr")[1:] # convert to HTML without header row

        for player in player_table:
            player_info = player.find('a') # ex) <a href="/register/player.fcgi?id=ahn---000seu">Seung Han Ahn</a>

            if player_info["href"].split("?id=")[1] not in added_player_id: # filter based on the unique id in the href link
                writer.writerow([player_info.text, front_url + player_info['href']]) # write player name and url
                added_player_id.add(player_info["href"].split("?id=")[1]) # save id in the filter


        print(f"Finished processing {year} {name}.")
# Out:
# Finished processing Doosan Bears 2024.
# Finished processing Hanwha Eagles 2024.
# Finished processing Kia Tigers 2024.
# Finished processing Kiwoom Heroes 2024.
# Finished processing KT Wiz 2024.
# Finished processing LG Twins 2024.
# Finished processing Lotte Giants 2024.
# Finished processing NC Dinos 2024.
# Finished processing Samsung Lions 2024.
# have called 10 apis: 1 min break starts
# Finished processing SSG Landers 2024.
# Finished processing Doosan Bears 2023.
# Finished processing Hanwha Eagles 2023.
# Finished processing Kia Tigers 2023.
# Finished processing Kiwoom Heroes 2023.
# Finished processing KT Wiz 2023.
# Finished processing LG Twins 2023.
# Finished processing Lotte Giants 2023.
# Finished processing NC Dinos 2023.
# Finished processing Samsung Lions 2023.
# have called 20 apis: 1 min break starts
# Finished processing SSG Landers 2023.
# Finished processing Doosan Bears 2022.
# Finished processing Hanwha Eagles 2022.
# Finished processing Kia Tigers 2022.
# ...
