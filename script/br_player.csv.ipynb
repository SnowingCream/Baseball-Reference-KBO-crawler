# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
import csv
import os

# %%
session = Session()

# %%
front_url = "https://www.baseball-reference.com" # front part of URL in which hrefs will be concatenated on.

# %% [markdown]
# ## Dup Check Setup

# %%
# initial header row setup
file_path = '../data/br_player.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name_eng","date_of_birth", "url"]
        writer.writerow(header)

# %%
# initial header row setup
file_path = '../data/br_finished_team_year.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name", "year"]
        writer.writerow(header)

# %%
# to filter duplicate
# both removed the header row
added_team_and_year = set([tuple(row) for row in csv.reader(open('../data/br_finished_team_year.csv', 'r'))][1:])
added_player = set([tuple(row) for row in csv.reader(open('../data/br_player.csv', 'r'))][1:])

# %% [markdown]
# ## Main Code

# %%
df = pd.read_csv('../data/br_team_year.csv')
team_urls = df.values.tolist() # all urls of KBO teams

# %%
for name, year, url in team_urls:

    if (name, year) in added_team_and_year:
        print(f"already done, skip over name: {name}, year: {year}")
        continue
    
    team_data = session.fetch(url).content.decode("utf-8") # eacm team's data
    team_html = BSoup(team_data, "lxml")
    comment_wrapper = team_html.find(id="all_standard_roster") # tag that contains desired table as a comment inside
    comment = comment_wrapper.find(string=lambda text: isinstance(text, Comment)) # extract comment
    players = BSoup(comment, "lxml").find_all("tr")[1:] # convert to HTML without header row

    with open('../data/br_player.csv', 'a', newline='') as players_info:

        writer = csv.writer(players_info)
    
        for player in players:
            player_link = player.find('a') # ex) <a href="/register/player.fcgi?id=ahn---000seu">Seung Han Ahn</a>
    
            name_eng = player_link.text
            player_url = front_url + player_link['href']
            
            player_data = session.fetch(player_url).content.decode("utf-8")
            player_html = BSoup(player_data, "lxml")
            dob = player_html.find(id = "necro-birth")['data-birth']
    
            player_row = (name_eng, dob, player_url)
                
            if player_row not in added_player: # filter based on the unique id in the href link
                added_player.add(player_row) 
                writer.writerow(player_row) 
                print("newly added: ", player_row)
            else:
                print("dup skipped: ", player_row)


    print(f"Finished processing {name} {year}.")

    with open('../data/br_finished_team_year.csv', 'a', newline='') as done_team_year:
        writer2 = csv.writer(done_team_year)
        writer2.writerow((name, year))
        added_team_and_year.add((name, year))
# Out:
# newly added:  ('Seung Han Ahn', '1992-01-25', 'https://www.baseball-reference.com/register/player.fcgi?id=ahn---000seu')
# newly added:  ('Raúl Alcántara', '1992-12-04', 'https://www.baseball-reference.com/register/player.fcgi?id=alcant001rau')
# newly added:  ('Jordan Balazovic', '1998-09-17', 'https://www.baseball-reference.com/register/player.fcgi?id=balazo000jor')
# newly added:  ('Kyu Bin Chang', '2001-04-21', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-001kyu')
# newly added:  ('Ji Kang Choi', '2001-07-23', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000jik')
# newly added:  ('Jong In Choi', '2001-05-01', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--002jon')
# newly added:  ('Jun Ho Choi', '2004-06-03', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--002jun')
# newly added:  ('Seung Yong Choi', '2001-05-11', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--004seu')
# have called 10 apis: 1 min break starts
# newly added:  ('Won Joon Choi', '1994-12-21', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--002don')
# newly added:  ('Been Gwak', '1999-05-28', 'https://www.baseball-reference.com/register/player.fcgi?id=gwak--000bee')
# newly added:  ('Kyeong-min Ho', '1990-08-26', 'https://www.baseball-reference.com/register/player.fcgi?id=heo---000kye')
# newly added:  ('Geon Hui Hong', '1992-09-29', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000keo')
# newly added:  ('Seong Ho Hong', '1997-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--004seo')
# newly added:  ('Jong Sung Im', '2005-03-03', 'https://www.baseball-reference.com/register/player.fcgi?id=im----000jon')
# newly added:  ('Seung Hyun Jang', '1994-03-07', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--000seu')
# newly added:  ('Da Min Jeon', '2001-08-21', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--000dam')
# newly added:  ('Min Jae Jeon', '1999-06-30', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--000min')
# newly added:  ('Cheol Won Jeong', '1999-03-27', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-000che')
# have called 20 apis: 1 min break starts
# newly added:  ('Soo Haeng Jo', '1993-08-30', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000soo')
# newly added:  ('Soo Bin Jung', '1990-10-07', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-000soo')
# newly added:  ('Seung Ho Kang', '1994-02-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--000seu')
# newly added:  ('Dae Han Kim', '2000-12-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---011dae')
# newly added:  ('Do Yun Kim', '2002-06-28', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000doy')
# newly added:  ('Dong Ju Kim', '2002-02-14', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---026don')
# newly added:  ('Ho Jun Kim', '1998-05-17', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001hoj')
# newly added:  ('In Tae Kim', '1994-07-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005in-')
# newly added:  ('Jae Hwan Kim', '1988-09-22', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008jae')
# newly added:  ('Jae-ho Kim', '1985-03-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007jae')
# have called 30 apis: 1 min break starts
# newly added:  ('Jung-woo Kim', '1999-05-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008jun')
# newly added:  ('Kang Ryul Kim', '1988-08-28', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001gan')
# newly added:  ('Ki-yeon Kim', '1997-09-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002ki-')
# newly added:  ('Min Gyu Kim', '1999-05-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---025min')
# newly added:  ('Min Hyeok Kim', '1996-05-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---021min')
# newly added:  ('Myeong Sin Kim', '1993-11-29', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005mye')
# newly added:  ('Tae-geun Kim', '1996-08-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---029tae')
# newly added:  ('Taek Yeon Kim', '2005-06-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---035tae')
# newly added:  ('Yu Seong Kim', '2002-01-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000yus')
# newly added:  ('Hwi Kwon', '2000-12-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000hwi')
# have called 40 apis: 1 min break starts
# newly added:  ('Byeong Heon Lee', '2003-06-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---004bye')
# newly added:  ('Byung-hwee Lee', '1998-08-05', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003byu')
# newly added:  ('Kyo Hoon Lee', '2000-05-29', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000kyo')
# newly added:  ('Young Ha Lee', '1997-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000you')
# newly added:  ('Myeong Jin Oh', '2001-04-09', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----002mye')
# newly added:  ('Chi Guk Park', '1998-03-10', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000chi')
# newly added:  ('Gye Beom Park', '1996-01-11', 'https://www.baseball-reference.com/register/player.fcgi?id=park--001gye')
# newly added:  ('Ji Ho Park', '2003-07-02', 'https://www.baseball-reference.com/register/player.fcgi?id=park--002jih')
# newly added:  ('Jong Ki Park', '1995-01-21', 'https://www.baseball-reference.com/register/player.fcgi?id=park--005jon')
# newly added:  ('Jun Young Park', '1997-08-05', 'https://www.baseball-reference.com/register/player.fcgi?id=park--003joo')
# have called 50 apis: 1 min break starts
# newly added:  ('Jung Soo Park', '1996-01-29', 'https://www.baseball-reference.com/register/player.fcgi?id=park--006jeo')
# newly added:  ('Min Jun Park', '2002-10-21', 'https://www.baseball-reference.com/register/player.fcgi?id=park--007min')
# newly added:  ('Shin-jee Park', '1999-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000shi')
# newly added:  ('Henry Ramos', '1992-04-15', 'https://www.baseball-reference.com/register/player.fcgi?id=ramos-001hen')
# newly added:  ('Hyun Jun Ryu', '2005-03-25', 'https://www.baseball-reference.com/register/player.fcgi?id=ryu---002hyu')
# newly added:  ('Ye Il Seo', '1993-06-19', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---000ye-')
# newly added:  ('Keisho Shirakawa', '2001-06-04', 'https://www.baseball-reference.com/register/player.fcgi?id=shirak000kei')
# newly added:  ('Brandon Waddell', '1994-06-03', 'https://www.baseball-reference.com/register/player.fcgi?id=waddel000bra')
# newly added:  ('Chan Yeol Yang', '1997-05-25', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--001cha')
# newly added:  ('Suk Hwan Yang', '1991-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--001seo')
# have called 60 apis: 1 min break starts
# newly added:  ('Ui-ji Yang', '1987-06-05', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000ui-')
# newly added:  ('Tong Keon Yeo', '2005-08-04', 'https://www.baseball-reference.com/register/player.fcgi?id=yeo---000ton')
# newly added:  ('Jared Young', '1995-07-09', 'https://www.baseball-reference.com/register/player.fcgi?id=young-000jar')
# newly added:  ('Jun Ho Yun', '2000-11-14', 'https://www.baseball-reference.com/register/player.fcgi?id=yun---001jun')
# Finished processing 2024 Doosan Bears.
# newly added:  ('Chi Hong An', '1990-07-02', 'https://www.baseball-reference.com/register/player.fcgi?id=an----000chi')
# newly added:  ('Min Seo Bae', '1999-11-18', 'https://www.baseball-reference.com/register/player.fcgi?id=bae---002min')
# newly added:  ('Jaime Barria', '1996-07-18', 'https://www.baseball-reference.com/register/player.fcgi?id=barria000jai')
# newly added:  ('Eun Seong Chae', '1990-02-06', 'https://www.baseball-reference.com/register/player.fcgi?id=chae--000weu')
# newly added:  ('Kyu Hyun Chang', '2002-06-28', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-000kyu')
# have called 70 apis: 1 min break starts
# newly added:  ('See-hwan Chang', '1987-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--000hyo')
# newly added:  ('Dong Uk Cho', '2004-11-02', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---003don')
# newly added:  ('In Ho Choi', '2000-01-30', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000inh')
# newly added:  ('Jae Hoon Choi', '1989-08-27', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000jae')
# newly added:  ('Woo Ram Chung', '1985-06-01', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-000woo')
# newly added:  ('Ju Suk Ha', '1994-02-25', 'https://www.baseball-reference.com/register/player.fcgi?id=ha----000joo')
# newly added:  ('Hyeong Been Han', '1998-12-11', 'https://www.baseball-reference.com/register/player.fcgi?id=han---001hye')
# newly added:  ('Seung Hyuk Han', '1993-01-03', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000seu')
# newly added:  ('Seung Ju Han', '2001-03-17', 'https://www.baseball-reference.com/register/player.fcgi?id=han---002seu')
# newly added:  ('Jun Seo Hwang', '2005-08-22', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-002jun')
# have called 80 apis: 1 min break starts
# newly added:  ('Young Mook Hwang', '1999-10-16', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000you')
# newly added:  ('Ji Su Jang', '2000-05-25', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--000ji-')
# newly added:  ('Jin Hyuk Jang', '1993-09-30', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-003jin')
# newly added:  ('Min Je Jang', '1990-03-19', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--001min')
# newly added:  ('Hyun Sang Joo', '1992-08-10', 'https://www.baseball-reference.com/register/player.fcgi?id=choo--000hye')
# newly added:  ('Eun Won Jung', '2000-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--000eun')
# newly added:  ('Beom Su Kim', '1995-10-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000bum')
# newly added:  ('Do Been Kim', '2001-01-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000dob')
# newly added:  ('In-hwan Kim', '1994-01-28', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006in-')
# newly added:  ('Kang Min Kim', '1982-09-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000gan')
# have called 90 apis: 1 min break starts
# newly added:  ('Ki Joong Kim', '2002-11-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000kij')
# newly added:  ('Kyu Yeon Kim', '2002-08-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007kyu')
# newly added:  ('Min Woo Kim', '1995-07-25', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---018min')
# newly added:  ('Seo Hyeon Kim', '2004-05-31', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---051seo')
# newly added:  ('Seung Il Kim', '2001-07-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008seu')
# newly added:  ('Tae Yean Kim', '1997-06-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---026tae')
# newly added:  ('Kwang-Min Kwon', '1997-12-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000kwa')
# newly added:  ('Chung Ho Lee', '1994-09-20', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003chu')
# newly added:  ('Do Yun Lee', '1996-10-07', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001do-')
# newly added:  ('Jae Won Lee', '1988-02-24', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---005jae')
# have called 100 apis: 1 min break starts
# newly added:  ('Jin Young Lee', '1997-07-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---004jin')
# newly added:  ('Min Woo Lee', '1993-02-09', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---006min')
# newly added:  ('Myung Ki Lee', '1987-12-26', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000mye')
# newly added:  ('Sang Hyuk Lee', '2001-09-14', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---030san')
# newly added:  ('Sang Kyu Lee', '1996-10-20', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---027san')
# newly added:  ('Tae Yang Lee', '1990-07-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003tae')
# newly added:  ('Won Seok Lee', '1999-03-31', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---010won')
# newly added:  ('Jong Chan Lim', '2001-09-28', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---002jon')
# newly added:  ('Dong Ju Moon', '2003-12-23', 'https://www.baseball-reference.com/register/player.fcgi?id=moon--002don')
# newly added:  ('Hyun Bin Moon', '2004-04-20', 'https://www.baseball-reference.com/register/player.fcgi?id=moon--000hyu')
# have called 110 apis: 1 min break starts
# newly added:  ('Ji Min Nam', '2001-02-12', 'https://www.baseball-reference.com/register/player.fcgi?id=nam---000jim')
# newly added:  ('Sang Un Park', '1997-03-03', 'https://www.baseball-reference.com/register/player.fcgi?id=park--007san')
# newly added:  ('Sang-won Park', '1994-09-09', 'https://www.baseball-reference.com/register/player.fcgi?id=park--006san')
# newly added:  ('Félix Peña', '1990-02-25', 'https://www.baseball-reference.com/register/player.fcgi?id=pena--002fel')
# newly added:  ('Yonathan Perlaza', '1998-11-10', 'https://www.baseball-reference.com/register/player.fcgi?id=perlaz000yon')
# newly added:  ('Si Hwan Roh', '2000-12-03', 'https://www.baseball-reference.com/register/player.fcgi?id=noh---000si-')
# newly added:  ('Hyun Jin Ryu', '1987-03-25', 'https://www.baseball-reference.com/register/player.fcgi?id=ryu---000hye')
# newly added:  ('Ricardo Sanchez', '1997-04-11', 'https://www.baseball-reference.com/register/player.fcgi?id=sanche005ric')
# newly added:  ('Ryan Weiss', '1996-12-10', 'https://www.baseball-reference.com/register/player.fcgi?id=weiss-000rya')
# newly added:  ('Jang Hyeok Yoo', '2000-05-30', 'https://www.baseball-reference.com/register/player.fcgi?id=yoo---000jan')
# have called 120 apis: 1 min break starts
# newly added:  ('Dae Kyung Yun', '1994-04-09', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--000dae')
# Finished processing 2024 Hanwha Eagles.
# newly added:  ('Cam Alldred', '1996-07-25', 'https://www.baseball-reference.com/register/player.fcgi?id=alldre000cam')
# newly added:  ('Sócrates Brito', '1992-09-06', 'https://www.baseball-reference.com/register/player.fcgi?id=brito-001soc')
# newly added:  ('Woo-hyuk Byun', '2000-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=byun--000woo')
# newly added:  ('Hyoung Woo Choi', '1983-12-16', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000hyo')
# newly added:  ('Jeong Yong Choi', '1996-10-24', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--004jeo')
# newly added:  ('Ji Min Choi', '2003-09-10', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000jim')
# newly added:  ('Won Jun Choi', '1997-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--004won')
# newly added:  ('Wil Crowe', '1994-09-09', 'https://www.baseball-reference.com/register/player.fcgi?id=crowe-000wil')
# have called 130 apis: 1 min break starts
# newly added:  ('Joon-soon Han', '1999-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=han---001joo')
# newly added:  ('Seung Taek Han', '1994-06-21', 'https://www.baseball-reference.com/register/player.fcgi?id=han---001seu')
# newly added:  ('Jong Pyo Hong', '2000-05-02', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000jon')
# newly added:  ('Dae In Hwang', '1996-02-10', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-001dae')
# newly added:  ('Dong Ha Hwang', '2002-07-30', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-001don')
# newly added:  ('Gi Yeong Im', '1993-04-16', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000ki-')
# newly added:  ('Hyun Sik Jang', '1995-02-24', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--000hye')
# newly added:  ('Jae Hyouk Jang', '2001-08-02', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--005jae')
# newly added:  ('Sang Hyun Jeon', '1996-04-18', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--001san')
# newly added:  ('Hai Young Jung', '2001-08-23', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--000hai')
# have called 140 apis: 1 min break starts
# newly added:  ('Dae Yu Kim', '1991-05-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003dae')
# newly added:  ('Do Yeong Kim', '2003-10-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001doy')
# newly added:  ('Doo Hyun Kim', '2003-04-25', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000doo')
# newly added:  ('Ho Ryung Kim', '1992-04-30', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003ho-')
# newly added:  ('Hyeon Su Kim', '2000-07-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001hyu')
# newly added:  ('Jeong Bin Kim', '1994-06-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000jeu')
# newly added:  ('Keon Kuk Kim', '1988-02-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016yon')
# newly added:  ('Ki-hoon Kim', '2000-01-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001ki-')
# newly added:  ('Kyu Sung Kim', '1997-03-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005kyu')
# newly added:  ('Min Jae Kim', '2003-07-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---033min')
# have called 150 apis: 1 min break starts
# newly added:  ('Min Ju Kim', '2002-09-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---035min')
# newly added:  ('Seung-hyun Kim', '1992-07-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005seu')
# newly added:  ('Sun Bin Kim', '1989-12-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002seo')
# newly added:  ('Tae-gun Kim', '1989-12-30', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003tae')
# newly added:  ('Yi Hwan Kim', '2000-09-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000yih')
# newly added:  ('Jong Wook Ko', '1989-01-11', 'https://www.baseball-reference.com/register/player.fcgi?id=ko----000jon')
# newly added:  ('Do Gyu Kwak', '2004-04-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kwak--000dog')
# newly added:  ('Eric Lauer', '1995-06-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lauer-000eri')
# newly added:  ('Chang Jin Lee', '1991-03-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---012cha')
# newly added:  ('Eui Lee Lee', '2002-06-16', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000eui')
# have called 160 apis: 1 min break starts
# newly added:  ('Hyeong Bum Lee', '1994-02-27', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001hyu')
# newly added:  ('Jun Young Lee', '1992-08-10', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---004joo')
# newly added:  ('Woo Sung Lee', '1994-07-17', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002woo')
# newly added:  ('Sung Bum Na', '1989-10-03', 'https://www.baseball-reference.com/register/player.fcgi?id=na----000sun')
# newly added:  ('James Naile', '1993-02-08', 'https://www.baseball-reference.com/register/player.fcgi?id=naile-002jam')
# newly added:  ('Sun Woo Oh', '1996-12-13', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----002seo')
# newly added:  ('Chan-Ho Park', '1995-06-05', 'https://www.baseball-reference.com/register/player.fcgi?id=park--004cha')
# newly added:  ('Jun Pyo Park', '1992-06-26', 'https://www.baseball-reference.com/register/player.fcgi?id=park--001joo')
# newly added:  ('Jung Woo Park', '1998-02-01', 'https://www.baseball-reference.com/register/player.fcgi?id=park--007jun')
# newly added:  ('Min Park', '2001-06-05', 'https://www.baseball-reference.com/register/player.fcgi?id=park--006min')
# have called 170 apis: 1 min break starts
# newly added:  ('Geon-chang Seo', '1989-08-22', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---000geo')
# newly added:  ('Eric Stout', '1993-03-27', 'https://www.baseball-reference.com/register/player.fcgi?id=stout-000eri')
# newly added:  ('Hyeon-jong Yang', '1988-03-01', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000hye')
# newly added:  ('Seung Cheol Yoo', '1998-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----001seu')
# newly added:  ('Do Hyun Yoon', '2003-05-07', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--000doh')
# newly added:  ('Joong Hyun Yoon', '1995-04-25', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--001joo')
# newly added:  ('Young Cheol Yoon', '2004-04-20', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--000you')
# newly added:  ('Ji Sung You', '2000-11-15', 'https://www.baseball-reference.com/register/player.fcgi?id=you---000jis')
# Finished processing 2024 Kia Tigers.
# newly added:  ('Sang Kwon Byeon', '1997-04-04', 'https://www.baseball-reference.com/register/player.fcgi?id=byeon-000san')
# have called 180 apis: 1 min break starts
# newly added:  ('Sang Woo Cho', '1994-09-04', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---002san')
# newly added:  ('Young Gun Cho', '1999-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=jo----000you')
# newly added:  ('Joo Hwan Choi', '1988-02-28', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000ju-')
# newly added:  ('Ronnie Dawson', '1995-05-19', 'https://www.baseball-reference.com/register/player.fcgi?id=dawson002ron')
# newly added:  ('Enmanuel De Jesus', '1996-12-10', 'https://www.baseball-reference.com/register/player.fcgi?id=dejesu001enm')
# newly added:  ('Yeong Min Ha', '1995-05-07', 'https://www.baseball-reference.com/register/player.fcgi?id=ha----000yeo')
# newly added:  ('Jae Young Jang', '2002-05-10', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--004jae')
# newly added:  ('Chan Heon Jeong', '1990-01-26', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-000cha')
# newly added:  ('Jun Pyo Jhun', '2005-05-07', 'https://www.baseball-reference.com/register/player.fcgi?id=jhun--000jun')
# newly added:  ('Seong Won Ju', '2000-08-30', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--000son')
# have called 190 apis: 1 min break starts
# newly added:  ('Seung Woo Ju', '2000-01-30', 'https://www.baseball-reference.com/register/player.fcgi?id=ju----000seu')
# newly added:  ('Ariel Jurado', '1996-01-30', 'https://www.baseball-reference.com/register/player.fcgi?id=jurado000ari')
# newly added:  ('Byeong Hwi Kim', '2001-02-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007bye')
# newly added:  ('Dong Heon Kim', '2004-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---028don')
# newly added:  ('Dong Hyeok Kim', '2001-12-27', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---022don')
# newly added:  ('Dong Kyu Kim', '2004-07-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---029don')
# newly added:  ('Dong Uk Kim', '1997-05-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---023don')
# newly added:  ('Gun Hee Kim', '2004-11-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000gun')
# newly added:  ('Hyeseong Kim', '1999-01-27', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016hye')
# newly added:  ('In-beom Kim', '2000-01-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007in-')
# have called 200 apis: 1 min break starts
# newly added:  ('Jae Hyun Kim', '1993-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---019jae')
# newly added:  ('Jae Woong Kim', '1998-10-22', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---029jae')
# newly added:  ('Joo-hyung Kim', '1996-03-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005joo')
# newly added:  ('Seon Gi Kim', '1991-09-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001seo')
# newly added:  ('Seong Min Kim', '1994-04-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---043seo')
# newly added:  ('Si Ang Kim', '2001-10-31', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001sia')
# newly added:  ('Su Hwan Kim', '1998-03-20', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000suh')
# newly added:  ('Tae Jin Kim', '1995-10-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---020tae')
# newly added:  ('Whee Jip Kim', '2002-01-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000whe')
# newly added:  ('Woong Bin Kim', '1996-02-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000woo')
# have called 210 apis: 1 min break starts
# newly added:  ('Yeon Ju Kim', '2004-02-27', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---017yeo')
# newly added:  ('Yun Ha Kim', '2005-03-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004yun')
# newly added:  ('Young Woo Ko', '2001-06-21', 'https://www.baseball-reference.com/register/player.fcgi?id=ko----001you')
# newly added:  ('Hyung Jong Lee', '1989-06-07', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---005hye')
# newly added:  ('Jae Sang Lee', '2005-04-17', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---024jae')
# newly added:  ('Jong Min Lee', '2001-06-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---017jon')
# newly added:  ('Ju Hyoung Lee', '2001-04-02', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000juh')
# newly added:  ('Myeong Jong Lee', '2002-12-05', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---005mye')
# newly added:  ('Seung Won Lee', '2004-07-02', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---025seu')
# newly added:  ('Won Seok Lee', '1986-10-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---004won')
# have called 220 apis: 1 min break starts
# newly added:  ('Yong-gyu Lee', '1985-08-26', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001yon')
# newly added:  ('Byung-Wook Lim', '1995-09-30', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000byu')
# newly added:  ('Ji-yeol Lim', '1995-08-22', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---001ji-')
# newly added:  ('Sung Hyun Moon', '1991-11-09', 'https://www.baseball-reference.com/register/player.fcgi?id=moon--001sun')
# newly added:  ('Seok Ju Oh', '1998-04-14', 'https://www.baseball-reference.com/register/player.fcgi?id=ok----000seo')
# newly added:  ('Beom Jun Park', '2004-05-28', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000beo')
# newly added:  ('Ju Hong Park', '2001-04-16', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000juh')
# newly added:  ('Jun Hyeong Park', '1999-03-07', 'https://www.baseball-reference.com/register/player.fcgi?id=park--009jun')
# newly added:  ('Seong Bhin Park', '2004-04-21', 'https://www.baseball-reference.com/register/player.fcgi?id=park--005seo')
# newly added:  ('Seung Joo Park', '1994-02-12', 'https://www.baseball-reference.com/register/player.fcgi?id=park--001seu')
# have called 230 apis: 1 min break starts
# newly added:  ('Soo Jong Park', '1999-02-25', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000soo')
# newly added:  ('Yun Sung Park', '2004-02-08', 'https://www.baseball-reference.com/register/player.fcgi?id=park--001yun')
# newly added:  ('Hwi Yun Shim', '2005-05-28', 'https://www.baseball-reference.com/register/player.fcgi?id=shim--000hwi')
# newly added:  ('Jun Woo Sin', '2001-06-21', 'https://www.baseball-reference.com/register/player.fcgi?id=sin---001jun')
# newly added:  ('Hyeon Gi Son', '2005-10-22', 'https://www.baseball-reference.com/register/player.fcgi?id=son---002hye')
# newly added:  ('Ji Hoo Song', '2005-01-08', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000jih')
# newly added:  ('Sung Mun Song', '1996-08-29', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000sun')
# newly added:  ('Jong-hyeon Won', '1987-07-31', 'https://www.baseball-reference.com/register/player.fcgi?id=won---000jon')
# newly added:  ('Sung Jun Won', '2000-03-31', 'https://www.baseball-reference.com/register/player.fcgi?id=won---000sun')
# newly added:  ('Gi-hyun Yang', '1998-12-16', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000gi-')
# have called 240 apis: 1 min break starts
# newly added:  ('Jin Won Ye', '1999-03-16', 'https://www.baseball-reference.com/register/player.fcgi?id=ye----000jin')
# newly added:  ('Jeong-Hyeon Yoon', '1993-05-17', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--001jeo')
# newly added:  ('Seok Won Yun', '2003-07-04', 'https://www.baseball-reference.com/register/player.fcgi?id=yun---006seo')
# Finished processing 2024 Kiwoom Heroes.
# newly added:  ('Hyun Min Ahn', '2003-08-22', 'https://www.baseball-reference.com/register/player.fcgi?id=ahn---000hyu')
# newly added:  ('Chi Young An', '1998-05-29', 'https://www.baseball-reference.com/register/player.fcgi?id=ahn---000chi')
# newly added:  ('Jung Dae Bae', '1995-06-12', 'https://www.baseball-reference.com/register/player.fcgi?id=bae---000bye')
# newly added:  ('Wes Benjamin', '1993-07-26', 'https://www.baseball-reference.com/register/player.fcgi?id=benjam000wes')
# newly added:  ('Seong Ho Cheon', '1997-10-30', 'https://www.baseball-reference.com/register/player.fcgi?id=cheon-000seo')
# newly added:  ('Dae Hyun Cho', '1999-08-06', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000dae')
# have called 250 apis: 1 min break starts
# newly added:  ('Yong Ho Cho', '1989-09-09', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---004yon')
# newly added:  ('William Cuevas', '1990-10-14', 'https://www.baseball-reference.com/register/player.fcgi?id=cuevas001wil')
# newly added:  ('Jun Ho Ha', '1989-04-29', 'https://www.baseball-reference.com/register/player.fcgi?id=ha----001jun')
# newly added:  ('Cha Hyeon Han', '1998-11-30', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000cha')
# newly added:  ('Hyeon Bin Hong', '1997-08-29', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000hyu')
# newly added:  ('Jae-gyun Hwang', '1987-07-28', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-001jae')
# newly added:  ('Jun Won Jang', '1995-11-21', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-000joo')
# newly added:  ('Sung-Woo Jang', '1990-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--001sun')
# newly added:  ('Yong-ju Jeon', '2000-02-12', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--001yon')
# newly added:  ('Jun Young Jeong', '2004-01-26', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-000jun')
# have called 260 apis: 1 min break starts
# newly added:  ('Yi Hyeon Jo', '1995-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---002yeo')
# newly added:  ('Kwon Ju', '1995-05-31', 'https://www.baseball-reference.com/register/player.fcgi?id=joo---000kwa')
# newly added:  ('Baek Ho Kang', '1999-07-29', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--000bae')
# newly added:  ('Geon Kang', '2004-07-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--000geo')
# newly added:  ('Hyeon Woo Kang', '2001-04-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--002hye')
# newly added:  ('Min Sung Kang', '1999-12-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--009min')
# newly added:  ('Byeong Jun Kim', '2003-07-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008bye')
# newly added:  ('Geon Hyoung Kim', '1996-07-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000rya')
# newly added:  ('Jun Tae Kim', '1994-07-31', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001joo')
# newly added:  ('Min Kim', '1999-04-14', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---024min')
# have called 270 apis: 1 min break starts
# newly added:  ('Min Hyuck Kim', '1995-11-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---017min')
# newly added:  ('Min Su Kim', '1992-07-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---019min')
# newly added:  ('Sang-soo Kim', '1990-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008san')
# newly added:  ('Young Hyun Kim', '2002-08-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006you')
# newly added:  ('Young Pyo Ko', '1991-09-16', 'https://www.baseball-reference.com/register/player.fcgi?id=ko----000you')
# newly added:  ('Dong Jin Kwon', '1998-09-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000don')
# newly added:  ('Chae Ho Lee', '1998-11-23', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---021cha')
# newly added:  ('Ho Yeon Lee', '1995-06-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000hoy')
# newly added:  ('Sang Dong Lee', '1995-11-24', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---025san')
# newly added:  ('Sun-woo Lee', '2000-09-19', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---008sun')
# have called 280 apis: 1 min break starts
# newly added:  ('Yong Ik Mon', '1995-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=mon---000yon')
# newly added:  ('Sang Chul Moon', '1991-04-06', 'https://www.baseball-reference.com/register/player.fcgi?id=moon--000san')
# newly added:  ('Jae Il Oh', '1986-10-29', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000jae')
# newly added:  ('Yoon Suk Oh', '1992-02-24', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000yoo')
# newly added:  ('ByungHo Park', '1986-07-10', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000byu')
# newly added:  ('Kyung Su Park', '1984-03-31', 'https://www.baseball-reference.com/register/player.fcgi?id=park--001kyu')
# newly added:  ('Min-suk Park', '2000-04-13', 'https://www.baseball-reference.com/register/player.fcgi?id=park--005min')
# newly added:  ('Se Jin Park', '1997-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=park--002sae')
# newly added:  ('Si Young Park', '1989-03-10', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000si-')
# newly added:  ('Yeong Hyun Park', '2003-10-11', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000yeo')
# have called 290 apis: 1 min break starts
# newly added:  ('Mel Rojas', '1990-05-24', 'https://www.baseball-reference.com/register/player.fcgi?id=rojas-002mel')
# newly added:  ('Jae Heon Seong', '1997-12-22', 'https://www.baseball-reference.com/register/player.fcgi?id=seong-000jae')
# newly added:  ('Woo Jun Shim', '1995-04-28', 'https://www.baseball-reference.com/register/player.fcgi?id=shim--000woo')
# newly added:  ('Bon Ki Shin', '1989-03-21', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--000bon')
# newly added:  ('Hyeong Jun So', '2001-09-16', 'https://www.baseball-reference.com/register/player.fcgi?id=so----000hye')
# newly added:  ('Dong Hyun Son', '2001-01-23', 'https://www.baseball-reference.com/register/player.fcgi?id=son---002don')
# newly added:  ('Min Sub Song', '1991-08-02', 'https://www.baseball-reference.com/register/player.fcgi?id=song--001min')
# newly added:  ('Sang Back Um', '1996-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=eom---000san')
# newly added:  ('Sang Hyun Weon', '2004-10-16', 'https://www.baseball-reference.com/register/player.fcgi?id=weon--000san')
# newly added:  ('Gyu-min Woo', '1985-01-21', 'https://www.baseball-reference.com/register/player.fcgi?id=wu----000gyu')
# have called 300 apis: 1 min break starts
# newly added:  ('Chung Myoung Yook', '2005-07-18', 'https://www.baseball-reference.com/register/player.fcgi?id=yook--000chu')
# newly added:  ('Jun Hyeok Yun', '2001-07-26', 'https://www.baseball-reference.com/register/player.fcgi?id=yun---000jun')
# Finished processing 2024 KT Wiz.
# newly added:  ('Ik Hun An', '1996-02-12', 'https://www.baseball-reference.com/register/player.fcgi?id=ahn---000ik-')
# newly added:  ('Dong Hwan Choi', '1989-09-19', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000don')
# newly added:  ('Myong Kyong Choi', '2001-06-14', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000myo')
# newly added:  ('Seung Min Choi', '1996-07-01', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--003seu')
# newly added:  ('Won Tae Choi', '1997-01-07', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--003won')
# newly added:  ('Won Yeong Choi', '2003-07-18', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--005won')
# newly added:  ('Austin Dean', '1993-10-14', 'https://www.baseball-reference.com/register/player.fcgi?id=dean--000aus')
# have called 310 apis: 1 min break starts
# newly added:  ('Dietrich Enns', '1991-05-16', 'https://www.baseball-reference.com/register/player.fcgi?id=enns--000die')
# newly added:  ('Bon Hyeok Gu', '1997-01-11', 'https://www.baseball-reference.com/register/player.fcgi?id=koo---001bon')
# newly added:  ('Chang Geon Ham', '2001-08-18', 'https://www.baseball-reference.com/register/player.fcgi?id=ham---002cha')
# newly added:  ('Deok Ju Ham', '1995-01-13', 'https://www.baseball-reference.com/register/player.fcgi?id=ham---000deo')
# newly added:  ('Elieser Hernández', '1995-05-03', 'https://www.baseball-reference.com/register/player.fcgi?id=hernan002eli')
# newly added:  ('Chang Ki Hong', '1993-11-21', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000cha')
# newly added:  ('Do Hwan Hur', '1984-07-31', 'https://www.baseball-reference.com/register/player.fcgi?id=hur---000do-')
# newly added:  ('Chan Kyu Im', '1992-11-20', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---007cha')
# newly added:  ('Jun Ho Jeon', '1998-07-01', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--001jun')
# newly added:  ('Woo Young Jin', '2001-02-05', 'https://www.baseball-reference.com/register/player.fcgi?id=jin---000woo')
# have called 320 apis: 1 min break starts
# newly added:  ('Ji Heon Jung', '2003-12-11', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--000jih')
# newly added:  ('Woo Young Jung', '1999-08-19', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--001woo')
# newly added:  ('Hyo Jong Kang', '2002-10-14', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--001hyo')
# newly added:  ('Casey Kelly', '1989-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kelly-001cas')
# newly added:  ('Beom Seok Kim', '2004-05-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000beo')
# newly added:  ('Dae Hyun Kim', '1997-03-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010dae')
# newly added:  ('Dae Won Kim', '2001-11-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---012dae')
# newly added:  ('Hyun Jong Kim', '2004-08-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004hyu')
# newly added:  ('Hyun Soo Kim', '1988-01-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004hye')
# newly added:  ('Jin Su Kim', '1998-08-31', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---021jin')
# have called 330 apis: 1 min break starts
# newly added:  ('Jin Sung Kim', '1985-03-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jin')
# newly added:  ('Ju Sung Kim', '1998-01-30', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007ju-')
# newly added:  ('Min Su Kim', '1998-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---022min')
# newly added:  ('Sung Jin Kim', '2000-03-17', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---011sun')
# newly added:  ('Sung Woo Kim', '2003-11-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---012sun')
# newly added:  ('Tae Woo Kim', '1997-10-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---036tae')
# newly added:  ('Young Jun Kim', '1999-01-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016yeo')
# newly added:  ('Yu Yeong Kim', '1994-05-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002yoo')
# newly added:  ('Yun Sik Kim', '2000-04-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003yun')
# newly added:  ('Ji Gang Lee', '1999-07-02', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000jig')
# have called 340 apis: 1 min break starts
# newly added:  ('Jong Jun Lee', '2001-03-09', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---018jon')
# newly added:  ('Ju Heon Lee', '2003-03-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002juh')
# newly added:  ('Mit Eum Lee', '2000-07-18', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001mit')
# newly added:  ('Sang Yung Lee', '2000-12-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---026san')
# newly added:  ('Woo Chan Lee', '1992-08-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---009yeo')
# newly added:  ('Young Bin Lee', '2002-06-17', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003you')
# newly added:  ('Jun Hyeung Lim', '2000-11-16', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---001jun')
# newly added:  ('Bo Gyeong Moon', '2000-07-19', 'https://www.baseball-reference.com/register/player.fcgi?id=moon--000bog')
# newly added:  ('Sung Ju Moon', '1997-02-20', 'https://www.baseball-reference.com/register/player.fcgi?id=moon--002sun')
# newly added:  ('Ji Hwan Oh', '1990-03-12', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000ji-')
# have called 350 apis: 1 min break starts
# newly added:  ('Seung Hyun Paek', '1995-05-26', 'https://www.baseball-reference.com/register/player.fcgi?id=paek--002seu')
# newly added:  ('Dong Won Park', '1990-04-07', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000don')
# newly added:  ('Hae Min Park', '1990-02-24', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000hae')
# newly added:  ('Myung Geun Park', '2004-03-27', 'https://www.baseball-reference.com/register/player.fcgi?id=park--001myu')
# newly added:  ('Min Jae Shin', '1996-01-21', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--001min')
# newly added:  ('Ho Young Son', '1994-08-23', 'https://www.baseball-reference.com/register/player.fcgi?id=son---000ho-')
# newly added:  ('Ju Young Son', '1998-12-02', 'https://www.baseball-reference.com/register/player.fcgi?id=son---001ju-')
# newly added:  ('Chan Eui Song', '1999-02-20', 'https://www.baseball-reference.com/register/player.fcgi?id=song--002cha')
# newly added:  ('Dong Hyun Sung', '1999-05-18', 'https://www.baseball-reference.com/register/player.fcgi?id=seong-000don')
# newly added:  ('Kang Hoon Woo', '2002-10-03', 'https://www.baseball-reference.com/register/player.fcgi?id=woo---000kan')
# have called 360 apis: 1 min break starts
# newly added:  ('Ho Sol Yoon', '1994-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--000hye')
# newly added:  ('Young Chan You', '1997-03-07', 'https://www.baseball-reference.com/register/player.fcgi?id=you---000you')
# Finished processing 2024 LG Twins.
# newly added:  ('Du San Baek', '2001-05-20', 'https://www.baseball-reference.com/register/player.fcgi?id=baek--000dus')
# newly added:  ('Charlie Barnes', '1995-10-01', 'https://www.baseball-reference.com/register/player.fcgi?id=barnes006cha')
# newly added:  ('Hang Choi', '1994-01-03', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000han')
# newly added:  ('Jun Yong Choi', '2001-10-10', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--001jun')
# newly added:  ('Keon Choi', '1999-04-10', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000keo')
# newly added:  ('Jae Hyun Choo', '1999-02-22', 'https://www.baseball-reference.com/register/player.fcgi?id=choo--000jae')
# newly added:  ('Seung Min Go', '2000-08-11', 'https://www.baseball-reference.com/register/player.fcgi?id=ko----002seu')
# have called 370 apis: 1 min break starts
# newly added:  ('Dong Hui Han', '1999-06-01', 'https://www.baseball-reference.com/register/player.fcgi?id=han---001don')
# newly added:  ('Hyun Hee Han', '1993-06-25', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000hyu')
# newly added:  ('Min Ki Hong', '2001-07-20', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--002min')
# newly added:  ('Seong Bin Hwang', '1997-12-19', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-004seo')
# newly added:  ('Do Hoon Hyun', '1993-01-13', 'https://www.baseball-reference.com/register/player.fcgi?id=hyun--000ki-')
# newly added:  ('Jun Seob Im', '1989-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000joo')
# newly added:  ('Du Seong Jang', '1999-09-16', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--000dus')
# newly added:  ('Jun-woo Jeon', '1986-02-25', 'https://www.baseball-reference.com/register/player.fcgi?id=jun---000jun')
# newly added:  ('Mi R Jeon', '2005-08-15', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--000mir')
# newly added:  ('Bo Keun Jeong', '1999-08-31', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--000bo-')
# have called 380 apis: 1 min break starts
# newly added:  ('Dae Sun Jeong', '2004-11-16', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001dae')
# newly added:  ('Hyeon Su Jeong', '2001-05-10', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-007hye')
# newly added:  ('Woo Jun Jeong', '2000-03-17', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001woo')
# newly added:  ('Hae Soo Jin', '1986-06-26', 'https://www.baseball-reference.com/register/player.fcgi?id=chin--000min')
# newly added:  ('Seung Hyun Jin', '2003-09-05', 'https://www.baseball-reference.com/register/player.fcgi?id=jin---000seu')
# newly added:  ('Hoon Jung', '1987-07-18', 'https://www.baseball-reference.com/register/player.fcgi?id=jung--000hoo')
# newly added:  ('Seong Woo Kang', '2005-04-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--004seo')
# newly added:  ('Seung Gu Kang', '2003-10-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--001seu')
# newly added:  ('Tae Yul Kang', '1996-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--003don')
# newly added:  ('Do Gyu Kim', '1998-07-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000dog')
# have called 390 apis: 1 min break starts
# newly added:  ('Dong Hyeok Kim', '2000-09-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---030don')
# ...
# newly added:  ('Daniel Castano', '1994-09-17', 'https://www.baseball-reference.com/register/player.fcgi?id=castan000dan')
# have called 430 apis: 1 min break starts
# newly added:  ('Ji Seon Chae', '1995-07-11', 'https://www.baseball-reference.com/register/player.fcgi?id=chae--000jis')
# newly added:  ('Jae Hwan Cheon', '1994-04-01', 'https://www.baseball-reference.com/register/player.fcgi?id=cheon-000jae')
# newly added:  ('Jeong Won Choi', '2000-06-24', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--005jeo')
# newly added:  ('Sung-yeong Choi', '1997-04-28', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--002sun')
# newly added:  ('Woo Seok Choi', '2005-03-31', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--003woo')
# newly added:  ('Sa Min Chun', '1999-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--000sa-')
# newly added:  ('Matt Davidson', '1991-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=davids002mat')
# newly added:  ('Tae Hun Do', '1993-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=do----000tae')
# newly added:  ('Jae Hwan Han', '2001-10-19', 'https://www.baseball-reference.com/register/player.fcgi?id=han---001jae')
# newly added:  ('Jae Seung Han', '2001-11-21', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000jae')
# have called 440 apis: 1 min break starts
# newly added:  ('Suk Hyun Han', '1994-05-17', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000suk')
# newly added:  ('Kyle Hart', '1992-11-23', 'https://www.baseball-reference.com/register/player.fcgi?id=hart--000kyl')
# newly added:  ('Chang Min Jeon', '2000-06-09', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--000cha')
# newly added:  ('Eric Jokisch', '1989-07-29', 'https://www.baseball-reference.com/register/player.fcgi?id=jokisc001eri')
# newly added:  ('Beom Jun Kim', '2000-04-20', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001beo')
# newly added:  ('Han Byul Kim', '2001-01-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003han')
# newly added:  ('Hyung Jun Kim', '1999-11-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---017hye')
# newly added:  ('Jae Yeol Kim', '1996-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---030jae')
# newly added:  ('Jin Ho Kim', '1998-06-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---019jin')
# newly added:  ('Ju Won Kim', '2002-07-30', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000juw')
# have called 450 apis: 1 min break starts
# newly added:  ('Min Gyu Kim', '2001-09-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---034min')
# newly added:  ('Min Su Kim', '1998-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---026min')
# newly added:  ('Se Hun Kim', '2005-04-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000seh')
# newly added:  ('Seong-Wook Kim', '1993-05-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---042seo')
# newly added:  ('Si Hoon Kim', '1999-02-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000sih')
# newly added:  ('Tae Hyun Kim', '1998-03-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---031tae')
# dup skipped:  ('Whee Jip Kim', '2002-01-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000whe')
# newly added:  ('Young Kyu Kim', '2000-02-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003you')
# newly added:  ('Hui Dong Kwon', '1990-12-30', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000hee')
# newly added:  ('Jae Hak Lee', '1990-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001jae')
# have called 460 apis: 1 min break starts
# newly added:  ('Jun Ho Lee', '2000-03-27', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---011jun')
# newly added:  ('Yong Chan Lee', '1989-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000yon')
# newly added:  ('Yong Jun Lee', '2002-05-08', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---014yon')
# newly added:  ('Jung Ho Lim', '1990-04-16', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---001jeo')
# newly added:  ('Sang Hyeon Lim', '2005-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000san')
# newly added:  ('Ji Hoon Mok', '2004-05-11', 'https://www.baseball-reference.com/register/player.fcgi?id=mok---000jih')
# newly added:  ('Yeong-soo Oh', '2000-01-30', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----001yeo')
# newly added:  ('Han Gyeol Park', '2004-04-26', 'https://www.baseball-reference.com/register/player.fcgi?id=park--003han')
# newly added:  ('Ju Hyeon Park', '1999-08-03', 'https://www.baseball-reference.com/register/player.fcgi?id=park--002juh')
# newly added:  ('Kun Woo Park', '1990-09-08', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000geo')
# have called 470 apis: 1 min break starts
# newly added:  ('Min Woo Park', '1993-02-06', 'https://www.baseball-reference.com/register/player.fcgi?id=park--004min')
# newly added:  ('Sei Hyok Park', '1990-01-09', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000sae')
# newly added:  ('Si Won Park', '2001-05-30', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000siw')
# newly added:  ('Young Bin Park', '1997-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=park--004you')
# newly added:  ('Jin Oug Ryou', '1996-10-10', 'https://www.baseball-reference.com/register/player.fcgi?id=ryou--000jin')
# newly added:  ('Eui Tae Seo', '1997-09-05', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---000eui')
# newly added:  ('Ho Cheol Seo', '1996-10-16', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---000hoc')
# newly added:  ('Min Hyeok Shin', '1999-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--002min')
# newly added:  ('Yeong Woo Shin', '2004-04-21', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--001yeo')
# newly added:  ('Yong Seok Shin', '2003-10-11', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--001yon')
# have called 480 apis: 1 min break starts
# newly added:  ('Rhee Hyun So', '1999-02-09', 'https://www.baseball-reference.com/register/player.fcgi?id=so----000yi-')
# newly added:  ('Ah-seop Son', '1988-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=son---000ah-')
# newly added:  ('Ju Hwan Son', '2002-01-05', 'https://www.baseball-reference.com/register/player.fcgi?id=son---000juh')
# newly added:  ('Myung Gi Song', '2000-08-09', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000myu')
# newly added:  ('Seung Hwan Song', '2000-10-28', 'https://www.baseball-reference.com/register/player.fcgi?id=song--002seu')
# Finished processing 2024 NC Dinos.
# newly added:  ('Ju Hyeong An', '1993-08-14', 'https://www.baseball-reference.com/register/player.fcgi?id=ahn---001joo')
# newly added:  ('Jung Hyun Baek', '1987-07-13', 'https://www.baseball-reference.com/register/player.fcgi?id=paek--000jeo')
# newly added:  ('Ruben Cardenas', '1997-10-10', 'https://www.baseball-reference.com/register/player.fcgi?id=carden000rub')
# newly added:  ('Chae Heung Choi', '1995-01-22', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--002cha')
# have called 490 apis: 1 min break starts
# newly added:  ('Ha-neul Choi', '1999-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000ha-')
# newly added:  ('Ji Guang Choi', '1998-03-13', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000jee')
# newly added:  ('Sung Hoon Choi', '1989-10-11', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--001sun')
# newly added:  ('Lewin Díaz', '1996-11-19', 'https://www.baseball-reference.com/register/player.fcgi?id=diaz--000lew')
# newly added:  ('Joung Woo Hong', '1996-03-16', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000jun')
# newly added:  ('Won Pyo Hong', '2001-03-27', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--001won')
# newly added:  ('Dong Jae Hwang', '2001-11-03', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000don')
# newly added:  ('Pilljoon Jang', '1988-04-08', 'https://www.baseball-reference.com/register/player.fcgi?id=jang--001pil')
# newly added:  ('Byung-woo Jeon', '1992-10-24', 'https://www.baseball-reference.com/register/player.fcgi?id=jeon--000byu')
# newly added:  ('Han Wool Kang', '1991-09-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--000han')
# have called 500 apis: 1 min break starts
# newly added:  ('Min-ho Kang', '1985-08-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--001min')
# newly added:  ('Dae Ho Kim', '2001-10-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013dae')
# newly added:  ('Dae Woo Kim', '1988-11-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008dae')
# newly added:  ('Do Hwan Kim', '2000-04-14', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006do-')
# newly added:  ('Dong Jin Kim', '1996-12-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---025don')
# newly added:  ('Dong-Yub Kim', '1990-07-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---014don')
# newly added:  ('Ho Jin Kim', '2005-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002hoj')
# newly added:  ('Hun Gon Kim', '1988-11-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002hun')
# newly added:  ('Hyeon Joon Kim', '2002-10-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---019hye')
# newly added:  ('Jae Hyuk Kim', '1999-12-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---031jae')
# have called 510 apis: 1 min break starts
# newly added:  ('Jae Sang Kim', '2004-07-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---033jae')
# newly added:  ('Jae Seong Kim', '1996-10-30', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---025jae')
# newly added:  ('Jae Yun Kim', '1990-09-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002jae')
# newly added:  ('Ji Chan Kim', '2001-03-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000jic')
# newly added:  ('Min Su Kim', '1991-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015min')
# newly added:  ('Seong Yoon Kim', '1999-02-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---044seo')
# newly added:  ('Tae Hoon Kim', '1992-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016don')
# newly added:  ('Tae Hoon Kim', '1996-03-31', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---023tae')
# newly added:  ('Young Woong Kim', '2003-08-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005you')
# newly added:  ('Yun Su Kim', '1999-12-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004yoo')
# have called 520 apis: 1 min break starts
# newly added:  ('Min-gyu Kong', '1999-09-27', 'https://www.baseball-reference.com/register/player.fcgi?id=kong--000min')
# newly added:  ('Ja Wook Koo', '1993-02-12', 'https://www.baseball-reference.com/register/player.fcgi?id=koo---001ja-')
# newly added:  ('Byung Heon Lee', '1999-10-26', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---005byu')
# newly added:  ('Chang-Yong Lee', '1999-06-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---023cha')
# newly added:  ('Ho Sung Lee', '2004-08-14', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000hos')
# newly added:  ('Jae Hyeon Lee', '2003-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---020jae')
# newly added:  ('Jae Ik Lee', '1994-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---018jae')
# newly added:  ('Sang Min Lee', '1990-11-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---022san')
# newly added:  ('Seung Hyun Lee', '2002-05-19', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---024seu')
# newly added:  ('Seung Hyun Lee', '1991-11-20', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---006seu')
# have called 530 apis: 1 min break starts
# newly added:  ('Seung Min Lee', '2000-08-26', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---019seu')
# newly added:  ('Sung Gyu Lee', '1993-08-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---007sun')
# newly added:  ('Chang Min Lim', '1985-08-25', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---003cha')
# newly added:  ('David MacKinnon', '1994-12-15', 'https://www.baseball-reference.com/register/player.fcgi?id=mackin000dav')
# dup skipped:  ('Jae Il Oh', '1986-10-29', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000jae')
# newly added:  ('Seunghwan Oh', '1982-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000seu')
# dup skipped:  ('ByungHo Park', '1986-07-10', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000byu')
# newly added:  ('Denyi Reyes', '1996-11-02', 'https://www.baseball-reference.com/register/player.fcgi?id=reyes-002den')
# newly added:  ('Ji Hyuk Ryu', '1994-01-13', 'https://www.baseball-reference.com/register/player.fcgi?id=ryu---000jee')
# newly added:  ('Seung Min Ryu', '2004-10-11', 'https://www.baseball-reference.com/register/player.fcgi?id=ryu---001seu')
# have called 540 apis: 1 min break starts
# newly added:  ('Connor Seabold', '1996-01-24', 'https://www.baseball-reference.com/register/player.fcgi?id=seabol000con')
# newly added:  ('Eun Beom Song', '1984-03-17', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000eun')
# newly added:  ('Tae In Won', '2000-04-06', 'https://www.baseball-reference.com/register/player.fcgi?id=won---000tae')
# newly added:  ('Do Geun Yang', '2003-02-06', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000dog')
# newly added:  ('Hyun Yang', '1992-08-23', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000hyu')
# newly added:  ('Woo Hyun Yang', '2000-04-13', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000woo')
# newly added:  ('Sun Yeop Yook', '2005-07-13', 'https://www.baseball-reference.com/register/player.fcgi?id=yook--000sun')
# newly added:  ('Jeong Bin Yoon', '1999-06-24', 'https://www.baseball-reference.com/register/player.fcgi?id=yoon--002jeo')
# Finished processing 2024 Samsung Lions.
# newly added:  ('Sang Hyun An', '1997-01-27', 'https://www.baseball-reference.com/register/player.fcgi?id=ahn---001san')
# have called 550 apis: 1 min break starts
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 23
#      20 name_eng = player_link.text
#      21 player_url = front_url + player_link['href']
# ---> 23 player_data = session.fetch(player_url).content.decode("utf-8")
#      24 player_html = BSoup(player_data, "lxml")
#      25 dob = player_html.find(id = "necro-birth")['data-birth']
#
# File /opt/homebrew/anaconda3/Study/Baseball/script/helper/session.py:34, in Session.fetch(self, url)
#      31 def fetch(self, url : str) -> requests.Response:
#      33     response = self.session.get(url)
# ---> 34     self.handle_call_rate()
#      36     if response.status_code != 200:
#      37         print(F"response status not 200: {response.status_code}")
#
# File /opt/homebrew/anaconda3/Study/Baseball/script/helper/session.py:24, in Session.handle_call_rate(self)
#      22 if self.cnt % self.max_per_min == 0:
#      23     print(F"have called {self.cnt} apis: 1 min break starts")
# ---> 24     time.sleep(60)
#
# KeyboardInterrupt:
