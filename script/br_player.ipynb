# %%
## Initial Setup

# %%
import pandas as pd
from bs4 import BeautifulSoup as BSoup
from bs4 import Comment
from helper.session import Session
import csv
import os

# %%
session = Session()

# %%
front_url = "https://www.baseball-reference.com" # front part of URL in which hrefs will be concatenated on.

# %% [markdown]
# ## Dup Check Setup

# %%
# initial header row setup
file_path = '../data/br_player.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["name_eng","date_of_birth", "url"]
        writer.writerow(header)

# %%
# initial header row setup
file_path = '../data/br_finished_team_year.csv'

if not os.path.exists(file_path) or os.path.getsize(file_path) == 0:
    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        header = ["year", "team"]
        writer.writerow(header)

# %%
# to filter duplicate
# both removed the header row
added_team_and_year = set([tuple(row) for row in csv.reader(open('../data/br_finished_team_year.csv', 'r'))][1:])
added_player = set([tuple(row) for row in csv.reader(open('../data/br_player.csv', 'r'))][1:])

# %% [markdown]
# ## Main Code

# %%
df = pd.read_csv('../data/br_team_year.csv')
team_urls = df.values.tolist() # all urls of KBO teams

# %%
unknown_dict = {
    "Ki-young Moon": "1972-09-24",
    "Sang-joo Choi": "1962-08-07"
}

# %%
for year, team, url in team_urls:

    if (str(year), team, url) in added_team_and_year:
        print(f"already done, skip over year: {year} team: {team}")
        continue
    
    team_data = session.fetch(url).content.decode("utf-8") # eacm team's data
    team_html = BSoup(team_data, "lxml")
    comment_wrapper = team_html.find(id="all_standard_roster") # tag that contains desired table as a comment inside
    comment = comment_wrapper.find(string=lambda text: isinstance(text, Comment)) # extract comment
    players = BSoup(comment, "lxml").find_all("tr")[1:] # convert to HTML without header row

    with open('../data/br_player.csv', 'a', newline='') as players_info:

        writer = csv.writer(players_info)
    
        for player in players:
            player_link = player.find('a') # ex) <a href="/register/player.fcgi?id=ahn---000seu">Seung Han Ahn</a>
    
            name_eng = player_link.text
            player_url = front_url + player_link['href']
            
            player_data = session.fetch(player_url).content.decode("utf-8")
            player_html = BSoup(player_data, "lxml")
            dob_tag = player_html.find(id = "necro-birth")

            # normal way to find date of birth
            if dob_tag:
                dob = dob_tag['data-birth']

            # if there is no date of birth data
            else:
                # reported cases are handled here
                if name_eng in unknown_dict:
                    dob = unknown_dict[name_eng]
                # will still lead to error -> to find a new unknown case
                else:
                    print("new unknown case")
                    dob = dob_tag['data-birth']


            player_row = (name_eng, dob, player_url)
                
            if player_row not in added_player: # filter based on the unique id in the href link
                added_player.add(player_row) 
                writer.writerow(player_row) 
                print("newly added: ", player_row)
            else:
                print("dup skipped: ", player_row)


    print(f"Finished processing {year} {team}.")

    with open('../data/br_finished_team_year.csv', 'a', newline='') as done_team_year:
        writer2 = csv.writer(done_team_year)
        writer2.writerow((year, team, url))
        added_team_and_year.add((year, team, url))
# Out:
# already done, skip over year: 2024 team: Doosan Bears
# already done, skip over year: 2024 team: Hanwha Eagles
# already done, skip over year: 2024 team: Kia Tigers
# already done, skip over year: 2024 team: Kiwoom Heroes
# already done, skip over year: 2024 team: KT Wiz
# already done, skip over year: 2024 team: LG Twins
# already done, skip over year: 2024 team: Lotte Giants
# already done, skip over year: 2024 team: NC Dinos
# already done, skip over year: 2024 team: Samsung Lions
# already done, skip over year: 2024 team: SSG Landers
# already done, skip over year: 2023 team: Doosan Bears
# already done, skip over year: 2023 team: Hanwha Eagles
# already done, skip over year: 2023 team: Kia Tigers
# already done, skip over year: 2023 team: Kiwoom Heroes
# already done, skip over year: 2023 team: KT Wiz
# already done, skip over year: 2023 team: LG Twins
# already done, skip over year: 2023 team: Lotte Giants
# already done, skip over year: 2023 team: NC Dinos
# already done, skip over year: 2023 team: Samsung Lions
# already done, skip over year: 2023 team: SSG Landers
# already done, skip over year: 2022 team: Doosan Bears
# already done, skip over year: 2022 team: Hanwha Eagles
# already done, skip over year: 2022 team: Kia Tigers
# already done, skip over year: 2022 team: Kiwoom Heroes
# already done, skip over year: 2022 team: KT Wiz
# already done, skip over year: 2022 team: LG Twins
# already done, skip over year: 2022 team: Lotte Giants
# already done, skip over year: 2022 team: NC Dinos
# already done, skip over year: 2022 team: Samsung Lions
# already done, skip over year: 2022 team: SSG Landers
# already done, skip over year: 2021 team: Doosan Bears
# already done, skip over year: 2021 team: Hanwha Eagles
# already done, skip over year: 2021 team: Kia Tigers
# already done, skip over year: 2021 team: Kiwoom Heroes
# already done, skip over year: 2021 team: KT Wiz
# already done, skip over year: 2021 team: LG Twins
# already done, skip over year: 2021 team: Lotte Giants
# already done, skip over year: 2021 team: NC Dinos
# already done, skip over year: 2021 team: Samsung Lions
# already done, skip over year: 2021 team: SSG Landers
# already done, skip over year: 2020 team: Doosan Bears
# already done, skip over year: 2020 team: Hanwha Eagles
# already done, skip over year: 2020 team: Kia Tigers
# already done, skip over year: 2020 team: Kiwoom Heroes
# already done, skip over year: 2020 team: KT Wiz
# already done, skip over year: 2020 team: LG Twins
# already done, skip over year: 2020 team: Lotte Giants
# already done, skip over year: 2020 team: NC Dinos
# already done, skip over year: 2020 team: Samsung Lions
# already done, skip over year: 2020 team: SK Wyverns
# already done, skip over year: 2019 team: Doosan Bears
# already done, skip over year: 2019 team: Hanwha Eagles
# already done, skip over year: 2019 team: Kia Tigers
# already done, skip over year: 2019 team: Kiwoom Heroes
# already done, skip over year: 2019 team: KT Wiz
# already done, skip over year: 2019 team: LG Twins
# already done, skip over year: 2019 team: Lotte Giants
# already done, skip over year: 2019 team: NC Dinos
# already done, skip over year: 2019 team: Samsung Lions
# already done, skip over year: 2019 team: SK Wyverns
# already done, skip over year: 2018 team: Doosan Bears
# already done, skip over year: 2018 team: Hanwha Eagles
# already done, skip over year: 2018 team: Kia Tigers
# already done, skip over year: 2018 team: KT Wiz
# already done, skip over year: 2018 team: LG Twins
# already done, skip over year: 2018 team: Lotte Giants
# already done, skip over year: 2018 team: NC Dinos
# already done, skip over year: 2018 team: Nexen Heroes
# already done, skip over year: 2018 team: Samsung Lions
# already done, skip over year: 2018 team: SK Wyverns
# already done, skip over year: 2017 team: Doosan Bears
# already done, skip over year: 2017 team: Hanwha Eagles
# already done, skip over year: 2017 team: Kia Tigers
# already done, skip over year: 2017 team: KT Wiz
# already done, skip over year: 2017 team: LG Twins
# already done, skip over year: 2017 team: Lotte Giants
# already done, skip over year: 2017 team: NC Dinos
# already done, skip over year: 2017 team: Nexen Heroes
# already done, skip over year: 2017 team: Samsung Lions
# already done, skip over year: 2017 team: SK Wyverns
# already done, skip over year: 2016 team: Doosan Bears
# already done, skip over year: 2016 team: Hanwha Eagles
# already done, skip over year: 2016 team: Kia Tigers
# already done, skip over year: 2016 team: KT Wiz
# already done, skip over year: 2016 team: LG Twins
# already done, skip over year: 2016 team: Lotte Giants
# already done, skip over year: 2016 team: NC Dinos
# already done, skip over year: 2016 team: Nexen Heroes
# already done, skip over year: 2016 team: Samsung Lions
# already done, skip over year: 2016 team: SK Wyverns
# already done, skip over year: 2015 team: Doosan Bears
# already done, skip over year: 2015 team: Hanwha Eagles
# already done, skip over year: 2015 team: Kia Tigers
# already done, skip over year: 2015 team: KT Wiz
# already done, skip over year: 2015 team: LG Twins
# already done, skip over year: 2015 team: Lotte Giants
# already done, skip over year: 2015 team: NC Dinos
# already done, skip over year: 2015 team: Nexen Heroes
# already done, skip over year: 2015 team: Samsung Lions
# already done, skip over year: 2015 team: SK Wyverns
# already done, skip over year: 2014 team: Doosan Bears
# already done, skip over year: 2014 team: Hanwha Eagles
# already done, skip over year: 2014 team: Kia Tigers
# already done, skip over year: 2014 team: LG Twins
# already done, skip over year: 2014 team: Lotte Giants
# already done, skip over year: 2014 team: NC Dinos
# already done, skip over year: 2014 team: Nexen Heroes
# already done, skip over year: 2014 team: Samsung Lions
# already done, skip over year: 2014 team: SK Wyverns
# already done, skip over year: 2013 team: Doosan Bears
# already done, skip over year: 2013 team: Hanwha Eagles
# already done, skip over year: 2013 team: Kia Tigers
# already done, skip over year: 2013 team: LG Twins
# already done, skip over year: 2013 team: Lotte Giants
# already done, skip over year: 2013 team: NC Dinos
# already done, skip over year: 2013 team: Nexen Heroes
# already done, skip over year: 2013 team: Samsung Lions
# already done, skip over year: 2013 team: SK Wyverns
# already done, skip over year: 2012 team: Doosan Bears
# already done, skip over year: 2012 team: Hanwha Eagles
# already done, skip over year: 2012 team: Kia Tigers
# already done, skip over year: 2012 team: LG Twins
# already done, skip over year: 2012 team: Lotte Giants
# already done, skip over year: 2012 team: Nexen Heroes
# already done, skip over year: 2012 team: Samsung Lions
# already done, skip over year: 2012 team: SK Wyverns
# already done, skip over year: 2011 team: Doosan Bears
# already done, skip over year: 2011 team: Hanwha Eagles
# already done, skip over year: 2011 team: Kia Tigers
# already done, skip over year: 2011 team: LG Twins
# already done, skip over year: 2011 team: Lotte Giants
# already done, skip over year: 2011 team: Nexen Heroes
# already done, skip over year: 2011 team: Samsung Lions
# already done, skip over year: 2011 team: SK Wyverns
# already done, skip over year: 2010 team: Doosan Bears
# already done, skip over year: 2010 team: Hanwha Eagles
# already done, skip over year: 2010 team: Kia Tigers
# already done, skip over year: 2010 team: LG Twins
# already done, skip over year: 2010 team: Lotte Giants
# already done, skip over year: 2010 team: Nexen Heroes
# already done, skip over year: 2010 team: Samsung Lions
# already done, skip over year: 2010 team: SK Wyverns
# already done, skip over year: 2009 team: Doosan Bears
# already done, skip over year: 2009 team: Hanwha Eagles
# already done, skip over year: 2009 team: Kia Tigers
# already done, skip over year: 2009 team: LG Twins
# already done, skip over year: 2009 team: Lotte Giants
# already done, skip over year: 2009 team: Samsung Lions
# already done, skip over year: 2009 team: SK Wyverns
# already done, skip over year: 2009 team: Woori Heroes
# already done, skip over year: 2008 team: Doosan Bears
# already done, skip over year: 2008 team: Hanwha Eagles
# already done, skip over year: 2008 team: Kia Tigers
# already done, skip over year: 2008 team: LG Twins
# already done, skip over year: 2008 team: Lotte Giants
# already done, skip over year: 2008 team: Samsung Lions
# already done, skip over year: 2008 team: SK Wyverns
# already done, skip over year: 2008 team: Woori Heroes
# already done, skip over year: 2007 team: Doosan Bears
# already done, skip over year: 2007 team: Hanwha Eagles
# already done, skip over year: 2007 team: Hyundai Unicorns
# already done, skip over year: 2007 team: Kia Tigers
# already done, skip over year: 2007 team: LG Twins
# already done, skip over year: 2007 team: Lotte Giants
# already done, skip over year: 2007 team: Samsung Lions
# already done, skip over year: 2007 team: SK Wyverns
# already done, skip over year: 2006 team: Doosan Bears
# already done, skip over year: 2006 team: Hanwha Eagles
# already done, skip over year: 2006 team: Hyundai Unicorns
# already done, skip over year: 2006 team: Kia Tigers
# already done, skip over year: 2006 team: LG Twins
# already done, skip over year: 2006 team: Lotte Giants
# already done, skip over year: 2006 team: Samsung Lions
# already done, skip over year: 2006 team: SK Wyverns
# already done, skip over year: 2005 team: Doosan Bears
# already done, skip over year: 2005 team: Hanwha Eagles
# already done, skip over year: 2005 team: Hyundai Unicorns
# already done, skip over year: 2005 team: Kia Tigers
# already done, skip over year: 2005 team: LG Twins
# already done, skip over year: 2005 team: Lotte Giants
# already done, skip over year: 2005 team: Samsung Lions
# already done, skip over year: 2005 team: SK Wyverns
# already done, skip over year: 2004 team: Doosan Bears
# already done, skip over year: 2004 team: Hanwha Eagles
# already done, skip over year: 2004 team: Hyundai Unicorns
# already done, skip over year: 2004 team: Kia Tigers
# already done, skip over year: 2004 team: LG Twins
# already done, skip over year: 2004 team: Lotte Giants
# already done, skip over year: 2004 team: Samsung Lions
# already done, skip over year: 2004 team: SK Wyverns
# already done, skip over year: 2003 team: Doosan Bears
# already done, skip over year: 2003 team: Hanwha Eagles
# already done, skip over year: 2003 team: Hyundai Unicorns
# already done, skip over year: 2003 team: Kia Tigers
# already done, skip over year: 2003 team: LG Twins
# already done, skip over year: 2003 team: Lotte Giants
# already done, skip over year: 2003 team: Samsung Lions
# already done, skip over year: 2003 team: SK Wyverns
# already done, skip over year: 2002 team: Doosan Bears
# already done, skip over year: 2002 team: Hanwha Eagles
# already done, skip over year: 2002 team: Hyundai Unicorns
# already done, skip over year: 2002 team: Kia Tigers
# already done, skip over year: 2002 team: LG Twins
# already done, skip over year: 2002 team: Lotte Giants
# already done, skip over year: 2002 team: Samsung Lions
# already done, skip over year: 2002 team: SK Wyverns
# already done, skip over year: 2001 team: Doosan Bears
# already done, skip over year: 2001 team: Hanwha Eagles
# already done, skip over year: 2001 team: Hyundai Unicorns
# already done, skip over year: 2001 team: Kia Tigers
# already done, skip over year: 2001 team: LG Twins
# already done, skip over year: 2001 team: Lotte Giants
# already done, skip over year: 2001 team: Samsung Lions
# already done, skip over year: 2001 team: SK Wyverns
# already done, skip over year: 2000 team: Doosan Bears
# already done, skip over year: 2000 team: Haitai Tigers
# already done, skip over year: 2000 team: Hanwha Eagles
# already done, skip over year: 2000 team: Hyundai Unicorns
# already done, skip over year: 2000 team: LG Twins
# already done, skip over year: 2000 team: Lotte Giants
# already done, skip over year: 2000 team: Samsung Lions
# already done, skip over year: 2000 team: SK Wyverns
# already done, skip over year: 1999 team: Doosan Bears
# already done, skip over year: 1999 team: Haitai Tigers
# already done, skip over year: 1999 team: Hanwha Eagles
# already done, skip over year: 1999 team: Hyundai Unicorns
# already done, skip over year: 1999 team: LG Twins
# already done, skip over year: 1999 team: Lotte Giants
# already done, skip over year: 1999 team: Samsung Lions
# already done, skip over year: 1999 team: Ssangbangwool Raiders
# already done, skip over year: 1998 team: Haitai Tigers
# already done, skip over year: 1998 team: Hanwha Eagles
# already done, skip over year: 1998 team: Hyundai Unicorns
# already done, skip over year: 1998 team: LG Twins
# already done, skip over year: 1998 team: Lotte Giants
# already done, skip over year: 1998 team: OB Bears
# already done, skip over year: 1998 team: Samsung Lions
# already done, skip over year: 1998 team: Ssangbangwool Raiders
# already done, skip over year: 1997 team: Haitai Tigers
# already done, skip over year: 1997 team: Hanwha Eagles
# already done, skip over year: 1997 team: Hyundai Unicorns
# already done, skip over year: 1997 team: LG Twins
# already done, skip over year: 1997 team: Lotte Giants
# already done, skip over year: 1997 team: OB Bears
# already done, skip over year: 1997 team: Samsung Lions
# already done, skip over year: 1997 team: Ssangbangwool Raiders
# already done, skip over year: 1996 team: Haitai Tigers
# already done, skip over year: 1996 team: Hanwha Eagles
# already done, skip over year: 1996 team: Hyundai Unicorns
# already done, skip over year: 1996 team: LG Twins
# already done, skip over year: 1996 team: Lotte Giants
# already done, skip over year: 1996 team: OB Bears
# already done, skip over year: 1996 team: Samsung Lions
# already done, skip over year: 1996 team: Ssangbangwool Raiders
# already done, skip over year: 1995 team: Haitai Tigers
# already done, skip over year: 1995 team: Hanwha Eagles
# already done, skip over year: 1995 team: LG Twins
# already done, skip over year: 1995 team: Lotte Giants
# already done, skip over year: 1995 team: OB Bears
# already done, skip over year: 1995 team: Pacific Dolphins
# already done, skip over year: 1995 team: Samsung Lions
# already done, skip over year: 1995 team: Ssangbangwool Raiders
# already done, skip over year: 1994 team: Haitai Tigers
# already done, skip over year: 1994 team: Hanwha Eagles
# already done, skip over year: 1994 team: LG Twins
# already done, skip over year: 1994 team: Lotte Giants
# already done, skip over year: 1994 team: OB Bears
# already done, skip over year: 1994 team: Pacific Dolphins
# already done, skip over year: 1994 team: Samsung Lions
# already done, skip over year: 1994 team: Ssangbangwool Raiders
# already done, skip over year: 1993 team: Binggre Eagles
# already done, skip over year: 1993 team: Haitai Tigers
# already done, skip over year: 1993 team: LG Twins
# already done, skip over year: 1993 team: Lotte Giants
# already done, skip over year: 1993 team: OB Bears
# already done, skip over year: 1993 team: Pacific Dolphins
# already done, skip over year: 1993 team: Samsung Lions
# already done, skip over year: 1993 team: Ssangbangwool Raiders
# already done, skip over year: 1992 team: Binggre Eagles
# already done, skip over year: 1992 team: Haitai Tigers
# already done, skip over year: 1992 team: LG Twins
# already done, skip over year: 1992 team: Lotte Giants
# already done, skip over year: 1992 team: OB Bears
# already done, skip over year: 1992 team: Pacific Dolphins
# already done, skip over year: 1992 team: Samsung Lions
# already done, skip over year: 1992 team: Ssangbangwool Raiders
# already done, skip over year: 1991 team: Binggre Eagles
# already done, skip over year: 1991 team: Haitai Tigers
# already done, skip over year: 1991 team: LG Twins
# already done, skip over year: 1991 team: Lotte Giants
# already done, skip over year: 1991 team: OB Bears
# already done, skip over year: 1991 team: Pacific Dolphins
# already done, skip over year: 1991 team: Samsung Lions
# already done, skip over year: 1991 team: Ssangbangwool Raiders
# already done, skip over year: 1990 team: Binggre Eagles
# already done, skip over year: 1990 team: Haitai Tigers
# already done, skip over year: 1990 team: LG Twins
# already done, skip over year: 1990 team: Lotte Giants
# already done, skip over year: 1990 team: OB Bears
# already done, skip over year: 1990 team: Pacific Dolphins
# already done, skip over year: 1990 team: Samsung Lions
# already done, skip over year: 1989 team: Binggre Eagles
# already done, skip over year: 1989 team: Haitai Tigers
# already done, skip over year: 1989 team: Lotte Giants
# already done, skip over year: 1989 team: MBC Blue Dragons
# already done, skip over year: 1989 team: OB Bears
# already done, skip over year: 1989 team: Pacific Dolphins
# already done, skip over year: 1989 team: Samsung Lions
# already done, skip over year: 1988 team: Binggre Eagles
# already done, skip over year: 1988 team: Haitai Tigers
# already done, skip over year: 1988 team: Lotte Giants
# already done, skip over year: 1988 team: MBC Blue Dragons
# already done, skip over year: 1988 team: OB Bears
# already done, skip over year: 1988 team: Pacific Dolphins
# already done, skip over year: 1988 team: Samsung Lions
# already done, skip over year: 1987 team: Binggre Eagles
# already done, skip over year: 1987 team: Chungbo Pintos
# already done, skip over year: 1987 team: Haitai Tigers
# already done, skip over year: 1987 team: Lotte Giants
# already done, skip over year: 1987 team: MBC Blue Dragons
# already done, skip over year: 1987 team: OB Bears
# already done, skip over year: 1987 team: Samsung Lions
# already done, skip over year: 1986 team: Binggre Eagles
# already done, skip over year: 1986 team: Chungbo Pintos
# already done, skip over year: 1986 team: Haitai Tigers
# already done, skip over year: 1986 team: Lotte Giants
# already done, skip over year: 1986 team: MBC Blue Dragons
# already done, skip over year: 1986 team: OB Bears
# already done, skip over year: 1986 team: Samsung Lions
# already done, skip over year: 1985 team: Chungbo Pintos
# already done, skip over year: 1985 team: Haitai Tigers
# already done, skip over year: 1985 team: Lotte Giants
# already done, skip over year: 1985 team: MBC Blue Dragons
# already done, skip over year: 1985 team: OB Bears
# already done, skip over year: 1985 team: Samsung Lions
# dup skipped:  ('Yeong-hwa Cha', '1957-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---000yeo')
# dup skipped:  ('Jin-beom Chang', '1959-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-002jin')
# dup skipped:  ('Do-yeon Cho', '1961-08-06', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000do-')
# dup skipped:  ('Chung-yeol Chou', '1959-02-25', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--000chu')
# newly added:  ('Dong-sik Chu', '1948-08-23', 'https://www.baseball-reference.com/register/player.fcgi?id=chu---000don')
# dup skipped:  ('Gi-seon Hwang', '1958-06-02', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000gi-')
# newly added:  ('Jeong-nam Kang', '1960-08-14', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--002jeo')
# dup skipped:  ('Man-sik Kang', '1957-02-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--000man')
# have called 10 apis: 1 min break starts
# dup skipped:  ('Bong-yeon Kim', '1952-01-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002bon')
# newly added:  ('Hyeon-jae Kim', '1956-06-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010hye')
# dup skipped:  ('Il-gwon Kim', '1956-09-20', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005il-')
# dup skipped:  ('Il-hwan Kim', '1954-01-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006il-')
# dup skipped:  ('Jong Mo Kim', '1959-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010jon')
# dup skipped:  ('Jong-yun Kim', '1957-06-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jon')
# dup skipped:  ('Jun-hwan Kim', '1955-05-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005jun')
# dup skipped:  ('Mu-jong Kim', '1954-04-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005mu-')
# dup skipped:  ('Seong Han Kim', '1958-05-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---031seo')
# dup skipped:  ('Yong-nam Kim', '1958-02-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010yon')
# have called 20 apis: 1 min break starts
# dup skipped:  ('Sang-yun Lee', '1960-12-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---020san')
# dup skipped:  ('Jeong-myeon Lim', '1958-09-17', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000jeo')
# dup skipped:  ('Hyi-soo Mun', '1965-03-15', 'https://www.baseball-reference.com/register/player.fcgi?id=mun---001hyi')
# dup skipped:  ('Jeon-seop Pak', '1959-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---000jeo')
# dup skipped:  ('Soo-won Pang', '1960-01-04', 'https://www.baseball-reference.com/register/player.fcgi?id=pang--001soo')
# dup skipped:  ('Jeong-hwan Seo', '1955-07-05', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---002jeo')
# dup skipped:  ('Il-seop Song', '1959-08-17', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000il-')
# dup skipped:  ('Seung-ho Yang', '1960-01-10', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--003seu')
# dup skipped:  ('Seung-an Yu', '1956-06-01', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----000seu')
# Finished processing 1984 Haitai Tigers.
# have called 30 apis: 1 min break starts
# dup skipped:  ('Chang-wan An', '1961-12-05', 'https://www.baseball-reference.com/register/player.fcgi?id=an----000cha')
# dup skipped:  ('Chang-ho Chen', '1954-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=chen--000cha')
# dup skipped:  ('Seong-ok Cho', '1961-08-25', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---004seo')
# dup skipped:  ('Yong-cheol Cho', '1965-08-22', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---002yon')
# dup skipped:  ('Dong-won Choi', '1958-05-24', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--003don')
# dup skipped:  ('In Kyo Chung', '1957-12-23', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-003in-')
# dup skipped:  ('Moon Yeon Han', '1961-04-10', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000mun')
# dup skipped:  ('Mun-jong Hong', '1954-11-14', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000mun')
# dup skipped:  ('Yeong-gi Jeong', '1956-02-29', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-002yeo')
# dup skipped:  ('Han-jo Kim', '1962-01-25', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002han')
# have called 40 apis: 1 min break starts
# dup skipped:  ('Jae-sang Kim', '1959-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016jae')
# dup skipped:  ('Jae-yeol Kim', '1961-04-25', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---018jae')
# dup skipped:  ('Jin-geun Kim', '1956-03-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008jin')
# dup skipped:  ('Min Ho Kim', '1961-04-28', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---011min')
# dup skipped:  ('Mun-hyi Kim', '1955-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002mun')
# dup skipped:  ('Seok-il Kim', '1959-11-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---022seo')
# newly added:  ('Seong-gwan Kim', '1952-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---029seo')
# dup skipped:  ('Seong-ho Kim', '1960-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---033seo')
# dup skipped:  ('Yong Hee Kim', '1955-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007yon')
# dup skipped:  ('Yong-cheol Kim', '1957-09-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004yon')
# have called 50 apis: 1 min break starts
# dup skipped:  ('Jin-u Lee', '1956-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002jin')
# dup skipped:  ('Kwang Kil Lee', '1960-08-04', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002gwa')
# dup skipped:  ('Mun-han Lee', '1961-07-03', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000mun')
# dup skipped:  ('Seok-gyu Lee', '1957-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---004seo')
# newly added:  ('Yun-seop Lee', '1958-03-01', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001yun')
# dup skipped:  ('Ho-gyun Lim', '1956-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000ho-')
# dup skipped:  ('Gyeong-hwan Pae', '1956-07-08', 'https://www.baseball-reference.com/register/player.fcgi?id=pae---000gye')
# dup skipped:  ('Yong-seong Pak', '1958-09-30', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---001yon')
# newly added:  ('Deok-yong Park', '1956-11-07', 'https://www.baseball-reference.com/register/player.fcgi?id=park--000deo')
# dup skipped:  ('Young Tae Park', '1959-08-25', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---001yeo')
# have called 60 apis: 1 min break starts
# dup skipped:  ('Jae-won Shim', '1953-07-30', 'https://www.baseball-reference.com/register/player.fcgi?id=shim--002jae')
# dup skipped:  ('Du-yeol Yu', '1956-10-29', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----000du-')
# Finished processing 1984 Lotte Giants.
# dup skipped:  ('Dong-yeol Cha', '1956-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---001don')
# dup skipped:  ('Jun-seop Cha', '1956-10-16', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---000jun')
# newly added:  ('Jung Woo Choi', '1955-06-02', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--002jeo')
# dup skipped:  ('Gi-ryong Ha', '1955-05-08', 'https://www.baseball-reference.com/register/player.fcgi?id=ha----000gi-')
# dup skipped:  ('Sun-myeong Jeong', '1954-06-30', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001sun')
# dup skipped:  ('Ba-wi Kim', '1955-04-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000ba-')
# dup skipped:  ('Bong Keun Kim', '1961-03-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000bon')
# have called 70 apis: 1 min break starts
# dup skipped:  ('Bong-gi Kim', '1953-12-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001bon')
# dup skipped:  ('Gyeong-pyo Kim', '1960-04-29', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---014gye')
# dup skipped:  ('In-sik Kim', '1953-11-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004in-')
# dup skipped:  ('Jae-bak Kim', '1954-05-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---014jae')
# dup skipped:  ('Jeong-soo Kim', '1960-10-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016jeo')
# dup skipped:  ('Mun-yeong Kim', '1960-04-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003mun')
# dup skipped:  ('Sang-hun Kim', '1960-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013san')
# dup skipped:  ('Yeong-gyun Kim', '1961-07-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008yeo')
# dup skipped:  ('Yong Dal Kim', '1956-05-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005yon')
# dup skipped:  ('Yong-un Kim', '1955-06-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013yon')
# have called 80 apis: 1 min break starts
# dup skipped:  ('Gil-hwan Lee', '1959-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002gil')
# dup skipped:  ('Gwang-eun Lee', '1955-06-28', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000gwa')
# dup skipped:  ('Gwang-gwon Lee', '1954-06-28', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003gwa')
# dup skipped:  ('Hae-chang Lee', '1953-04-23', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001hae')
# dup skipped:  ('Jong-do Lee', '1952-05-22', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---008jon')
# dup skipped:  ('Seong-soo Lee', '1960-10-23', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---009seo')
# dup skipped:  ('Yeong-il Oh', '1960-02-06', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000yeo')
# dup skipped:  ('Cheol Young Park', '1960-05-22', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---005che')
# dup skipped:  ('Eon-ho Shin', '1955-12-18', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--000eon')
# dup skipped:  ('Yeong-un Song', '1952-12-15', 'https://www.baseball-reference.com/register/player.fcgi?id=song--001yeo')
# have called 90 apis: 1 min break starts
# dup skipped:  ('Je-ryong Yu', '1956-08-11', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----000je-')
# dup skipped:  ('Jong-gyeom Yu', '1956-09-14', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----000jon')
# dup skipped:  ('Seong-ryong Yu', '1960-07-18', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----003seo')
# Finished processing 1984 MBC Blue Dragons.
# dup skipped:  ('Ho-yeon Chang', '1960-05-05', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-001ho-')
# dup skipped:  ('Bum Hyun Cho', '1960-10-01', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000beo')
# newly added:  ('Jong-gyu Cho', '1955-10-08', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000jon')
# dup skipped:  ('Yil Yeon Choi', '1961-07-27', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--000il-')
# dup skipped:  ('Hyung Chul Gye', '1953-04-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kye---000hye')
# dup skipped:  ('Dai Hwa Han', '1960-07-08', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000dae')
# have called 100 apis: 1 min break starts
# dup skipped:  ('O-jong Han', '1961-06-16', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000o-j')
# dup skipped:  ('Hyi-seop Hong', '1957-02-08', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000hyi')
# dup skipped:  ('Sin-cha Hong', '1959-01-03', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000sin')
# dup skipped:  ('Tae-hwan Hwang', '1952-08-06', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000tae')
# dup skipped:  ('Jong-hyeon Jeong', '1959-12-05', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-002jon')
# dup skipped:  ('Cheol-won Kang', '1958-01-27', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--001che')
# dup skipped:  ('Dae Jin Kim', '1955-12-22', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005dae')
# dup skipped:  ('Jin Wook Kim', '1960-08-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013jin')
# dup skipped:  ('Jin-hong Kim', '1962-09-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---011jin')
# dup skipped:  ('Kwang Lim Kim', '1961-03-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005gwa')
# have called 110 apis: 1 min break starts
# dup skipped:  ('Kwang Soo Kim', '1959-01-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006gwa')
# dup skipped:  ('Kyung Moon Kim', '1958-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---012gye')
# dup skipped:  ('Myeong-gu Kim', '1961-05-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001mye')
# dup skipped:  ('Seong-ho Kim', '1955-09-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---032seo')
# dup skipped:  ('U-yeol Kim', '1949-09-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000u-y')
# dup skipped:  ('Chun Suh Koo', '1963-08-15', 'https://www.baseball-reference.com/register/player.fcgi?id=ku----000che')
# dup skipped:  ('Jae-seo Ku', '1963-08-15', 'https://www.baseball-reference.com/register/player.fcgi?id=ku----000jae')
# dup skipped:  ('Geun-sik Lee', '1959-06-23', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003geu')
# dup skipped:  ('Hong Bum Lee', '1953-02-10', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000hon')
# newly added:  ('Sam-yeol Lee', '1955-03-10', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---004sam')
# have called 120 apis: 1 min break starts
# dup skipped:  ('Won-yeong Pae', '1962-01-15', 'https://www.baseball-reference.com/register/player.fcgi?id=pae---000won')
# dup skipped:  ('Hae-jong Pak', '1952-09-09', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---000hae')
# dup skipped:  ('Jong-hun Pak', '1959-06-12', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---005jon')
# dup skipped:  ('Sang Youl Park', '1955-08-05', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---006san')
# dup skipped:  ('In-sang Sa', '1960-12-18', 'https://www.baseball-reference.com/register/player.fcgi?id=sa----000in-')
# dup skipped:  ('Kyung Sik Shin', '1961-08-19', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--002gye')
# dup skipped:  ('Se-jong Yang', '1958-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000se-')
# dup skipped:  ('Ji Hwuon Yoo', '1955-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----002ji-')
# dup skipped:  ('Dong-gyun Yun', '1949-07-02', 'https://www.baseball-reference.com/register/player.fcgi?id=yun---001don')
# dup skipped:  ('Seok-hwan Yun', '1961-07-17', 'https://www.baseball-reference.com/register/player.fcgi?id=yun---004seo')
# Finished processing 1984 OB Bears.
# have called 130 apis: 1 min break starts
# newly added:  ('Tae-seop Aum', '1959-07-17', 'https://www.baseball-reference.com/register/player.fcgi?id=aum---000tae')
# dup skipped:  ('Jeong-gi Chang', '1958-08-10', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-001jeo')
# dup skipped:  ('Myeong-bu Chang', '1950-12-27', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-000mye')
# dup skipped:  ('Heung-un Cho', '1954-08-13', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000heu')
# dup skipped:  ('Gye Hun Choi', '1961-06-06', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--001gye')
# dup skipped:  ('Hong-seok Chou', '1960-03-28', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--001hon')
# dup skipped:  ('Yeong-hwan Chou', '1959-02-28', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--001yeo')
# newly added:  ('Un Ho', '1959-08-18', 'https://www.baseball-reference.com/register/player.fcgi?id=ho----000un-')
# dup skipped:  ('Gu-seon Jeong', '1956-12-15', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-000gu-')
# have called 140 apis: 1 min break starts
# dup skipped:  ('Gu-wang Jeong', '1954-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001gu-')
# dup skipped:  ('Seong-man Jeong', '1955-10-10', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-005seo')
# dup skipped:  ('Sa-yong Kam', '1957-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kam---000sa-')
# dup skipped:  ('Dae Jin Kim', '1955-12-22', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005dae')
# newly added:  ('Deok-yeol Kim', '1955-04-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002deo')
# dup skipped:  ('Ho-geun Kim', '1960-06-29', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001ho-')
# dup skipped:  ('Jae-hyeon Kim', '1959-03-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jae')
# dup skipped:  ('Jeong-soo Kim', '1953-04-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jeo')
# dup skipped:  ('Jin-u Kim', '1958-09-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---012jin')
# dup skipped:  ('Kyung Nam Kim', '1959-11-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013gye')
# have called 150 apis: 1 min break starts
# dup skipped:  ('Moo Gwan Kim', '1955-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004mu-')
# dup skipped:  ('Sang-gi Kim', '1961-03-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010san')
# dup skipped:  ('U-geun Kim', '1956-01-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000u-g')
# dup skipped:  ('Yu-dong Kim', '1954-04-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003yu-')
# dup skipped:  ('Gwang-ok Kum', '1956-12-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kum---000gwa')
# dup skipped:  ('Doo Jo Kwon', '1951-06-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000du-')
# dup skipped:  ('Seon-ung Lee', '1961-02-11', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---006seo')
# dup skipped:  ('Yeong-gu Lee', '1954-12-24', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---007yeo')
# dup skipped:  ('Mun-hyeon Oh', '1953-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000mun')
# newly added:  ('In-cheon Paek', '1943-11-27', 'https://www.baseball-reference.com/register/player.fcgi?id=haku--000jin')
# have called 160 apis: 1 min break starts
# dup skipped:  ('Jeong-hu Pak', '1959-12-22', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---002jeo')
# newly added:  ('Jun-yeong Pak', '1953-02-20', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---001jun')
# dup skipped:  ('Tae-jun Shin', '1955-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--000tae')
# dup skipped:  ('Gyeong-ha Wu', '1957-10-15', 'https://www.baseball-reference.com/register/player.fcgi?id=wu----000gye')
# dup skipped:  ('Seung Kwan Yang', '1959-06-02', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--002seu')
# dup skipped:  ('Ho-bong Yin', '1958-03-04', 'https://www.baseball-reference.com/register/player.fcgi?id=yin---000ho-')
# Finished processing 1984 Sammi Superstars.
# newly added:  ('Bo-seong Chen', '1953-06-11', 'https://www.baseball-reference.com/register/player.fcgi?id=chen--000bo-')
# dup skipped:  ('Dong-han Chin', '1961-06-04', 'https://www.baseball-reference.com/register/player.fcgi?id=chin--000don')
# dup skipped:  ('Hak-soo Ham', '1955-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=ham---000hak')
# have called 170 apis: 1 min break starts
# dup skipped:  ('Gyu-ok Ho', '1956-08-08', 'https://www.baseball-reference.com/register/player.fcgi?id=ho----000gyu')
# dup skipped:  ('Seung-gyu Hong', '1960-06-20', 'https://www.baseball-reference.com/register/player.fcgi?id=hong--000seu')
# dup skipped:  ('Byung Il Hwang', '1960-03-22', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000bye')
# dup skipped:  ('Gyu-bong Hwang', '1953-04-24', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000gyu')
# dup skipped:  ('Hyo-jo Jang', '1956-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-000hyo')
# dup skipped:  ('Tae Soo Jang', '1957-10-15', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-003tae')
# dup skipped:  ('Hyeon-bal Jeong', '1953-02-20', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-005hye')
# dup skipped:  ('Jin-ho Jeong', '1956-06-23', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001jin')
# dup skipped:  ('Seong-ryong Jeong', '1964-05-19', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-006seo')
# dup skipped:  ('Yong-gwon Jun', '1961-04-12', 'https://www.baseball-reference.com/register/player.fcgi?id=jun---000yon')
# have called 180 apis: 1 min break starts
# dup skipped:  ('Dong-jae Kim', '1960-10-31', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013don')
# dup skipped:  ('Geun-seok Kim', '1962-06-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000geu')
# dup skipped:  ('Han-geun Kim', '1955-03-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001han')
# dup skipped:  ('I-soo Kim', '1960-08-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000i-s')
# dup skipped:  ('Il-ryung Kim', '1951-05-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008il-')
# dup skipped:  ('Si Jin Kim', '1958-03-20', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001si-')
# dup skipped:  ('Sung Rae Kim', '1961-12-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---037seo')
# dup skipped:  ('Ki-hong Kwon', '1961-07-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000gi-')
# dup skipped:  ('Young Ho Kwon', '1954-01-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--002yeo')
# dup skipped:  ('Man Soo Lee', '1958-09-19', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002man')
# have called 190 apis: 1 min break starts
# dup skipped:  ('Sun Hee Lee', '1955-02-14', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---005seo')
# dup skipped:  ('Dae Seok Oh', '1960-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000dae')
# dup skipped:  ('Dae-ung Pae', '1954-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=pae---000dae')
# dup skipped:  ('Chan Pak', '1955-04-26', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---003cha')
# dup skipped:  ('Jung Hwan Park', '1957-05-25', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---003jeo')
# dup skipped:  ('Seung Ho Park', '1958-02-09', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---000seu')
# newly added:  ('Young-jin Park', '1958-07-27', 'https://www.baseball-reference.com/register/player.fcgi?id=park--002you')
# dup skipped:  ('Sang Dae Son', '1954-10-20', 'https://www.baseball-reference.com/register/player.fcgi?id=son---001san')
# dup skipped:  ('Il Soo Song', '1950-12-13', 'https://www.baseball-reference.com/register/player.fcgi?id=song--001il-')
# dup skipped:  ('Jin-ho Song', '1957-08-16', 'https://www.baseball-reference.com/register/player.fcgi?id=song--001jin')
# have called 200 apis: 1 min break starts
# dup skipped:  ('Nak-soo Song', '1957-08-12', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000nak')
# dup skipped:  ('Il Hwan Yang', '1961-06-10', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000il-')
# Finished processing 1984 Samsung Lions.
# dup skipped:  ('Yeong-hwa Cha', '1957-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---000yeo')
# dup skipped:  ('Jin-beom Chang', '1959-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-002jin')
# dup skipped:  ('Jong-gyu Cho', '1955-10-08', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000jon')
# dup skipped:  ('Chung-yeol Chou', '1959-02-25', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--000chu')
# dup skipped:  ('Dong-sik Chu', '1948-08-23', 'https://www.baseball-reference.com/register/player.fcgi?id=chu---000don')
# newly added:  ('Yeong-jae Eom', '1960-10-24', 'https://www.baseball-reference.com/register/player.fcgi?id=eom---000yeo')
# dup skipped:  ('Gi-seon Hwang', '1958-06-02', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000gi-')
# have called 210 apis: 1 min break starts
# dup skipped:  ('Man-sik Kang', '1957-02-15', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--000man')
# dup skipped:  ('Bong-yeon Kim', '1952-01-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002bon')
# dup skipped:  ('Hyeon-jae Kim', '1956-06-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010hye')
# dup skipped:  ('Il-gwon Kim', '1956-09-20', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005il-')
# dup skipped:  ('Il-hwan Kim', '1954-01-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006il-')
# dup skipped:  ('Jong Mo Kim', '1959-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010jon')
# dup skipped:  ('Jong-yun Kim', '1957-06-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jon')
# dup skipped:  ('Jun-hwan Kim', '1955-05-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005jun')
# dup skipped:  ('Mu-jong Kim', '1954-04-07', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005mu-')
# dup skipped:  ('Seong Han Kim', '1958-05-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---031seo')
# have called 220 apis: 1 min break starts
# dup skipped:  ('U-geun Kim', '1956-01-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000u-g')
# dup skipped:  ('Yong-nam Kim', '1958-02-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010yon')
# dup skipped:  ('Sang-yun Lee', '1960-12-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---020san')
# dup skipped:  ('Jeong-myeon Lim', '1958-09-17', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000jeo')
# dup skipped:  ('Jeon-seop Pak', '1959-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---000jeo')
# dup skipped:  ('Soo-won Pang', '1960-01-04', 'https://www.baseball-reference.com/register/player.fcgi?id=pang--001soo')
# dup skipped:  ('Jeong-hwan Seo', '1955-07-05', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---002jeo')
# dup skipped:  ('Tae-jun Shin', '1955-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--000tae')
# dup skipped:  ('Il-seop Song', '1959-08-17', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000il-')
# dup skipped:  ('Seung-ho Yang', '1960-01-10', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--003seu')
# Finished processing 1983 Haitai Tigers.
# have called 230 apis: 1 min break starts
# dup skipped:  ('Dong-yeol Cha', '1956-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---001don')
# dup skipped:  ('Chang-ho Chen', '1954-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=chen--000cha')
# dup skipped:  ('Dong-won Choi', '1958-05-24', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--003don')
# dup skipped:  ('Moon Yeon Han', '1961-04-10', 'https://www.baseball-reference.com/register/player.fcgi?id=han---000mun')
# dup skipped:  ('Hak-soo Jeong', '1956-12-04', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001hak')
# dup skipped:  ('Mun-seop Jeong', '1960-04-04', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001mun')
# dup skipped:  ('Yeong-gi Jeong', '1956-02-29', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-002yeo')
# dup skipped:  ('Deok-yeol Kim', '1955-04-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002deo')
# dup skipped:  ('Ho-geun Kim', '1960-06-29', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001ho-')
# have called 240 apis: 1 min break starts
# dup skipped:  ('Jae-sang Kim', '1959-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016jae')
# dup skipped:  ('Jeong-soo Kim', '1953-04-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jeo')
# newly added:  ('Jong-geun Kim', '1960-03-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---008jon')
# dup skipped:  ('Mun-hyi Kim', '1955-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002mun')
# dup skipped:  ('Seok-il Kim', '1959-11-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---022seo')
# dup skipped:  ('Seong-gwan Kim', '1952-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---029seo')
# dup skipped:  ('Seong-ho Kim', '1960-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---033seo')
# ...
# dup skipped:  ('Sang-yun Lee', '1960-12-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---020san')
# have called 400 apis: 1 min break starts
# dup skipped:  ('Jeong-myeon Lim', '1958-09-17', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000jeo')
# dup skipped:  ('Jeon-seop Pak', '1959-02-04', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---000jeo')
# dup skipped:  ('Soo-won Pang', '1960-01-04', 'https://www.baseball-reference.com/register/player.fcgi?id=pang--001soo')
# dup skipped:  ('Tae-jun Shin', '1955-06-27', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--000tae')
# Finished processing 1982 Haitai Tigers.
# dup skipped:  ('Tae-seop Aum', '1959-07-17', 'https://www.baseball-reference.com/register/player.fcgi?id=aum---000tae')
# newly added:  ('Gi-man Bang', '1954-05-15', 'https://www.baseball-reference.com/register/player.fcgi?id=bang--000gi-')
# dup skipped:  ('Dong-yeol Cha', '1956-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---001don')
# dup skipped:  ('Chang-ho Chen', '1954-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=chen--000cha')
# newly added:  ('Ok-gyu Choi', '1953-07-17', 'https://www.baseball-reference.com/register/player.fcgi?id=choi--000ok-')
# have called 410 apis: 1 min break starts
# newly added:  ('Sun-ha Chou', '1955-01-15', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--000sun')
# dup skipped:  ('Hak-soo Jeong', '1956-12-04', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001hak')
# dup skipped:  ('Mun-seop Jeong', '1960-04-04', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001mun')
# dup skipped:  ('Deok-yeol Kim', '1955-04-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002deo')
# dup skipped:  ('Il-hwan Kim', '1954-01-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006il-')
# dup skipped:  ('Jae-sang Kim', '1959-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---016jae')
# dup skipped:  ('Jeong-soo Kim', '1953-04-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jeo')
# dup skipped:  ('Mun-hyi Kim', '1955-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002mun')
# dup skipped:  ('Seong-gwan Kim', '1952-07-06', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---029seo')
# dup skipped:  ('Yong Hee Kim', '1955-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007yon')
# have called 420 apis: 1 min break starts
# dup skipped:  ('Yong-cheol Kim', '1957-09-21', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004yon')
# dup skipped:  ('Doo Jo Kwon', '1951-06-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--000du-')
# dup skipped:  ('Jin-u Lee', '1956-03-18', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002jin')
# newly added:  ('Seong-deuk Lee', '1953-07-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---007seo')
# dup skipped:  ('Yun-seop Lee', '1958-03-01', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---001yun')
# dup skipped:  ('Sang-soo No', '1958-05-05', 'https://www.baseball-reference.com/register/player.fcgi?id=no----001san')
# dup skipped:  ('Yong-seong Pak', '1958-09-30', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---001yon')
# Finished processing 1982 Lotte Giants.
# dup skipped:  ('Jun-seop Cha', '1956-10-16', 'https://www.baseball-reference.com/register/player.fcgi?id=cha---000jun')
# dup skipped:  ('Ho Cho', '1957-09-22', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000ho-')
# have called 430 apis: 1 min break starts
# dup skipped:  ('Jung Woo Choi', '1955-06-02', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--002jeo')
# dup skipped:  ('Jeong-gi Chou', '1956-07-16', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--001jeo')
# dup skipped:  ('Gi-ryong Ha', '1955-05-08', 'https://www.baseball-reference.com/register/player.fcgi?id=ha----000gi-')
# dup skipped:  ('Sun-myeong Jeong', '1954-06-30', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001sun')
# dup skipped:  ('Yeong-gi Jeong', '1956-02-29', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-002yeo')
# dup skipped:  ('Ba-wi Kim', '1955-04-08', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000ba-')
# dup skipped:  ('Bong-gi Kim', '1953-12-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001bon')
# dup skipped:  ('In-sik Kim', '1953-11-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004in-')
# dup skipped:  ('Jae-bak Kim', '1954-05-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---014jae')
# newly added:  ('Si-cheol Kim', '1958-11-24', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000si-')
# have called 440 apis: 1 min break starts
# dup skipped:  ('Yong Dal Kim', '1956-05-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---005yon')
# dup skipped:  ('Yong-un Kim', '1955-06-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013yon')
# dup skipped:  ('Gil-hwan Lee', '1959-07-15', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002gil')
# dup skipped:  ('Gwang-eun Lee', '1955-06-28', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000gwa')
# dup skipped:  ('Gwang-gwon Lee', '1954-06-28', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003gwa')
# dup skipped:  ('Jong-do Lee', '1952-05-22', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---008jon')
# newly added:  ('Soo-hyi Pae', '1955-04-30', 'https://www.baseball-reference.com/register/player.fcgi?id=pae---000soo')
# dup skipped:  ('In-cheon Paek', '1943-11-27', 'https://www.baseball-reference.com/register/player.fcgi?id=haku--000jin')
# dup skipped:  ('Jae-cheon Pak', '1957-10-10', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---002jae')
# dup skipped:  ('Seok-chae Pak', '1957-08-26', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---002seo')
# have called 450 apis: 1 min break starts
# dup skipped:  ('Eon-ho Shin', '1955-12-18', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--000eon')
# dup skipped:  ('Yeong-un Song', '1952-12-15', 'https://www.baseball-reference.com/register/player.fcgi?id=song--001yeo')
# dup skipped:  ('Jong-gyeom Yu', '1956-09-14', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----000jon')
# dup skipped:  ('Seung-an Yu', '1956-06-01', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----000seu')
# Finished processing 1982 MBC Blue Dragons.
# dup skipped:  ('Bum Hyun Cho', '1960-10-01', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000beo')
# dup skipped:  ('Hyung Chul Gye', '1953-04-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kye---000hye')
# dup skipped:  ('Tae-hwan Hwang', '1952-08-06', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000tae')
# dup skipped:  ('Hyeok-jin Jeong', '1960-07-05', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-004hye')
# dup skipped:  ('Jong-hyeon Jeong', '1959-12-05', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-002jon')
# have called 460 apis: 1 min break starts
# dup skipped:  ('Cheol-won Kang', '1958-01-27', 'https://www.baseball-reference.com/register/player.fcgi?id=kang--001che')
# dup skipped:  ('Hyeon-hong Kim', '1956-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---009hye')
# dup skipped:  ('Jin-hong Kim', '1962-09-10', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---011jin')
# dup skipped:  ('Kwang Soo Kim', '1959-01-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---006gwa')
# dup skipped:  ('Kyung Moon Kim', '1958-11-01', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---012gye')
# dup skipped:  ('U-yeol Kim', '1949-09-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000u-y')
# dup skipped:  ('Yu-dong Kim', '1954-04-09', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---003yu-')
# dup skipped:  ('Chun Suh Koo', '1963-08-15', 'https://www.baseball-reference.com/register/player.fcgi?id=ku----000che')
# dup skipped:  ('Jae-seo Ku', '1963-08-15', 'https://www.baseball-reference.com/register/player.fcgi?id=ku----000jae')
# newly added:  ('Geun-sik Lee', '1958-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002geu')
# have called 470 apis: 1 min break starts
# dup skipped:  ('Geun-sik Lee', '1959-06-23', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003geu')
# dup skipped:  ('Hong Bum Lee', '1953-02-10', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000hon')
# dup skipped:  ('Cheol-sun Pak', '1956-03-12', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---003che')
# newly added:  ('Jong-ho Pak', '1964-12-07', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---004jon')
# dup skipped:  ('Sang Youl Park', '1955-08-05', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---006san')
# dup skipped:  ('Dae-yeong Seonu', '1957-09-12', 'https://www.baseball-reference.com/register/player.fcgi?id=seonu-000dae')
# dup skipped:  ('Kyung Sik Shin', '1961-08-19', 'https://www.baseball-reference.com/register/player.fcgi?id=shin--002gye')
# dup skipped:  ('Se-jong Yang', '1958-01-17', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--000se-')
# dup skipped:  ('Ji Hwuon Yoo', '1955-10-04', 'https://www.baseball-reference.com/register/player.fcgi?id=yu----002ji-')
# dup skipped:  ('Dong-gyun Yun', '1949-07-02', 'https://www.baseball-reference.com/register/player.fcgi?id=yun---001don')
# Finished processing 1982 OB Bears.
# have called 480 apis: 1 min break starts
# dup skipped:  ('Jeong-gi Chang', '1958-08-10', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-001jeo')
# dup skipped:  ('Heung-un Cho', '1954-08-13', 'https://www.baseball-reference.com/register/player.fcgi?id=cho---000heu')
# dup skipped:  ('Yeong-hwan Chou', '1959-02-28', 'https://www.baseball-reference.com/register/player.fcgi?id=chou--001yeo')
# newly added:  ('Sang-yeon Han', '1964-08-27', 'https://www.baseball-reference.com/register/player.fcgi?id=han---001san')
# dup skipped:  ('Un Ho', '1959-08-18', 'https://www.baseball-reference.com/register/player.fcgi?id=ho----000un-')
# dup skipped:  ('Sa-yong Kam', '1957-03-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kam---000sa-')
# newly added:  ('Dong-cheol Kim', '1960-06-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---010don')
# newly added:  ('Gu-gil Kim', '1953-06-16', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000gu-')
# newly added:  ('Ho-in Kim', '1954-09-12', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---002ho-')
# have called 490 apis: 1 min break starts
# dup skipped:  ('Jae-hyeon Kim', '1959-03-03', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---015jae')
# newly added:  ('Jin-cheol Kim', '1958-04-18', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---007jin')
# dup skipped:  ('Kyung Nam Kim', '1959-11-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---013gye')
# dup skipped:  ('Moo Gwan Kim', '1955-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---004mu-')
# dup skipped:  ('Gwang-ok Kum', '1956-12-19', 'https://www.baseball-reference.com/register/player.fcgi?id=kum---000gwa')
# newly added:  ('Chan-seon Lee', '1962-05-21', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---008cha')
# dup skipped:  ('Chul Sung Lee', '1957-03-14', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---003che')
# newly added:  ('Chun-geun Lee', '1948-03-01', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---000chu')
# newly added:  ('Gyeong-soo Lee', '1959-05-27', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---008gye')
# newly added:  ('Ju-mo Mun', '1962-11-14', 'https://www.baseball-reference.com/register/player.fcgi?id=mun---000ju-')
# have called 500 apis: 1 min break starts
# dup skipped:  ('Mun-hyeon Oh', '1953-02-13', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000mun')
# dup skipped:  ('Jun-yeong Pak', '1953-02-20', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---001jun')
# newly added:  ('Gyeong-ho Park', '1951-01-15', 'https://www.baseball-reference.com/register/player.fcgi?id=park--003gye')
# newly added:  ('Gyeong-seop Song', '1960-11-26', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000gye')
# dup skipped:  ('Seung Kwan Yang', '1959-06-02', 'https://www.baseball-reference.com/register/player.fcgi?id=yang--002seu')
# dup skipped:  ('Ho-bong Yin', '1958-03-04', 'https://www.baseball-reference.com/register/player.fcgi?id=yin---000ho-')
# Finished processing 1982 Sammi Superstars.
# dup skipped:  ('Bo-seong Chen', '1953-06-11', 'https://www.baseball-reference.com/register/player.fcgi?id=chen--000bo-')
# dup skipped:  ('Hak-soo Ham', '1955-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=ham---000hak')
# dup skipped:  ('Gyu-ok Ho', '1956-08-08', 'https://www.baseball-reference.com/register/player.fcgi?id=ho----000gyu')
# have called 510 apis: 1 min break starts
# dup skipped:  ('Gyu-bong Hwang', '1953-04-24', 'https://www.baseball-reference.com/register/player.fcgi?id=hwang-000gyu')
# dup skipped:  ('Tae Soo Jang', '1957-10-15', 'https://www.baseball-reference.com/register/player.fcgi?id=chang-003tae')
# dup skipped:  ('Gu-wang Jeong', '1954-03-26', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-001gu-')
# dup skipped:  ('Hyeon-bal Jeong', '1953-02-20', 'https://www.baseball-reference.com/register/player.fcgi?id=jeong-005hye')
# dup skipped:  ('Han-geun Kim', '1955-03-05', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---001han')
# newly added:  ('Hwi-uk Kim', '1957-08-11', 'https://www.baseball-reference.com/register/player.fcgi?id=kim---000hwi')
# dup skipped:  ('Young Ho Kwon', '1954-01-23', 'https://www.baseball-reference.com/register/player.fcgi?id=kwon--002yeo')
# dup skipped:  ('Man Soo Lee', '1958-09-19', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---002man')
# dup skipped:  ('Sun Hee Lee', '1955-02-14', 'https://www.baseball-reference.com/register/player.fcgi?id=lee---005seo')
# newly added:  ('Sin-geun Lim', '1949-11-28', 'https://www.baseball-reference.com/register/player.fcgi?id=lim---000sin')
# have called 520 apis: 1 min break starts
# dup skipped:  ('Dae Seok Oh', '1960-01-02', 'https://www.baseball-reference.com/register/player.fcgi?id=oh----000dae')
# dup skipped:  ('Dae-ung Pae', '1954-03-02', 'https://www.baseball-reference.com/register/player.fcgi?id=pae---000dae')
# dup skipped:  ('Chan Pak', '1955-04-26', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---003cha')
# dup skipped:  ('Jung Hwan Park', '1957-05-25', 'https://www.baseball-reference.com/register/player.fcgi?id=pak---003jeo')
# dup skipped:  ('Young-jin Park', '1958-07-27', 'https://www.baseball-reference.com/register/player.fcgi?id=park--002you')
# dup skipped:  ('Jeong-hwan Seo', '1955-07-05', 'https://www.baseball-reference.com/register/player.fcgi?id=seo---002jeo')
# dup skipped:  ('Sang Deuk Shon', '1956-04-03', 'https://www.baseball-reference.com/register/player.fcgi?id=son---002san')
# dup skipped:  ('Sang Dae Son', '1954-10-20', 'https://www.baseball-reference.com/register/player.fcgi?id=son---001san')
# dup skipped:  ('Jin-ho Song', '1957-08-16', 'https://www.baseball-reference.com/register/player.fcgi?id=song--001jin')
# dup skipped:  ('Nak-soo Song', '1957-08-12', 'https://www.baseball-reference.com/register/player.fcgi?id=song--000nak')
# Finished processing 1982 Samsung Lions.
